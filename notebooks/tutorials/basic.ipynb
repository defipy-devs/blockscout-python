# %% [markdown]
# * https://explorer.rollux.com/api/v2/addresses

# %%
from blockscout import Blockscout
from blockscout import Explorer
from blockscout import Net

# %%
Explorer.ROLLUX

# %%
ETHERSCAN_API_KEY = 'GHFFWQYDKM7EFP7PBQNHSADWBDJP4S2S5W'
eth = Blockscout(ETHERSCAN_API_KEY, Net.ROLLUX) 
eth.get_addresses()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/blockscout/configs/ROLLUX-stable.json
# addresses
# {'exchange_rate': None,
#  'items': [{'coin_balance': '3562345790348679629254255',
#    'tx_count': '0',
#    'ens_domain_name': None,
#    'hash': '0x4200000000000000000000000000000000000016',
#    'implementation_name': 'L2ToL1MessagePasser',
#    'is_contract': True,
#    'is_verified': True,
#    'metadata': None,
#    'name': 'Proxy',
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '2389404170619869910712627',
#    'tx_count': '3618',
#    'ens_domain_name': None,
#    'hash': '0x4200000000000000000000000000000000000006',
#    'implementation_name': None,
#    'is_contract': True,
#    'is_verified': True,
#    'metadata': None,
#    'name': 'WETH9',
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '2102094138991638080984784',
# ...

# %%
ETHERSCAN_API_KEY = 'GHFFWQYDKM7EFP7PBQNHSADWBDJP4S2S5W'
eth = Blockscout(ETHERSCAN_API_KEY) 
eth.get_eth_balance(address="0xddbd2b932c763ba5b1b7ae3b362eac3e8d40121a")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/blockscout/configs/MAIN-stable.json
# module=account&action=balance&address=0xddbd2b932c763ba5b1b7ae3b362eac3e8d40121a&tag=latest
# {'message': "Params 'module' and 'action' are required parameters",
#  'result': None,
#  'status': '0'}
