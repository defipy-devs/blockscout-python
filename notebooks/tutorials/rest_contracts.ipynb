# %%
from blockscout import Blockscout
from blockscout import Net
from blockscout import API

eth = Blockscout(Net.ROLLUX, API.REST)

# %%
#eth.get_smart_contract(address="0x420000000000000000000000000000000000001A")

# %%
eth.get_smart_contract_counters()

# %%
eth.get_smart_contracts(contract_type="proxy")
# Out:
# url: https://explorer.rollux.com/api/v2/smart-contracts?q=proxy&filter=vyper%20%7C%20solidity%20%7C%20yul
# {'items': [{'address': {'ens_domain_name': None,
#     'hash': '0x420000000000000000000000000000000000001A',
#     'implementation_name': None,
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'Proxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '966182273769402504708',
#    'compiler_version': 'v0.8.15+commit.e14f2714',
#    'has_constructor_args': False,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': True,
#    'tx_count': 0,
#    'verified_at': '2024-07-09T15:09:32.884518Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0xFc13Ebe7FEB9595D70195E9168aA7F3acE153621',
#     'implementation_name': None,
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
# ...
