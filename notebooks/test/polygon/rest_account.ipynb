# %%
from blockscout import Blockscout
from blockscout import TokenTransfers
from blockscout import Net
from blockscout import API

eth_rest = Blockscout(Net.MATIC, API.REST)

# %%
eth_rest.get_addresses()
# Out:
# url: https://polygon.blockscout.com/api/v2/addresses
# {'items': [{'coin_balance': '8577069734565831004933396996',
#    'tx_count': '25119',
#    'ens_domain_name': None,
#    'hash': '0x0000000000000000000000000000000000001010',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': True,
#    'is_verified': True,
#    'metadata': None,
#    'name': 'MRC20',
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '139374050176606783043332878',
#    'tx_count': '2847048',
#    'ens_domain_name': None,
#    'hash': '0x0d500B1d8E8eF31E21C99d1Db9A6444d3ADf1270',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': True,
#    'is_verified': True,
#    'metadata': None,
#    'name': 'WMATIC',
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '121193430628908732135506290',
#    'tx_count': '6689',
#    'ens_domain_name': None,
#    'hash': '0x4c569c1e541A19132AC893748E0ad54C7c989FF4',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '24232116636691760700931439',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x79B4fd4011A1C52D2233b24750A12ca5Eec2Cf38',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '18120233472864649899598458',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x71956a1Cd5a4233177F7Bf9a2d5778851e201934',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '12792810278020378141834650',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x68Bd76deeb37c239c5D6D57F50bf32257546f7f2',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '12000000991418299000002997',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0xfCbB9e5BB354B6F9fd40362Cee043F510dd3028D',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '10000007920000000000000000',
#    'tx_count': '4',
#    'ens_domain_name': None,
#    'hash': '0x0295CF3F55628eBF3F2Ed013356c8B83794E0a37',
#    'implementation_address': '0x3E5c63644E683549055b9Be8653de26E0B4CD36E',
#    'implementation_name': 'GnosisSafeL2',
#    'implementations': [{'address': '0x3E5c63644E683549055b9Be8653de26E0B4CD36E',
#      'name': 'GnosisSafeL2'}],
#    'is_contract': True,
#    'is_verified': True,
#    'metadata': None,
#    'name': 'GnosisSafeProxy',
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '10000000997961108238606706',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0xee5B5B923fFcE93A870B3104b7CA09c3db80047A',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '9589474819741576946320425',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x101bd2BCe771CcD8460279bC3E9472ba621305f1',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '7909514037345576362634006',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0xb8Cbbf78c7Ad1cDF4cA0e111B35491f3bFE027AC',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '7716954205515180315286825',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x7A8ed27F4C30512326878652d20fC85727401854',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '7121959734302089395396146',
#    'tx_count': '79558',
#    'ens_domain_name': None,
#    'hash': '0xe84F75FC9cAA49876d0Ba18d309da4231d44E94D',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '6876544851468617694357627',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x3D8FC1CFfAa110F7A7F9f8BC237B73d54C4aBf61',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '6322070808473456750965298',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0xD6216fC19DB775Df9774a6E33526131dA7D19a2c',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '6298975872282422953295103',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0xC882b111A75C0c657fC507C04FbFcD2cC984F071',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '5349733867376496176161000',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x4fdFE365436b5273a42F135C6a6244A20404271E',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '5345010000000200000000000',
#    'tx_count': '36',
#    'ens_domain_name': None,
#    'hash': '0xaC72565CcF186F10E6a7a3964492C62be5757E31',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': True,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '5060024539556010427962912',
#    'tx_count': '13096',
#    'ens_domain_name': None,
#    'hash': '0x576b81F0c21EDBc920ad63FeEEB2b0736b018A58',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '4889072310864200459782494',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0xD3d877fc323De661Ff9E1a38147A1AC679ce7C64',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '4615477110320302876297869',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0xF639d88a89384A4D97f2bA9159567Ddb3890Ea07',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '4595358508455886137538041',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0xc40D8d57b09300babe0682bD8b48be0Da16feB9C',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '4544306961743752029893000',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x86523c87c8ec98c7539e2c58Cd813eE9D1A08D96',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '4070566792595356787191962',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x77134cbC06cB00b66F4c7e623D5fdBF6777635EC',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '3999997617913018274842944',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x9a552417cfc942A5C88Ab474756d3D9962f917C0',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '3904492564571115976719905',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x6b0Ee0B1c553913F4585e9Ec5c60461eA16Fd20f',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '3697899102046249214947575',
#    'tx_count': '1647551',
#    'ens_domain_name': None,
#    'hash': '0xe7804c37c13166fF0b37F5aE0BB07A3aEbb6e245',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '3677687060073690327168026',
#    'tx_count': '2',
#    'ens_domain_name': None,
#    'hash': '0x7c7379531b2aEE82e4Ca06D4175D13b9CBEafd49',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '3284850175032162755793007',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x91Dca37856240E5e1906222ec79278b16420Dc92',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '3086676979324690615661998',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x3d66dd9C9cF2EE749F1fA743daD336b84254221f',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '3086189752930426178223796',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0xcb651E977EfDa911dDDAa46139eF03E5249a2581',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '2998555775126375208252476',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x5770815B0c2a09A43C9E5AEcb7e2f3886075B605',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '2996002006248024597587000',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x290708f233f5d95385Cd60efe7a1642b5ac53b8E',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '2787893073545749171509058',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x7EF2D7B88D43F1831241F0dD63E0bdeF048Ba8aC',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '2702430016175455567988682',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x417850c1Cd0fB428eb63649E9DC4C78edE9A34E8',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '2607353427713250675085538',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x507EecA0CAc579923FDc7723A092EEEaE137aDF8',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '2568509128327198863906845',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x57571d366a00B3389b0aDf30A114BC7DA7a11580',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '2568509126982270886039845',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0xb2230c37a5Df1D6563D5f2AbE1094726481e81d4',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '2509459045683295021555027',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x58e7D88446cd56bEC0e6051C1A58Ce1234eC6933',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '2489522218095455434130121',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x0639556F03714A74a5fEEaF5736a4A64fF70D206',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '2489406792092522027449730',
#    'tx_count': '343827',
#    'ens_domain_name': None,
#    'hash': '0x0D0707963952f2fBA59dD06f2b425ace40b492Fe',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '2470715674564024993067192',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x61712578CD8960fDe54CC91a7B7f3282e33676ee',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '2401603682551993948939324',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x7EdebF5cEdBbC6e97e98BAB2534FA02A1BA7A193',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '2397537561941906829596855',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0xA43c51aacae41AeC73e1EfF2d13D69eD13DE8DaB',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '2396036084953111136033834',
#    'tx_count': '31',
#    'ens_domain_name': None,
#    'hash': '0xf0c7dE14e228d620E388f73Fb144000f9BaE358d',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '2316951600000110000000000',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0xaEFfAB965b38aC8D4B7c571E8fa0d67BA5F084f8',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '2254834188228718278019170',
#    'tx_count': '14133',
#    'ens_domain_name': None,
#    'hash': '0xD5C08681719445A5Fdce2Bda98b341A49050d821',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '2196671645512613455849017',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x71dDc5EA37ede029b384c274aBfA7B7a05A9F40d',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '2163553311986384184638151',
#    'tx_count': '772790',
#    'ens_domain_name': None,
#    'hash': '0xf89d7b9c864f589bbF53a82105107622B35EaA40',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '2142184075122956753147153',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0xA435Afc08d5bC9E69b484363FaaB559Dc75255CF',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []}],
#  'total_supply': '0.0',
#  'exchange_rate': '0.496551',
#  'next_page_params': {'fetched_coin_balance': '2142184075122956753147153',
#   'hash': '0xa435afc08d5bc9e69b484363faab559dc75255cf',
#   'items_count': 50}}

# %%
eth_rest.get_coin_balance_history_by_day(address = '0x8A4AA176007196D48d39C89402d3753c39AE64c1')

# %%
#eth_rest.get_coin_balance_history(address = '0x8A4AA176007196D48d39C89402d3753c39AE64c1')

# %%
eth_rest.get_token_balances_with_filtering(address = '0x48023b16c3e81AA7F6eFFbdEB35Bb83f4f31a8fd')

# %%
eth_rest.get_token_balances(address = '0x8A4AA176007196D48d39C89402d3753c39AE64c1')

# %%
#eth_rest.get_blocks_validated(address = '0x4200000000000000000000000000000000000011')

# %%
#eth_rest.get_address_logs(address = '0x48023b16c3e81AA7F6eFFbdEB35Bb83f4f31a8fd')

# %%
#eth_rest.get_address_transactions(address = '0x8A4AA176007196D48d39C89402d3753c39AE64c1')

# %%
eth_rest.get_address_counters(address = '0x8A4AA176007196D48d39C89402d3753c39AE64c1')

# %%
eth_rest.get_address_info(address = '0x8A4AA176007196D48d39C89402d3753c39AE64c1')
