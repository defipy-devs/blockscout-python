# %% [markdown]
# * https://eth.blockscout.com

# %%
from blockscout import Blockscout
from blockscout import TokenTransfers
from blockscout import Net
from blockscout import API

vitalik_addr = '0xd8da6bf26964af9d7eed9e03e53415d37aa96045'
usdc_addr = '0x3c499c542cEF5E3811e1192ce70d8cC03d5c3359'

eth_rest = Blockscout(Net.MATIC, API.REST)

# %%
eth_rest.get_addresses()
# Out:
# url: https://polygon.blockscout.com/api/v2/addresses
# {'items': [{'coin_balance': '8577069733555831019063274758',
#    'tx_count': '25119',
#    'ens_domain_name': None,
#    'hash': '0x0000000000000000000000000000000000001010',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': True,
#    'is_verified': True,
#    'metadata': None,
#    'name': 'MRC20',
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '139549940965626390659986476',
#    'tx_count': '2847048',
#    'ens_domain_name': None,
#    'hash': '0x0d500B1d8E8eF31E21C99d1Db9A6444d3ADf1270',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': True,
#    'is_verified': True,
#    'metadata': None,
#    'name': 'WMATIC',
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '121193430628908732135506290',
#    'tx_count': '6689',
#    'ens_domain_name': None,
#    'hash': '0x4c569c1e541A19132AC893748E0ad54C7c989FF4',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '24245332626023760700931439',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x79B4fd4011A1C52D2233b24750A12ca5Eec2Cf38',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '18120233472864649899598458',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x71956a1Cd5a4233177F7Bf9a2d5778851e201934',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '12795513600079957085812794',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x68Bd76deeb37c239c5D6D57F50bf32257546f7f2',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '12000000991418299000002997',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0xfCbB9e5BB354B6F9fd40362Cee043F510dd3028D',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '10000007920000000000000000',
#    'tx_count': '4',
#    'ens_domain_name': None,
#    'hash': '0x0295CF3F55628eBF3F2Ed013356c8B83794E0a37',
#    'implementation_address': '0x3E5c63644E683549055b9Be8653de26E0B4CD36E',
#    'implementation_name': 'GnosisSafeL2',
#    'implementations': [{'address': '0x3E5c63644E683549055b9Be8653de26E0B4CD36E',
#      'name': 'GnosisSafeL2'}],
#    'is_contract': True,
#    'is_verified': True,
#    'metadata': None,
#    'name': 'GnosisSafeProxy',
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '10000000997961108238606706',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0xee5B5B923fFcE93A870B3104b7CA09c3db80047A',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '9589474819741576946320425',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x101bd2BCe771CcD8460279bC3E9472ba621305f1',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '7909514037345576362634006',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0xb8Cbbf78c7Ad1cDF4cA0e111B35491f3bFE027AC',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '7716954205515180315286825',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x7A8ed27F4C30512326878652d20fC85727401854',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '7284861477275354876036146',
#    'tx_count': '79558',
#    'ens_domain_name': None,
#    'hash': '0xe84F75FC9cAA49876d0Ba18d309da4231d44E94D',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '6876544850019321845191305',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x3D8FC1CFfAa110F7A7F9f8BC237B73d54C4aBf61',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '6322070808473456750965298',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0xD6216fC19DB775Df9774a6E33526131dA7D19a2c',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '6298975872282422953295103',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0xC882b111A75C0c657fC507C04FbFcD2cC984F071',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '5349733867376496176161000',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x4fdFE365436b5273a42F135C6a6244A20404271E',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '5345010000000200000000000',
#    'tx_count': '36',
#    'ens_domain_name': None,
#    'hash': '0xaC72565CcF186F10E6a7a3964492C62be5757E31',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': True,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '5064715655295931225239826',
#    'tx_count': '13096',
#    'ens_domain_name': None,
#    'hash': '0x576b81F0c21EDBc920ad63FeEEB2b0736b018A58',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '4889408657217215844150919',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0xD3d877fc323De661Ff9E1a38147A1AC679ce7C64',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '4615477110320302876297869',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0xF639d88a89384A4D97f2bA9159567Ddb3890Ea07',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '4595358508455886137538041',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0xc40D8d57b09300babe0682bD8b48be0Da16feB9C',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '4544306961743752029893000',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x86523c87c8ec98c7539e2c58Cd813eE9D1A08D96',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '4070936384425777785784752',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x77134cbC06cB00b66F4c7e623D5fdBF6777635EC',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '3999997617913018274842944',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x9a552417cfc942A5C88Ab474756d3D9962f917C0',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '3904492564571115976719905',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x6b0Ee0B1c553913F4585e9Ec5c60461eA16Fd20f',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '3686182233825411347089277',
#    'tx_count': '1647551',
#    'ens_domain_name': None,
#    'hash': '0xe7804c37c13166fF0b37F5aE0BB07A3aEbb6e245',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '3677687060073690327168026',
#    'tx_count': '2',
#    'ens_domain_name': None,
#    'hash': '0x7c7379531b2aEE82e4Ca06D4175D13b9CBEafd49',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '3284850175032162755793007',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x91Dca37856240E5e1906222ec79278b16420Dc92',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '3086676979324690615661998',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x3d66dd9C9cF2EE749F1fA743daD336b84254221f',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '3086189752930426178223796',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0xcb651E977EfDa911dDDAa46139eF03E5249a2581',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '3008932839465955130629488',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x5770815B0c2a09A43C9E5AEcb7e2f3886075B605',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '2996002006248024597587000',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x290708f233f5d95385Cd60efe7a1642b5ac53b8E',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '2791038105704932408533642',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x7EF2D7B88D43F1831241F0dD63E0bdeF048Ba8aC',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '2702430016175455567988682',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x417850c1Cd0fB428eb63649E9DC4C78edE9A34E8',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '2607353427713250675085538',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x507EecA0CAc579923FDc7723A092EEEaE137aDF8',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '2568509128327198863906845',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x57571d366a00B3389b0aDf30A114BC7DA7a11580',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '2568509126982270886039845',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0xb2230c37a5Df1D6563D5f2AbE1094726481e81d4',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '2495882709530454108408733',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x0639556F03714A74a5fEEaF5736a4A64fF70D206',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '2494129044924124020988027',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x58e7D88446cd56bEC0e6051C1A58Ce1234eC6933',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '2488007890075056053270419',
#    'tx_count': '343827',
#    'ens_domain_name': None,
#    'hash': '0x0D0707963952f2fBA59dD06f2b425ace40b492Fe',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '2470715674564024993067192',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x61712578CD8960fDe54CC91a7B7f3282e33676ee',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '2401603682551993948939324',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x7EdebF5cEdBbC6e97e98BAB2534FA02A1BA7A193',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '2397537561941906829596855',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0xA43c51aacae41AeC73e1EfF2d13D69eD13DE8DaB',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '2396036084953111136033834',
#    'tx_count': '31',
#    'ens_domain_name': None,
#    'hash': '0xf0c7dE14e228d620E388f73Fb144000f9BaE358d',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '2316951600000110000000000',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0xaEFfAB965b38aC8D4B7c571E8fa0d67BA5F084f8',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '2254667399896758275131826',
#    'tx_count': '14133',
#    'ens_domain_name': None,
#    'hash': '0xD5C08681719445A5Fdce2Bda98b341A49050d821',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '2196671645512613455849017',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x71dDc5EA37ede029b384c274aBfA7B7a05A9F40d',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '2142184075122956753147153',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0xA435Afc08d5bC9E69b484363FaaB559Dc75255CF',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '2138895839176058422850000',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0xd907a895b60CD8995F303EF53C86190ED8dA7c00',
#    'implementation_address': None,
#    'implementation_name': None,
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []}],
#  'total_supply': '0.0',
#  'exchange_rate': '0.499936',
#  'next_page_params': {'fetched_coin_balance': '2138895839176058422850000',
#   'hash': '0xd907a895b60cd8995f303ef53c86190ed8da7c00',
#   'items_count': 50}}

# %%
eth_rest.get_coin_balance_history_by_day(address = vitalik_addr)
# Out:
# url: https://polygon.blockscout.com/api/v2/addresses/0xd8da6bf26964af9d7eed9e03e53415d37aa96045/coin-balance-history-by-day
# {'items': [{'date': '2024-04-27', 'value': '453555716534783819563'},
#   {'date': '2024-04-28', 'value': '453555717634783819563'},
#   {'date': '2024-05-06', 'value': '453565717744783819563'},
#   {'date': '2024-05-13', 'value': '453565718844783819563'},
#   {'date': '2024-05-15', 'value': '453565718944783819563'},
#   {'date': '2024-05-18', 'value': '453565718945783819563'},
#   {'date': '2024-05-22', 'value': '460355093510342755709'},
#   {'date': '2024-05-23', 'value': '460355203510342755709'},
#   {'date': '2024-05-24', 'value': '460355203511342755709'},
#   {'date': '2024-05-25', 'value': '460356303511342755709'},
#   {'date': '2024-05-26', 'value': '460356403511342755709'},
#   {'date': '2024-05-27', 'value': '460356506511342755709'},
#   {'date': '2024-05-30', 'value': '460356507511342755709'},
#   {'date': '2024-06-04', 'value': '460367018611342755809'},
#   {'date': '2024-06-07', 'value': '460368119611342755809'},
#   {'date': '2024-06-08', 'value': '460368421611342755809'},
#   {'date': '2024-06-10', 'value': '460368523611342755809'},
#   {'date': '2024-06-14', 'value': '460368933711346755809'},
#   {'date': '2024-06-16', 'value': '460367868787346755809'},
#   {'date': '2024-06-18', 'value': '460630431175346755809'},
#   {'date': '2024-06-22', 'value': '460630631175346755809'},
#   {'date': '2024-06-24', 'value': '460632632185346755809'},
#   {'date': '2024-06-26', 'value': '460633333195346755809'},
#   {'date': '2024-06-28', 'value': '460633335195346755809'},
#   {'date': '2024-06-29', 'value': '460633435295346755809'},
#   {'date': '2024-07-02', 'value': '460633436295346755809'},
#   {'date': '2024-07-03', 'value': '460635436395346755809'},
#   {'date': '2024-07-04', 'value': '460636436495346755809'},
#   {'date': '2024-07-07', 'value': '460637447495346755809'},
#   {'date': '2024-07-10', 'value': '460637448595346755809'},
#   {'date': '2024-07-11', 'value': '460637449595346755809'},
#   {'date': '2024-07-14', 'value': '460637461595346755809'},
#   {'date': '2024-07-15', 'value': '460637462595346755809'},
#   {'date': '2024-07-16', 'value': '460637463895346755809'},
#   {'date': '2024-07-17', 'value': '460637463995346755809'},
#   {'date': '2024-07-18', 'value': '460637563995346755809'},
#   {'date': '2024-07-19', 'value': '460637565995346755809'},
#   {'date': '2024-07-20', 'value': '460637566995346755809'},
#   {'date': '2024-07-23', 'value': '460637567995346755809'},
#   {'date': '2024-07-24', 'value': '460637577995346755809'},
#   {'date': '2024-07-25', 'value': '460637577995346755809'}],
#  'days': 90}

# %%
eth_rest.get_coin_balance_history(address = vitalik_addr)
# Out:
# url: https://polygon.blockscout.com/api/v2/addresses/0xd8da6bf26964af9d7eed9e03e53415d37aa96045/coin-balance-history
# {'items': [{'block_number': 59762084,
#    'block_timestamp': '2024-07-24T19:03:17Z',
#    'delta': '10000000000000',
#    'transaction_hash': '0x37ce00c07a66bd5286fc10ba70ae68128c833edaf0796ced56e5c4392baa9a02',
#    'value': '460637577995346755809'},
#   {'block_number': 59713288,
#    'block_timestamp': '2024-07-23T12:58:29Z',
#    'delta': '1000000000000',
#    'transaction_hash': '0x3a09678af24a79d07da2719e9943c436a0cda4b4f2ed708dd1051422a7e6f375',
#    'value': '460637567995346755809'},
#   {'block_number': 59601838,
#    'block_timestamp': '2024-07-20T16:16:22Z',
#    'delta': '1000000000000',
#    'transaction_hash': '0xecdd9a2e71a263bfdade9326be0ef9874ab9df3bdc1874d103bbcd2779b83cc9',
#    'value': '460637566995346755809'},
#   {'block_number': 59547214,
#    'block_timestamp': '2024-07-19T06:36:01Z',
#    'delta': '2000000000000',
#    'transaction_hash': '0x43262d1d1b35d6145f179b9b71678f969ed90ddd444748094ef10fcda7cbc429',
#    'value': '460637565995346755809'},
#   {'block_number': 59499864,
#    'block_timestamp': '2024-07-18T01:24:43Z',
#    'delta': '100000000000000',
#    'transaction_hash': '0x3f6ab40f5eb6af5d44efb7993f549641e3f560220b2bb99d2024567df77cccec',
#    'value': '460637563995346755809'},
#   {'block_number': 59479836,
#    'block_timestamp': '2024-07-17T13:03:57Z',
#    'delta': '100000000000',
#    'transaction_hash': '0x87c7135241dc2fc8f5d020bd479a62baf6f9a186926780c8f8a3740dd3ebd226',
#    'value': '460637463995346755809'},
#   {'block_number': 59427166,
#    'block_timestamp': '2024-07-16T04:35:53Z',
#    'delta': '1300000000000',
#    'transaction_hash': '0xbd8c4af1a6e6488bd7c6f5a2761fb5470a3804508e1022d6a14698b6ba1198dd',
#    'value': '460637463895346755809'},
#   {'block_number': 59402418,
#    'block_timestamp': '2024-07-15T13:20:33Z',
#    'delta': '1000000000000',
#    'transaction_hash': '0xa6a2d458a90098e10a8f5b0bab27298ff2d2e84e66f2759e9a2c3e94920cfec2',
#    'value': '460637462595346755809'},
#   {'block_number': 59356989,
#    'block_timestamp': '2024-07-14T09:20:18Z',
#    'delta': '12000000000000',
#    'transaction_hash': '0x13a3a752613643c2d44e2c30f167baacab8dd30334b1714f21a76a3523d34cf7',
#    'value': '460637461595346755809'},
#   {'block_number': 59224215,
#    'block_timestamp': '2024-07-10T23:29:28Z',
#    'delta': '1000000000000',
#    'transaction_hash': '0x399477e0fdc24cb1aa141eb8dcb99fcc8c80d424490582838ef8d3c346486b4e',
#    'value': '460637449595346755809'},
#   {'block_number': 59183925,
#    'block_timestamp': '2024-07-09T22:39:17Z',
#    'delta': '1100000000000',
#    'transaction_hash': '0x5270bace7dea683a9f093edf1a3c5769eac0aa97dc536efea349f83533051245',
#    'value': '460637448595346755809'},
#   {'block_number': 59075419,
#    'block_timestamp': '2024-07-07T03:46:03Z',
#    'delta': '1011000000000000',
#    'transaction_hash': '0xa65dbb2614c926b26e0b9ff6e558182f9a87faaa24b99de9522cbefb5705e320',
#    'value': '460637447495346755809'},
#   {'block_number': 58963592,
#    'block_timestamp': '2024-07-04T06:49:59Z',
#    'delta': '100000000000',
#    'transaction_hash': '0x10f9167c7bb595dd6487976594f31163e384e0547649637f7303ab5c9b38e680',
#    'value': '460636436495346755809'},
#   {'block_number': 58932355,
#    'block_timestamp': '2024-07-03T11:34:38Z',
#    'delta': '1000000000000000',
#    'transaction_hash': '0x86992467112d148ea0f5c61c470d76a7a076189907843587f5dffdaee0202875',
#    'value': '460636436395346755809'},
#   {'block_number': 58910797,
#    'block_timestamp': '2024-07-02T22:17:17Z',
#    'delta': '100000000000',
#    'transaction_hash': '0xc2cf7773010854db5f49c175519375f0f5b709b05a7e9b5c4afab0c59d39d4d5',
#    'value': '460635436395346755809'},
#   {'block_number': 58890997,
#    'block_timestamp': '2024-07-02T10:04:57Z',
#    'delta': '2000000000000000',
#    'transaction_hash': '0xfc0d89a6c9af2ee858a266532c52b85b8b956eece90c8b996f852449b4ec0f6a',
#    'value': '460635436295346755809'},
#   {'block_number': 58873487,
#    'block_timestamp': '2024-07-01T23:17:19Z',
#    'delta': '1000000000000',
#    'transaction_hash': '0x71f22cb37bd9a0291979a3ce4322d63d06b895dd42313d4c935b1898bb4b7f33',
#    'value': '460633436295346755809'},
#   {'block_number': 58761476,
#    'block_timestamp': '2024-06-29T02:14:27Z',
#    'delta': '100100000000000',
#    'transaction_hash': '0x78d18b086ddb0b8baeb29fddd9a6c23fa3bef0f29f5b057761a1a09c095eea09',
#    'value': '460633435295346755809'},
#   {'block_number': 58707097,
#    'block_timestamp': '2024-06-27T16:43:10Z',
#    'delta': '2000000000000',
#    'transaction_hash': '0xeb90e38e65c3f07748d457c7892472ad1bba2e01293fd791b18e017d86a126e4',
#    'value': '460633335195346755809'},
#   {'block_number': 58621551,
#    'block_timestamp': '2024-06-25T11:59:08Z',
#    'delta': '10000000000000',
#    'transaction_hash': '0x9711a5ab7c739bc543adf8b20c393b0d6a91a480dca840e74bc85e001aa21f31',
#    'value': '460633333195346755809'},
#   {'block_number': 58612197,
#    'block_timestamp': '2024-06-25T06:13:10Z',
#    'delta': '691010000000000',
#    'transaction_hash': '0x41ff939f33f2f3dbedad2d387d864c3e2d371425ae2c2e52d6fcbcfae7c5c165',
#    'value': '460633323195346755809'},
#   {'block_number': 58549157,
#    'block_timestamp': '2024-06-23T15:21:33Z',
#    'delta': '2001010000000000',
#    'transaction_hash': '0x71e1c3f34b101ca2122f272b737a4a0ac53d3f33ca2d3bf6a830d6b86f5df9c4',
#    'value': '460632632185346755809'},
#   {'block_number': 58473014,
#    'block_timestamp': '2024-06-21T16:25:18Z',
#    'delta': '200000000000000',
#    'transaction_hash': '0x870e46b22f6c356bfb44d68169c37fa678bede73c5e0a457af42182a96ceb4b0',
#    'value': '460630631175346755809'},
#   {'block_number': 58319159,
#    'block_timestamp': '2024-06-17T17:34:46Z',
#    'delta': '262562388000000000',
#    'transaction_hash': '0xed04d174b382f31ebe5983d72927dbbe2c9a280d9fa178b73b7cc67d1d312d39',
#    'value': '460630431175346755809'},
#   {'block_number': 58217833,
#    'block_timestamp': '2024-06-15T03:07:05Z',
#    'delta': '1000000000000000',
#    'transaction_hash': '0x79f1c996ddbd2cdee673807d002c5e9d6cd869edc24ec6923a6a9be616aa7e48',
#    'value': '460367868787346755809'},
#   {'block_number': 58151152,
#    'block_timestamp': '2024-06-13T10:00:48Z',
#    'delta': '-2064924000000000',
#    'transaction_hash': '0x126377c17aca6f4d7900cb85064e0e656cdf3853db1305104a0d6460101ee347',
#    'value': '460366868787346755809'},
#   {'block_number': 58143897,
#    'block_timestamp': '2024-06-13T05:32:28Z',
#    'delta': '410100004000000',
#    'transaction_hash': '0xb486bca852ff8935bdc8c8ed0a098f9c67f626f1d3bcd7808ea5622197a68b72',
#    'value': '460368933711346755809'},
#   {'block_number': 57994904,
#    'block_timestamp': '2024-06-09T09:41:45Z',
#    'delta': '102000000000000',
#    'transaction_hash': '0xe47c2a761e2931140411e390d7545653a06130dd25362c967b991a3c7697a42e',
#    'value': '460368523611342755809'},
#   {'block_number': 57918409,
#    'block_timestamp': '2024-06-07T10:32:29Z',
#    'delta': '302000000000000',
#    'transaction_hash': '0x5ec6ed51a91de09c101e4f0084531a394d66644d8d8dc2d368d65d11183b205c',
#    'value': '460368421611342755809'},
#   {'block_number': 57861021,
#    'block_timestamp': '2024-06-05T23:09:55Z',
#    'delta': '1101000000000000',
#    'transaction_hash': '0xcf70d511a964b295bdd324da3c467b9be598e01d3a4313738dbd38781157e802',
#    'value': '460368119611342755809'},
#   {'block_number': 57751968,
#    'block_timestamp': '2024-06-03T03:56:27Z',
#    'delta': '10511100000000100',
#    'transaction_hash': '0x9dbc9e8b7a68e40e4253fc20adf0b39b08aee4a1a3232d3c0026a49328f8575c',
#    'value': '460367018611342755809'},
#   {'block_number': 57548897,
#    'block_timestamp': '2024-05-28T22:45:35Z',
#    'delta': '1000000000000',
#    'transaction_hash': '0xf15d035d11b60fa11bd1db142423f15c9d704217ace8e27906a94e6db6a6ff4f',
#    'value': '460356507511342755709'},
#   {'block_number': 57446029,
#    'block_timestamp': '2024-05-26T07:20:53Z',
#    'delta': '103000000000000',
#    'transaction_hash': '0x1cbb35f7431ed4f4ce8b35aeb62d5b6edff03cb13563b7053c7342a2cc01b9ae',
#    'value': '460356506511342755709'},
#   {'block_number': 57399028,
#    'block_timestamp': '2024-05-25T02:22:29Z',
#    'delta': '100000000000000',
#    'transaction_hash': '0x44191b13817df2d038634a4e96514bbd02fee550a98fd069265bfd08e876c060',
#    'value': '460356403511342755709'},
#   {'block_number': 57384189,
#    'block_timestamp': '2024-05-24T17:13:39Z',
#    'delta': '1100000000000000',
#    'transaction_hash': '0xa4a8dd755ebd2968a6262164510e006c863c831a9a950e6e64b5a8f5c1c066c3',
#    'value': '460356303511342755709'},
#   {'block_number': 57325167,
#    'block_timestamp': '2024-05-23T04:50:38Z',
#    'delta': '1000000000',
#    'transaction_hash': '0x2c4819f1773518509c5244af1372ccf47a58700f83a22ae980913d48f71b1ffa',
#    'value': '460355203511342755709'},
#   {'block_number': 57308035,
#    'block_timestamp': '2024-05-22T18:16:59Z',
#    'delta': '110000000000000',
#    'transaction_hash': '0xcf65eae0feba8d5019fa2e5f785d24a097d74168c9dd66ff50a5dcb73ce656fe',
#    'value': '460355203510342755709'},
#   {'block_number': 57265200,
#    'block_timestamp': '2024-05-21T15:52:41Z',
#    'delta': '6789374564558936146',
#    'transaction_hash': '0xe1de396c25f60f3e8ee0015c8686473279a066a1682f3c36ea80bf2650b9bf3c',
#    'value': '460355093510342755709'},
#   {'block_number': 57091335,
#    'block_timestamp': '2024-05-17T04:42:03Z',
#    'delta': '1000000000',
#    'transaction_hash': '0xacfc5083c9e9486f6e6fa740160b6eedc44e8483b49fc8ccd99b1b9ed240d2b7',
#    'value': '453565718945783819563'},
#   {'block_number': 57011976,
#    'block_timestamp': '2024-05-15T03:46:51Z',
#    'delta': '100000000000',
#    'transaction_hash': '0x97b3a095f833dfdf38becb0cfeb907ad2d4496e7d8b1919793e63c25e93418b8',
#    'value': '453565718944783819563'},
#   {'block_number': 56902293,
#    'block_timestamp': '2024-05-12T08:10:04Z',
#    'delta': '1100000000000',
#    'transaction_hash': '0xce3d5f04f795c166c842c90a66ba99091ca94155449546062500d576c54f2288',
#    'value': '453565718844783819563'},
#   {'block_number': 56646590,
#    'block_timestamp': '2024-05-05T18:32:33Z',
#    'delta': '10000110000000000',
#    'transaction_hash': '0x6eb3c0c945dc39ea6dd931645a5de378570d34ee1e7f5f4ca08c2d270f960b73',
#    'value': '453565717744783819563'},
#   {'block_number': 56350996,
#    'block_timestamp': '2024-04-28T04:19:37Z',
#    'delta': '1100000000000',
#    'transaction_hash': '0x012e25933ae0a162489ab779c907f81e0df0b3597f76c8b309f96d626fdc4562',
#    'value': '453555717634783819563'},
#   {'block_number': 56294456,
#    'block_timestamp': '2024-04-26T17:28:24Z',
#    'delta': '10000000000',
#    'transaction_hash': '0x9f299bd3835e221ce41d2c3787edecf2612ff7aa6b59904a372df57e42e99166',
#    'value': '453555716534783819563'},
#   {'block_number': 56239455,
#    'block_timestamp': '2024-04-25T07:34:07Z',
#    'delta': '10000000000',
#    'transaction_hash': '0xa1a91d6c92c3fd58a9e34600588c3171c9be2c9b9fb0b13e3e084e5f24722040',
#    'value': '453555716524783819563'},
#   {'block_number': 56202892,
#    'block_timestamp': '2024-04-24T09:01:47Z',
#    'delta': '10000000000',
#    'transaction_hash': '0x5a29091174a358b6664f24700e686f4563bee559b08a442a2aaa178fa543e139',
#    'value': '453555716514783819563'},
#   {'block_number': 56163872,
#    'block_timestamp': '2024-04-23T08:58:35Z',
#    'delta': '10000000000',
#    'transaction_hash': '0xdcd4c0fb9191f82fa3a0e8617f039f9b3340d05e40a370076f380d4ef4d05280',
#    'value': '453555716504783819563'},
#   {'block_number': 56145094,
#    'block_timestamp': '2024-04-22T21:24:03Z',
#    'delta': '1000000000000',
#    'transaction_hash': '0x860d8f8f862f2c3eda4c19671df45f47ac9bb9973417d1e0f17b296b3d478e37',
#    'value': '453555716494783819563'},
#   {'block_number': 56031994,
#    'block_timestamp': '2024-04-19T23:40:54Z',
#    'delta': '10000000000000',
#    'transaction_hash': '0x73ff53b4e74c259bd2a488dc0e339d373b60957f4c3825e21b27d1bfa7b83403',
#    'value': '453555715494783819563'},
#   {'block_number': 56026301,
#    'block_timestamp': '2024-04-19T20:10:20Z',
#    'delta': '10000000000000',
#    'transaction_hash': '0xc3d4af24d5d9cb24e97c6db3de6c9a7d46d661c851a01c2b20e69bdb327a2a31',
#    'value': '453555705494783819563'}],
#  'next_page_params': {'block_number': 56026301, 'items_count': 50}}

# %%
eth_rest.get_token_balances_with_filtering(address = vitalik_addr)
# Out:
# url: https://polygon.blockscout.com/api/v2/addresses/0xd8da6bf26964af9d7eed9e03e53415d37aa96045/tokens/?/type=ERC-20%2CERC-721%2CERC-1155
# {'items': [{'token': {'address': '0xE261D618a959aFfFd53168Cd07D12E37B26761db',
#     'circulating_market_cap': '46582106.82541228',
#     'decimals': '18',
#     'exchange_rate': '0.201306',
#     'holders': '33381',
#     'icon_url': 'https://assets.coingecko.com/coins/images/28383/small/Token_Logo.png?1696527383',
#     'name': 'Dimo',
#     'symbol': 'DIMO',
#     'total_supply': '845904752489865044171520438',
#     'type': 'ERC-20',
#     'volume_24h': '1420615.3345673021'},
#    'token_id': None,
#    'token_instance': None,
#    'value': '1193347651590009975420'},
#   {'token': {'address': '0x086373fad3447F7F86252fb59d56107e9E0FaaFa',
#     'circulating_market_cap': '1999995.7441932263',
#     'decimals': '18',
#     'exchange_rate': '0.04596468',
#     'holders': '16578',
#     'icon_url': 'https://assets.coingecko.com/coins/images/12322/small/photo_2021-10-26_00-47-35.jpg?1696512151',
#     'name': 'Yup',
#     'symbol': 'YUP',
#     'total_supply': '27322946159650606619770518',
#     'type': 'ERC-20',
#     'volume_24h': '75953.24347406797'},
#    'token_id': None,
#    'token_instance': None,
#    'value': '3773689166196425000000'},
#   {'token': {'address': '0x3d2bD0e15829AA5C362a4144FdF4A1112fa29B5c',
#     'circulating_market_cap': '2042448.4854914919',
#     'decimals': '18',
#     'exchange_rate': '0.00736184',
#     'holders': '34328',
#     'icon_url': 'https://assets.coingecko.com/coins/images/35884/small/Bonsai_BW_Coingecko-200x200.jpg?1710071621',
#     'name': 'Bonsai Token',
#     'symbol': 'BONSAI',
#     'total_supply': '1000000000000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': '1401.693774174597'},
#    'token_id': None,
#    'token_instance': None,
#    'value': '15841468500000000000000'},
#   {'token': {'address': '0x7ceB23fD6bC0adD59E62ac25578270cFf1b9f619',
#     'circulating_market_cap': '0.0',
#     'decimals': '18',
#     'exchange_rate': '3179.58',
#     'holders': '478814',
#     'icon_url': 'https://assets.coingecko.com/coins/images/2518/small/weth.png?1696503332',
#     'name': 'Wrapped Ether',
#     'symbol': 'WETH',
#     'total_supply': '153286315952157847451515',
#     'type': 'ERC-20',
#     'volume_24h': '2911036436.777449'},
#    'token_id': None,
#    'token_instance': None,
#    'value': '22652492040102743'},
#   {'token': {'address': '0x2791Bca1f2de4661ED88A30C99A7a9449Aa84174',
#     'circulating_market_cap': '0.0',
#     'decimals': '6',
#     'exchange_rate': '1.0',
#     'holders': '601193',
#     'icon_url': 'https://assets.coingecko.com/coins/images/33000/small/usdc.png?1700119918',
#     'name': 'USD Coin (PoS)',
#     'symbol': 'USDC',
#     'total_supply': '317480737390318',
#     'type': 'ERC-20',
#     'volume_24h': '32354573.231947396'},
#    'token_id': None,
#    'token_instance': None,
#    'value': '70052053'},
#   {'token': {'address': '0xc2132D05D31c914a87C6611C10748AEb04B58e8F',
#     'circulating_market_cap': '0.0',
#     'decimals': '6',
#     'exchange_rate': '0.999837',
#     'holders': '1953944',
#     'icon_url': 'https://assets.coingecko.com/coins/images/35023/small/USDT.png?1707233644',
#     'name': '(PoS) Tether USD',
#     'symbol': 'USDT',
#     'total_supply': '914353050222252',
#     'type': 'ERC-20',
#     'volume_24h': '22046112.079760145'},
#    'token_id': None,
#    'token_instance': None,
#    'value': '68264994'},
#   {'token': {'address': '0x8b78927048de67b9e8c8F834359F15C3822eD871',
#     'circulating_market_cap': '1023102.4907590421',
#     'decimals': '18',
#     'exchange_rate': '0.04521027',
#     'holders': '3630',
#     'icon_url': 'https://assets.coingecko.com/coins/images/27247/small/CG_final_.png?1715370599',
#     'name': 'LegendsOfElysium',
#     'symbol': 'LOE',
#     'total_supply': '200000000000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': '188516.0722109734'},
#    'token_id': None,
#    'token_instance': None,
#    'value': '289790252851101550479'},
#   {'token': {'address': '0x282d8efCe846A88B159800bd4130ad77443Fa1A1',
#     'circulating_market_cap': '216630395.3032223',
#     'decimals': '18',
#     'exchange_rate': '0.522423',
#     'holders': '2528',
#     'icon_url': 'https://assets.coingecko.com/coins/images/3687/small/ocean-protocol-logo.jpg?1696504363',
#     'name': 'Ocean Token (PoS)',
#     'symbol': 'mOCEAN',
#     'total_supply': '4411425456214003400193736',
#     'type': 'ERC-20',
#     'volume_24h': '1042250.8012941699'},
#    'token_id': None,
#    'token_instance': None,
#    'value': '11021000000000000000'},
#   {'token': {'address': '0x8f3Cf7ad23Cd3CaDbD9735AFf958023239c6A063',
#     'circulating_market_cap': '5275394370.9316435',
#     'decimals': '18',
#     'exchange_rate': '1.0',
#     'holders': '484555',
#     'icon_url': 'https://assets.coingecko.com/coins/images/9956/small/Badge_Dai.png?1696509996',
#     'name': '(PoS) Dai Stablecoin',
#     'symbol': 'DAI',
#     'total_supply': '192414466470640189582583535',
#     'type': 'ERC-20',
#     'volume_24h': '238135798.9494718'},
#    'token_id': None,
#    'token_instance': None,
#    'value': '5399228034446809996'},
#   {'token': {'address': '0x1a763170B96F23f15576D0fa0b2619d1254c437d',
#     'circulating_market_cap': '837248.6979147041',
#     'decimals': '18',
#     'exchange_rate': '0.293371',
#     'holders': '370',
#     'icon_url': 'https://assets.coingecko.com/coins/images/27871/small/AurusX_token_2D.jpg?1696526889',
#     'name': 'AurusX',
#     'symbol': 'AX',
#     'total_supply': '16995890923040157677945815',
#     'type': 'ERC-20',
#     'volume_24h': '86191.76801306887'},
#    'token_id': None,
#    'token_instance': None,
#    'value': '12000000000000000000'},
#   {'token': {'address': '0x172370d5Cd63279eFa6d502DAB29171933a610AF',
#     'circulating_market_cap': '300576523.7639606',
#     'decimals': '18',
#     'exchange_rate': '0.252497',
#     'holders': '10983',
#     'icon_url': 'https://assets.coingecko.com/coins/images/12124/small/Curve.png?1696511967',
#     'name': 'CRV (PoS)',
#     'symbol': 'CRV',
#     'total_supply': '10224301177832352844859771',
#     'type': 'ERC-20',
#     'volume_24h': '96672191.10756099'},
#    'token_id': None,
#    'token_instance': None,
#    'value': '13389845161345744334'},
#   {'token': {'address': '0x1BFD67037B42Cf73acF2047067bd4F2C47D9BfD6',
#     'circulating_market_cap': '10130787255.65223',
#     'decimals': '8',
#     'exchange_rate': '65562',
#     'holders': '89085',
#     'icon_url': 'https://assets.coingecko.com/coins/images/7598/small/wrapped_bitcoin_wbtc.png?1696507857',
#     'name': '(PoS) Wrapped BTC',
#     'symbol': 'WBTC',
#     'total_supply': '425197148600',
#     'type': 'ERC-20',
#     'volume_24h': '610511438.0214272'},
#    'token_id': None,
#    'token_instance': None,
#    'value': '4917'},
#   {'token': {'address': '0xd566C529B33ECF15170F600d4B1aB12468c8efC6',
#     'circulating_market_cap': '0.0',
#     'decimals': '18',
#     'exchange_rate': '0.00111674',
#     'holders': '489',
#     'icon_url': 'https://assets.coingecko.com/coins/images/29388/small/Avatar512.png?1696528334',
#     'name': 'UERII (PoS)',
#     'symbol': 'UERII',
#     'total_supply': '345482427152408761591689212',
#     'type': 'ERC-20',
#     'volume_24h': '2035.3582335589226'},
#    'token_id': None,
#    'token_instance': None,
#    'value': '2400000000000000000000'},
#   {'token': {'address': '0x0d500B1d8E8eF31E21C99d1Db9A6444d3ADf1270',
#     'circulating_market_cap': '0.0',
#     'decimals': '18',
#     'exchange_rate': '0.493271',
#     'holders': '171881',
#     'icon_url': 'https://assets.coingecko.com/coins/images/14073/small/matic.png?1696513797',
#     'name': 'Wrapped Matic',
#     'symbol': 'WMATIC',
#     'total_supply': '139552955265815446973842122',
#     'type': 'ERC-20',
#     'volume_24h': '34340837.29764731'},
#    'token_id': None,
#    'token_instance': None,
#    'value': '3002100000000000000'},
#   {'token': {'address': '0x831753DD7087CaC61aB5644b308642cc1c33Dc13',
#     'circulating_market_cap': '28132307.664106626',
#     'decimals': '18',
#     'exchange_rate': '39.11',
#     'holders': '4968',
#     'icon_url': 'https://assets.coingecko.com/coins/images/13970/small/quick.png?1696513704',
#     'name': 'Quickswap',
#     'symbol': 'QUICK',
#     'total_supply': '953652935082369796563243',
#     'type': 'ERC-20',
#     'volume_24h': '19340.321674171133'},
#    'token_id': None,
#    'token_instance': None,
#    'value': '32834780686012659'},
#   {'token': {'address': '0xE238Ecb42C424E877652AD82d8A939183A04C35f',
#     'circulating_market_cap': '12340658.398634095',
#     'decimals': '18',
#     'exchange_rate': '0.03999958',
#     'holders': '5730',
#     'icon_url': 'https://assets.coingecko.com/coins/images/29533/small/IMG_4643.png?1696528475',
#     'name': 'WiFi Map',
#     'symbol': 'WIFI',
#     'total_supply': '1000000000000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': '569301.1770607141'},
#    'token_id': None,
#    'token_instance': None,
#    'value': '15000000000000000000'},
#   {'token': {'address': '0x04565fE9AA3ae571ada8e1bEBF8282C4e5247b2A',
#     'circulating_market_cap': '853655.8582348954',
#     'decimals': '6',
#     'exchange_rate': '0.00004743',
#     'holders': '704214',
#     'icon_url': 'https://assets.coingecko.com/coins/images/37966/small/COIN_200x200.png?1716778831',
#     'name': 'Wild Goat Coin',
#     'symbol': 'WGC',
#     'total_supply': '1652229627317194',
#     'type': 'ERC-20',
#     'volume_24h': '6639.439589096716'},
#    'token_id': None,
#    'token_instance': None,
#    'value': '11835767971'},
#   {'token': {'address': '0x0Da0BD2f57A27A70665D53db4eA71E1f26F77a46',
#     'circulating_market_cap': '0.0',
#     'decimals': '18',
#     'exchange_rate': '0.374356',
#     'holders': '71',
#     'icon_url': 'https://assets.coingecko.com/coins/images/35306/small/CROW_IMG.jpeg?1708156194',
#     'name': 'Cropto Wheat Token',
#     'symbol': 'CROW',
#     'total_supply': '376550902712997945220739',
#     'type': 'ERC-20',
#     'volume_24h': '6008.156207469476'},
#    'token_id': None,
#    'token_instance': None,
#    'value': '1000000000000000000'},
#   {'token': {'address': '0xD8513c22Dd61161ba3872859A6D10eB1612Df742',
#     'circulating_market_cap': '159976.94944723492',
#     'decimals': '18',
#     'exchange_rate': '0.00705867',
#     'holders': '2940',
#     'icon_url': 'https://assets.coingecko.com/coins/images/34006/small/Surfboard_logo.png?1703618759',
#     'name': 'SurfBoard',
#     'symbol': 'BOARD',
#     'total_supply': '500000000000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': '115974.67143811994'},
#    'token_id': None,
#    'token_instance': None,
#    'value': '17000000000000000000'},
#   {'token': {'address': '0x1aDCef5c780d8895AC77E6Ee9239B4b3eCb76DA2',
#     'circulating_market_cap': '0.0',
#     'decimals': '6',
#     'exchange_rate': '0.00117555',
#     'holders': '16686',
#     'icon_url': 'https://assets.coingecko.com/coins/images/25056/small/C6_miUEU_400x400.jpg?1696524207',
#     'name': 'TOTEM',
#     'symbol': 'TOTEM',
#     'total_supply': '139298798856360',
#     'type': 'ERC-20',
#     'volume_24h': '1629.4535923934698'},
#    'token_id': None,
#    'token_instance': None,
#    'value': '100000000'},
#   {'token': {'address': '0x3c499c542cEF5E3811e1192ce70d8cC03d5c3359',
#     'circulating_market_cap': '33806257445.160835',
#     'decimals': '6',
#     'exchange_rate': '0.999755',
#     'holders': '564888',
#     'icon_url': 'https://assets.coingecko.com/coins/images/6319/small/usdc.png?1696506694',
#     'name': 'USD Coin',
#     'symbol': 'USDC',
#     'total_supply': '390808855866960',
#     'type': 'ERC-20',
#     'volume_24h': '9318673255.556795'},
#    'token_id': None,
#    'token_instance': None,
#    'value': '111181'},
#   {'token': {'address': '0xbFc70507384047Aa74c29Cdc8c5Cb88D0f7213AC',
#     'circulating_market_cap': '67674439.36025122',
#     'decimals': '18',
#     'exchange_rate': '0.01094916',
#     'holders': '3224',
#     'icon_url': 'https://assets.coingecko.com/coins/images/22062/small/Logo_Circle_720_%281%29.png?1696521405',
#     'name': 'Artificial Liquid Intelligence Token',
#     'symbol': 'ALI',
#     'total_supply': '115326209925972270658362252',
#     'type': 'ERC-20',
#     'volume_24h': '1205121.569099236'},
#    'token_id': None,
#    'token_instance': None,
#    'value': '7000000000000000000'},
#   {'token': {'address': '0xE313bcB77dbA15F39Ff0B9cEABe140cedD0953cB',
#     'circulating_market_cap': '0.0',
#     'decimals': '9',
#     'exchange_rate': '0.0009246',
#     'holders': '2202',
#     'icon_url': 'https://assets.coingecko.com/coins/images/33771/small/Jugnipfp_v1.png?1702969196',
#     'name': 'Jugni',
#     'symbol': 'JUGNI',
#     'total_supply': '100000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': '6.734388923531349'},
#    'token_id': None,
#    'token_instance': None,
#    'value': '64000000000'},
#   {'token': {'address': '0x0052074d3eB1429F39E5eA529b54a650C21F5AA4',
#     'circulating_market_cap': '0.0',
#     'decimals': '18',
#     'exchange_rate': '1.35',
#     'holders': '6000',
#     'icon_url': 'https://assets.coingecko.com/coins/images/38433/small/Frame_427319491.png?1717535375',
#     'name': 'RetaStake',
#     'symbol': 'RTK',
#     'total_supply': '200000000000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': '46905.66305594992'},
#    'token_id': None,
#    'token_instance': None,
#    'value': '34696300000000000'},
#   {'token': {'address': '0xDD75542611D57C4b6e68168B14C3591C539022eD',
#     'circulating_market_cap': '66416538.33050711',
#     'decimals': '18',
#     'exchange_rate': '0.096279',
#     'holders': '20978',
#     'icon_url': 'https://assets.coingecko.com/coins/images/14830/small/logo128px.png?1700169101',
#     'name': 'ZEN Exchange Token',
#     'symbol': 'pZCX',
#     'total_supply': '103785933571866845204295177',
#     'type': 'ERC-20',
#     'volume_24h': '3576319.6552229677'},
#    'token_id': None,
#    'token_instance': None,
#    'value': '311000000000000000'},
#   {'token': {'address': '0x655304E9Cc103b47f0afa0825767D6cCe426717C',
#     'circulating_market_cap': '0.0',
#     'decimals': '18',
#     'exchange_rate': '0.01084361',
#     'holders': '69961',
#     'icon_url': 'https://assets.coingecko.com/coins/images/34301/small/200.png?1717626581',
#     'name': 'OSSChain',
#     'symbol': 'OSS',
#     'total_supply': '11700000000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': '16.19533807281165'},
#    'token_id': None,
#    'token_instance': None,
#    'value': '2143434764261732000'},
#   {'token': {'address': '0x4A506181f07Da5ddFDA4ca4c2Fa4c67001dB94B4',
#     'circulating_market_cap': '0.0',
#     'decimals': '18',
#     'exchange_rate': '0.00010996',
#     'holders': '23541',
#     'icon_url': 'https://assets.coingecko.com/coins/images/32550/small/Dyl-pfp-200x.png?1698479973',
#     'name': 'Dyl',
#     'symbol': 'Dyl',
#     'total_supply': '85321563845918687521647559',
#     'type': 'ERC-20',
#     'volume_24h': '6535.554040375757'},
#    'token_id': None,
#    'token_instance': None,
#    'value': '138000000000000000000'},
#   {'token': {'address': '0x229b1b6C23ff8953D663C4cBB519717e323a0a84',
#     'circulating_market_cap': '0.0',
#     'decimals': '18',
#     'exchange_rate': '0.00090752',
#     'holders': '14892',
#     'icon_url': 'https://assets.coingecko.com/coins/images/18819/small/logo-bholdus-6.png?1696518281',
#     'name': 'BLOK',
#     'symbol': 'BLOK',
#     'total_supply': '200000000000000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': '1701371.9582517887'},
#    'token_id': None,
#    'token_instance': None,
#    'value': '11000000000000000000'},
#   {'token': {'address': '0xD86b5923F3AD7b585eD81B448170ae026c65ae9a',
#     'circulating_market_cap': '0.0',
#     'decimals': '18',
#     'exchange_rate': '0.00020235',
#     'holders': '44890',
#     'icon_url': 'https://assets.coingecko.com/coins/images/14588/small/logo_-_2021-03-31T123525.615.png?1696514268',
#     'name': 'IRON Stablecoin',
#     'symbol': 'IRON',
#     'total_supply': '52544639570842074728224974',
#     'type': 'ERC-20',
#     'volume_24h': '1.0381341552542782'},
#    'token_id': None,
#    'token_instance': None,
#    'value': '40000000000000000000'},
#   {'token': {'address': '0x9CA6a77C8B38159fd2dA9Bd25bc3E259C33F5E39',
#     'circulating_market_cap': '0.0',
#     'decimals': '18',
#     'exchange_rate': '0.00544415',
#     'holders': '15303',
#     'icon_url': 'https://assets.coingecko.com/coins/images/23358/small/sporkdao.PNG?1696522573',
#     'name': 'The SporkDAO Token (PoS)',
#     'symbol': 'SPORK',
#     'total_supply': '262296261053534968307635434',
#     'type': 'ERC-20',
#     'volume_24h': '25.53441980160622'},
#    'token_id': None,
#    'token_instance': None,
#    'value': '1000000000000000000'},
#   {'token': {'address': '0xbA777aE3a3C91fCD83EF85bfe65410592Bdd0f7c',
#     'circulating_market_cap': '752184.2865780968',
#     'decimals': '18',
#     'exchange_rate': '0.00000127',
#     'holders': '4801',
#     'icon_url': 'https://assets.coingecko.com/coins/images/32278/small/BitCone_Logo_V7.5_halo_NO_circle_-200x200_copy_BIGGER.png?1697180757',
#     'name': 'BitCone',
#     'symbol': 'CONE',
#     'total_supply': '608000000000000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': '13509.440154504036'},
#    'token_id': None,
#    'token_instance': None,
#    'value': '2663000000000000000000'},
#   {'token': {'address': '0x18e73A5333984549484348A94f4D219f4faB7b81',
#     'circulating_market_cap': '191356.93583133304',
#     'decimals': '8',
#     'exchange_rate': '0.00383105',
#     'holders': '1349',
#     'icon_url': 'https://assets.coingecko.com/coins/images/27630/small/duckies_logo.png?1706528164',
#     'name': 'Yellow Duckies',
#     'symbol': 'DUCKIES',
#     'total_supply': '14770000000000000',
#     'type': 'ERC-20',
#     'volume_24h': '36.75757770802036'},
#    'token_id': None,
#    'token_instance': None,
#    'value': '79977606'},
#   {'token': {'address': '0x6863BD30C9e313B264657B107352bA246F8Af8e0',
#     'circulating_market_cap': '715186.9812823529',
#     'decimals': '18',
#     'exchange_rate': '0.050954',
#     'holders': '87',
#     'icon_url': 'https://assets.coingecko.com/coins/images/15887/small/uyO7dQzR_400x400.jpg?1696515502',
#     'name': 'BlackPool Token (PoS)',
#     'symbol': 'BPT',
#     'total_supply': '395127899796051776753900',
#     'type': 'ERC-20',
#     'volume_24h': '49.963096600024116'},
#    'token_id': None,
#    'token_instance': None,
#    'value': '57612135366384149'},
#   {'token': {'address': '0xe9bC9AD74CCa887Aff32ba09a121B1256fC9f052',
#     'circulating_market_cap': '3904577.9608476995',
#     'decimals': '18',
#     'exchange_rate': '0.0000013',
#     'holders': '507551',
#     'icon_url': 'https://assets.coingecko.com/coins/images/35425/small/pigcoin_200.png?1708544734',
#     'name': 'Pigcoin',
#     'symbol': 'PIG',
#     'total_supply': '3000000000000000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': '48804.41425847263'},
#    'token_id': None,
#    'token_instance': None,
#    'value': '180880000000000000000'},
#   {'token': {'address': '0xED88227296943857409A8e0f15Ad7134e70D0F73',
#     'circulating_market_cap': '0.0',
#     'decimals': '18',
#     'exchange_rate': '0.00019687',
#     'holders': '54',
#     'icon_url': 'https://assets.coingecko.com/coins/images/27424/small/lumiii-icon-200x200.png?1696526465',
#     'name': 'LumiiiToken',
#     'symbol': 'LUMIII',
#     'total_supply': '10000000000000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': '4.2459451291034815'},
#    'token_id': None,
#    'token_instance': None,
#    'value': '544980104153599521'},
#   {'token': {'address': '0x382586651f043cBdEc7bb586e367D77B26D7d149',
#     'circulating_market_cap': '0.0',
#     'decimals': '6',
#     'exchange_rate': '9.349E-9',
#     'holders': '887665',
#     'icon_url': 'https://assets.coingecko.com/coins/images/34938/small/Black_and_White_Old_Logo_2.png?1716581933',
#     'name': 'Wild Goat Coin',
#     'symbol': 'WGC',
#     'total_supply': '20076547113333646',
#     'type': 'ERC-20',
#     'volume_24h': '56.097459399910115'},
#    'token_id': None,
#    'token_instance': None,
#    'value': '11335767971'},
#   {'token': {'address': '0x1a13F4Ca1d028320A707D99520AbFefca3998b7F',
#     'circulating_market_cap': '0.0',
#     'decimals': '6',
#     'exchange_rate': '0.997836',
#     'holders': '3433',
#     'icon_url': 'https://assets.coingecko.com/coins/images/14318/small/aUSDC.e260d492.png?1696514006',
#     'name': 'Aave Matic Market USDC',
#     'symbol': 'amUSDC',
#     'total_supply': '8002805225386',
#     'type': 'ERC-20',
#     'volume_24h': '595753.910417137'},
#    'token_id': None,
#    'token_instance': None,
#    'value': '5'},
#   {'token': {'address': '0x311434160D7537be358930def317AfB606C0D737',
#     'circulating_market_cap': '65813001.381097',
#     'decimals': '18',
#     'exchange_rate': '1.013',
#     'holders': '21783',
#     'icon_url': 'https://assets.coingecko.com/coins/images/19073/small/flCKDeh6_400x400.jpg?1696518523',
#     'name': 'Nakamoto.Games',
#     'symbol': 'NAKA',
#     'total_supply': '180000000000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': '57134082.989032485'},
#    'token_id': None,
#    'token_instance': None,
#    'value': '50692'},
#   {'token': {'address': '0x7cbFf4069CBe5BC7C10fA09A1a8549d97c1CD8eB',
#     'circulating_market_cap': None,
#     'decimals': '18',
#     'exchange_rate': None,
#     'holders': '607',
#     'icon_url': None,
#     'name': 'Kylar.io Coin',
#     'symbol': 'KYC',
#     'total_supply': '49999999999999989007002999997003',
#     'type': 'ERC-20',
#     'volume_24h': None},
#    'token_id': None,
#    'token_instance': None,
#    'value': '5000000000000000000000000000000'},
#   {'token': {'address': '0xaAAa03CBE1DCcF2851301F899b5a2e8C12306A1e',
#     'circulating_market_cap': None,
#     'decimals': '18',
#     'exchange_rate': None,
#     'holders': '15',
#     'icon_url': None,
#     'name': 'POLSㅤ',
#     'symbol': 'POLSㅤ',
#     'total_supply': '210000000000000000000000000000000000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': None},
#    'token_id': None,
#    'token_instance': None,
#    'value': '95400000000000000000000000000'},
#   {'token': {'address': '0xA5EbEc4CcC9A5C4f176289Df3F1c10EaFF713A57',
#     'circulating_market_cap': None,
#     'decimals': '18',
#     'exchange_rate': None,
#     'holders': '15',
#     'icon_url': None,
#     'name': 'Niggerbutt',
#     'symbol': 'NIGGERBUTT',
#     'total_supply': '1488000000000000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': None},
#    'token_id': None,
#    'token_instance': None,
#    'value': '39813482924000000000000000000'},
#   {'token': {'address': '0x37e06DEf1c214CF734023CaAF78225D3C6A73e23',
#     'circulating_market_cap': None,
#     'decimals': '18',
#     'exchange_rate': None,
#     'holders': '15',
#     'icon_url': None,
#     'name': 'Rose Petal',
#     'symbol': 'RPT',
#     'total_supply': '555555555555000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': None},
#    'token_id': None,
#    'token_instance': None,
#    'value': '5555555555000000000000000000'},
#   {'token': {'address': '0x6EC063057eE3D6fE80f913204172762922d507Cc',
#     'circulating_market_cap': None,
#     'decimals': '18',
#     'exchange_rate': None,
#     'holders': '5297',
#     'icon_url': None,
#     'name': 'Platypus Coin',
#     'symbol': 'PLAT',
#     'total_supply': '49982994490792379666800072194763',
#     'type': 'ERC-20',
#     'volume_24h': None},
#    'token_id': None,
#    'token_instance': None,
#    'value': '1697448156765000000000000000'},
#   {'token': {'address': '0xFf5572266B6EFe611ff6FE73F6002EdBe54383C1',
#     'circulating_market_cap': None,
#     'decimals': '18',
#     'exchange_rate': None,
#     'holders': '4',
#     'icon_url': None,
#     'name': 'FLY',
#     'symbol': 'FLY',
#     'total_supply': '7000000000000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': None},
#    'token_id': None,
#    'token_instance': None,
#    'value': '899910000000000000000000000'},
#   {'token': {'address': '0xd0ae0bca32fe50E71f74556082910ECd6FB1E739',
#     'circulating_market_cap': None,
#     'decimals': '18',
#     'exchange_rate': None,
#     'holders': '39',
#     'icon_url': None,
#     'name': 'CryptoDeGenS',
#     'symbol': 'CDGS',
#     'total_supply': '44942004839000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': None},
#    'token_id': None,
#    'token_instance': None,
#    'value': '420101069266300000000000000'},
#   {'token': {'address': '0x5Ffd7e78Fa0b657bd39BBC4CAbAAe003344f1A53',
#     'circulating_market_cap': None,
#     'decimals': '18',
#     'exchange_rate': None,
#     'holders': '130',
#     'icon_url': None,
#     'name': 'TYLER JOHN WOLCOTT Token',
#     'symbol': 'TJWLCTT',
#     'total_supply': '9000000000000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': None},
#    'token_id': None,
#    'token_instance': None,
#    'value': '146000001000000000000000000'},
#   {'token': {'address': '0x2017Fcaea540d2925430586DC92818035Bfc2F50',
#     'circulating_market_cap': None,
#     'decimals': '18',
#     'exchange_rate': None,
#     'holders': '3936',
#     'icon_url': None,
#     'name': 'NFT Fans',
#     'symbol': 'nftfan',
#     'total_supply': '1000000000000000000000000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': None},
#    'token_id': None,
#    'token_instance': None,
#    'value': '25031987000000000000000000'},
#   {'token': {'address': '0x57d2EBF37bfB4f370b408bEBdF4A3592b74Cef21',
#     'circulating_market_cap': None,
#     'decimals': '18',
#     'exchange_rate': None,
#     'holders': '1',
#     'icon_url': None,
#     'name': 'lol',
#     'symbol': 'lol',
#     'total_supply': '21000000000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': None},
#    'token_id': None,
#    'token_instance': None,
#    'value': '21000000000000000000000000'},
#   {'token': {'address': '0xfe7377B49567387345b44fc603F0Fa3d294e62C7',
#     'circulating_market_cap': None,
#     'decimals': '18',
#     'exchange_rate': None,
#     'holders': '41',
#     'icon_url': None,
#     'name': 'THE PEOPLEs MONEY',
#     'symbol': 'TPM',
#     'total_supply': '111111111111111000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': None},
#    'token_id': None,
#    'token_instance': None,
#    'value': '17983800000000000000000000'},
#   {'token': {'address': '0x9B8cc6320F22325759B7D2CA5CD27347bB4eCD86',
#     'circulating_market_cap': None,
#     'decimals': '18',
#     'exchange_rate': None,
#     'holders': '112235',
#     'icon_url': None,
#     'name': 'pointless',
#     'symbol': 'pointless',
#     'total_supply': '1000000000000000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': None},
#    'token_id': None,
#    'token_instance': None,
#    'value': '11254011399999999960154113'}],
#  'next_page_params': {'/type': 'ERC-20,ERC-721,ERC-1155',
#   'fiat_value': None,
#   'id': 2650626380,
#   'items_count': 50,
#   'value': '11254011399999999960154113'}}

# %%
#eth_rest.get_token_balances(address = vitalik_addr)

# %%
eth_rest.get_blocks_validated(address = '0xC02aaA39b223FE8D0A0e5C4F27eAD9083C756Cc2')

# %%
#eth_rest.get_address_logs(address = usdc_addr)

# %%
#eth_rest.get_address_transactions(address = usdc_addr)

# %%
eth_rest.get_address_counters(address = usdc_addr)
# Out:
# url: https://polygon.blockscout.com/api/v2/addresses/0x3c499c542cEF5E3811e1192ce70d8cC03d5c3359/counters
# {'transactions_count': '6283450',
#  'token_transfers_count': '1729970',
#  'gas_usage_count': '311284988343',
#  'validations_count': '0'}

# %%
eth_rest.get_address_info(address = usdc_addr)
# Out:
# url: https://polygon.blockscout.com/api/v2/addresses/0x3c499c542cEF5E3811e1192ce70d8cC03d5c3359
# {'block_number_balance_updated_at': 59807549,
#  'coin_balance': '0',
#  'creation_tx_hash': None,
#  'creator_address_hash': None,
#  'ens_domain_name': None,
#  'exchange_rate': '0.499936',
#  'has_beacon_chain_withdrawals': False,
#  'has_decompiled_code': False,
#  'has_logs': True,
#  'has_token_transfers': True,
#  'has_tokens': True,
#  'has_validated_blocks': False,
#  'hash': '0x3c499c542cEF5E3811e1192ce70d8cC03d5c3359',
#  'implementation_address': '0x235AE97b28466Db30469b89A9fe4cFf0659f82Cb',
#  'implementation_name': 'FiatTokenV2_2',
#  'implementations': [{'address': '0x235AE97b28466Db30469b89A9fe4cFf0659f82Cb',
#    'name': 'FiatTokenV2_2'}],
#  'is_contract': True,
#  'is_verified': True,
#  'metadata': None,
#  'name': 'FiatTokenProxy',
#  'private_tags': [],
#  'public_tags': [],
#  'token': {'address': '0x3c499c542cEF5E3811e1192ce70d8cC03d5c3359',
#   'circulating_market_cap': '33806257445.160835',
#   'decimals': '6',
#   'exchange_rate': '0.999755',
#   'holders': '564889',
#   'icon_url': 'https://assets.coingecko.com/coins/images/6319/small/usdc.png?1696506694',
#   'name': 'USD Coin',
#   'symbol': 'USDC',
#   'total_supply': '390808855866960',
#   'type': 'ERC-20',
#   'volume_24h': '9318673255.556795'},
#  'watchlist_address_id': None,
#  'watchlist_names': []}
