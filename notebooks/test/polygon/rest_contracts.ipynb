# %%
from blockscout import Blockscout
from blockscout import TokenTransfers
from blockscout import Net
from blockscout import API

vitalik_addr = '0xd8da6bf26964af9d7eed9e03e53415d37aa96045'
usdc_addr = '0x3c499c542cEF5E3811e1192ce70d8cC03d5c3359'

eth_rest = Blockscout(Net.MATIC, API.REST)

# %%
#eth_rest.get_smart_contract(address=usdc_addr)

# %%
eth_rest.get_smart_contract_counters()
# Out:
# url: https://polygon.blockscout.com/api/v2/smart-contracts/counters
# {'smart_contracts': '26272659',
#  'new_smart_contracts_24h': '4478',
#  'new_verified_smart_contracts_24h': '105',
#  'verified_smart_contracts': '9692'}

# %%
eth_rest.get_smart_contracts(contract_type="proxy")
# Out:
# url: https://polygon.blockscout.com/api/v2/smart-contracts?q=proxy&filter=vyper%20%7C%20solidity%20%7C%20yul
# {'items': [{'address': {'ens_domain_name': None,
#     'hash': '0xA1c57f48F0Deb89f569dFbE6E2B7f46D33606fD4',
#     'implementation_address': '0x7FFB3d637014488b63fb9858E279385685AFc1e2',
#     'implementation_name': 'UChildERC20',
#     'implementations': [{'address': '0x7FFB3d637014488b63fb9858E279385685AFc1e2',
#       'name': 'UChildERC20'}],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'RootChainManagerProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.6.6+commit.6c089d02',
#    'has_constructor_args': False,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': '597398044.8283623',
#    'optimization_enabled': False,
#    'tx_count': 14212,
#    'verified_at': '2024-07-25T19:31:12.588749Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0xE6A537a407488807F0bbeb0038B79004f19DDDFb',
#     'implementation_address': '0xE91916515DeF4c2F5756B8d75741Cdf2bb3A3244',
#     'implementation_name': None,
#     'implementations': [{'address': '0xE91916515DeF4c2F5756B8d75741Cdf2bb3A3244',
#       'name': None}],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'ERC1967Proxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.8.7+commit.e28d00a7',
#    'has_constructor_args': False,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': False,
#    'tx_count': 5233,
#    'verified_at': '2024-07-25T17:28:53.451018Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x639E3bE076A639936E46BB22e6c62c2aF3C98462',
#     'implementation_address': '0x29fcB43b46531BcA003ddC8FCB67FFE91900C762',
#     'implementation_name': None,
#     'implementations': [{'address': '0x29fcB43b46531BcA003ddC8FCB67FFE91900C762',
#       'name': None}],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'GnosisSafeProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.7.6+commit.7338295f',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': False,
#    'tx_count': None,
#    'verified_at': '2024-07-25T17:28:52.955749Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0xfEC0391fcaE5EDa7B14944415F730F037c96ca72',
#     'implementation_address': None,
#     'implementation_name': None,
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'ProxyAdmin',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.8.20+commit.a1b79de6',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': True,
#    'tx_count': None,
#    'verified_at': '2024-07-25T09:01:27.122507Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x7b74e039b52c05F99b5c3C847494Cda7c56ea4F3',
#     'implementation_address': '0xA13d6a2E0DCE28F05513164328269E51Cb55062D',
#     'implementation_name': 'TREXImplementationAuthority',
#     'implementations': [{'address': '0xA13d6a2E0DCE28F05513164328269E51Cb55062D',
#       'name': 'TREXImplementationAuthority'}],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'TokenProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.8.17+commit.8df45f5f',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': True,
#    'tx_count': None,
#    'verified_at': '2024-07-25T06:18:39.537916Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x3Cef98bb43d732E2F285eE605a8158cDE967D219',
#     'implementation_address': '0x93B6c737634D94d5a9B313b292920aa18159e5F9',
#     'implementation_name': None,
#     'implementations': [{'address': '0x93B6c737634D94d5a9B313b292920aa18159e5F9',
#       'name': None}],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'RootChainManagerProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.6.6+commit.6c089d02',
#    'has_constructor_args': False,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': '273755078.2007724',
#    'optimization_enabled': False,
#    'tx_count': 759,
#    'verified_at': '2024-07-24T07:44:17.217805Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0xafDfF9DE0027fB670B8A32795C7626ada159Ec8E',
#     'implementation_address': '0xC0FEb3a5f49691E1c51640F20852E028aE3F2430',
#     'implementation_name': None,
#     'implementations': [{'address': '0xC0FEb3a5f49691E1c51640F20852E028aE3F2430',
#       'name': None}],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'ERC1967Proxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': '0.8.9+commit.e5eed63a',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': True,
#    'tx_count': 115,
#    'verified_at': '2024-07-24T00:59:01.584851Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0xFDb64200aaDb3b8ee51bA9c1BDF5bF71eB923d24',
#     'implementation_address': None,
#     'implementation_name': None,
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'Proxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.8.13+commit.abaa5c0e',
#    'has_constructor_args': False,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': False,
#    'tx_count': None,
#    'verified_at': '2024-07-23T23:53:36.258643Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x76Abd186BEd3A9a432b15A7F8e13af8C6996B219',
#     'implementation_address': '0xC8Da03B02b1ad0Ad46690bd8023188B9e4ce9e7D',
#     'implementation_name': 'TREXImplementationAuthority',
#     'implementations': [{'address': '0xC8Da03B02b1ad0Ad46690bd8023188B9e4ce9e7D',
#       'name': 'TREXImplementationAuthority'}],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'IdentityRegistryProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.8.17+commit.8df45f5f',
#    'has_constructor_args': False,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': True,
#    'tx_count': None,
#    'verified_at': '2024-07-23T12:31:16.683026Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0xCC0b720bD9E1337191360f9A0546CF4F5c68Ddf5',
#     'implementation_address': '0xC8Da03B02b1ad0Ad46690bd8023188B9e4ce9e7D',
#     'implementation_name': 'TREXImplementationAuthority',
#     'implementations': [{'address': '0xC8Da03B02b1ad0Ad46690bd8023188B9e4ce9e7D',
#       'name': 'TREXImplementationAuthority'}],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'IdentityRegistryStorageProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.8.17+commit.8df45f5f',
#    'has_constructor_args': False,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': True,
#    'tx_count': None,
#    'verified_at': '2024-07-23T12:31:15.652235Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x5da7B2A3367D5508Dc9424705628085BBb42a516',
#     'implementation_address': '0xC8Da03B02b1ad0Ad46690bd8023188B9e4ce9e7D',
#     'implementation_name': 'TREXImplementationAuthority',
#     'implementations': [{'address': '0xC8Da03B02b1ad0Ad46690bd8023188B9e4ce9e7D',
#       'name': 'TREXImplementationAuthority'}],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'ClaimTopicsRegistryProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.8.17+commit.8df45f5f',
#    'has_constructor_args': False,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': True,
#    'tx_count': None,
#    'verified_at': '2024-07-23T12:31:15.556354Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0xe9035Fc69bf2b9CEc0D788763426f1B5fd17Cddc',
#     'implementation_address': '0xC8Da03B02b1ad0Ad46690bd8023188B9e4ce9e7D',
#     'implementation_name': 'TREXImplementationAuthority',
#     'implementations': [{'address': '0xC8Da03B02b1ad0Ad46690bd8023188B9e4ce9e7D',
#       'name': 'TREXImplementationAuthority'}],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'TokenProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.8.17+commit.8df45f5f',
#    'has_constructor_args': False,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': True,
#    'tx_count': None,
#    'verified_at': '2024-07-23T12:31:15.531585Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0xfA9fA769baCb30cCdA08E8fabe1B93C0535C6233',
#     'implementation_address': '0xC8Da03B02b1ad0Ad46690bd8023188B9e4ce9e7D',
#     'implementation_name': 'TREXImplementationAuthority',
#     'implementations': [{'address': '0xC8Da03B02b1ad0Ad46690bd8023188B9e4ce9e7D',
#       'name': 'TREXImplementationAuthority'}],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'TrustedIssuersRegistryProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.8.17+commit.8df45f5f',
#    'has_constructor_args': False,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': True,
#    'tx_count': None,
#    'verified_at': '2024-07-23T12:31:15.511912Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x49F1e7Cc179EC3A7344C17f2a38E2d58267bCf83',
#     'implementation_address': '0xc4c29463fE8808644872efAd5Cc211383105BD80',
#     'implementation_name': 'FundManager',
#     'implementations': [{'address': '0xc4c29463fE8808644872efAd5Cc211383105BD80',
#       'name': 'FundManager'}],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'EIP173Proxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': '0.8.26+commit.8a97fa7a',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': True,
#    'tx_count': 0,
#    'verified_at': '2024-07-23T11:44:31.921355Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0xe95FC76F835ddada61a8D43605150862EeD0C7a0',
#     'implementation_address': None,
#     'implementation_name': None,
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'ProxyMinter',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': '0.8.26+commit.8a97fa7a',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': False,
#    'tx_count': None,
#    'verified_at': '2024-07-22T17:32:23.835058Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0xDef87c507ef911Fd99c118c53171510Eb7967738',
#     'implementation_address': None,
#     'implementation_name': None,
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'ProxyOFT',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': '0.8.23+commit.f704f362',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': True,
#    'tx_count': None,
#    'verified_at': '2024-07-22T16:48:26.312841Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x6c987bCd2b60e1568186De095c6497aA30C28601',
#     'implementation_address': '0xA13d6a2E0DCE28F05513164328269E51Cb55062D',
#     'implementation_name': 'TREXImplementationAuthority',
#     'implementations': [{'address': '0xA13d6a2E0DCE28F05513164328269E51Cb55062D',
#       'name': 'TREXImplementationAuthority'}],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'TokenProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': None,
#    'compiler_version': 'v0.8.17+commit.8df45f5f',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': True,
#    'tx_count': None,
#    'verified_at': '2024-07-22T10:41:29.459761Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x8492925E813C6700Dc378632FD7CDd7c139C966D',
#     'implementation_address': None,
#     'implementation_name': None,
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'ProxyAdmin',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.8.20+commit.a1b79de6',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': True,
#    'tx_count': None,
#    'verified_at': '2024-07-22T07:53:11.404210Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x7E5DeEefB63881A696f4174EdeEE14B24A8a1080',
#     'implementation_address': None,
#     'implementation_name': None,
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'GnosisSafeProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.7.6+commit.7338295f',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': False,
#    'tx_count': 0,
#    'verified_at': '2024-07-19T11:24:56.914315Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0xE4aE011950BCB3228cFDD952527Ba265c7c96021',
#     'implementation_address': None,
#     'implementation_name': None,
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'ProxyAdmin',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.8.20+commit.a1b79de6',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': True,
#    'tx_count': None,
#    'verified_at': '2024-07-19T07:07:28.249243Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0xDd96d46a1Fe544855E2AE8Dd092B5231D68d64D8',
#     'implementation_address': None,
#     'implementation_name': None,
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'BeaconProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': '0.8.17+commit.8df45f5f',
#    'has_constructor_args': False,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': True,
#    'tx_count': None,
#    'verified_at': '2024-07-19T06:54:52.195963Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x23fba714C467Cf6BaBd17571cAc3cCb109CFEfC3',
#     'implementation_address': '0x91E91ff9D8dbA7AB198A6c1617774767Ce82170F',
#     'implementation_name': None,
#     'implementations': [{'address': '0x91E91ff9D8dbA7AB198A6c1617774767Ce82170F',
#       'name': None}],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'EIP173ProxyWithReceive',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.8.20+commit.a1b79de6',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': True,
#    'tx_count': None,
#    'verified_at': '2024-07-18T06:21:00.888347Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x72e6B59D4a90ab232e55D4BB7ed2dD17494D62fB',
#     'implementation_address': '0x328a369cD14d9DA4fB86548E35274CFE0F76B9A5',
#     'implementation_name': None,
#     'implementations': [{'address': '0x328a369cD14d9DA4fB86548E35274CFE0F76B9A5',
#       'name': None}],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'EIP1967Proxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': '0.8.15+commit.e14f2714',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': True,
#    'tx_count': 17998,
#    'verified_at': '2024-07-17T17:38:56.982906Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0xc8F7B28B2EB7136f35e2A6d71a1AfCce937283BF',
#     'implementation_address': None,
#     'implementation_name': None,
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'ProxyAdmin',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.8.24+commit.e11b9ed9',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': True,
#    'tx_count': None,
#    'verified_at': '2024-07-17T08:02:32.928232Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0xc82634e5b7aee1197fABc5eC8971d088e5b66536',
#     'implementation_address': None,
#     'implementation_name': None,
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'ProxyAdmin',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.8.19+commit.7dd6d404',
#    'has_constructor_args': False,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': True,
#    'tx_count': None,
#    'verified_at': '2024-07-16T22:47:29.844476Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x7af28FEb1cbc622a410fC0DbDdb2f772fe3D56dA',
#     'implementation_address': None,
#     'implementation_name': None,
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'ProxyOracle',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': '0.8.16+commit.07a7930e',
#    'has_constructor_args': False,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': True,
#    'tx_count': None,
#    'verified_at': '2024-07-16T15:34:52.297203Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0xf0361c94bf3036dc95f83b4aED476800B1992A19',
#     'implementation_address': None,
#     'implementation_name': None,
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'ProxyAdmin',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': '0.8.26+commit.8a97fa7a',
#    'has_constructor_args': False,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': True,
#    'tx_count': None,
#    'verified_at': '2024-07-16T13:14:09.027582Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x7272a5a8BD39f204bF773E8b74BB01E31681Ad1D',
#     'implementation_address': '0x42B348F1724D6Df9f80053ddD3885934049EDF38',
#     'implementation_name': 'UChildERC20',
#     'implementations': [{'address': '0x42B348F1724D6Df9f80053ddD3885934049EDF38',
#       'name': 'UChildERC20'}],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'UChildERC20Proxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': '0.6.6+commit.6c089d02',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': False,
#    'tx_count': 32070,
#    'verified_at': '2024-07-16T11:40:39.963022Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x2D6dcd519603EBCdEe3fd41547022C13368f1162',
#     'implementation_address': None,
#     'implementation_name': None,
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'ProxyStaker',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': '0.8.20+commit.a1b79de6',
#    'has_constructor_args': False,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': True,
#    'tx_count': None,
#    'verified_at': '2024-07-16T09:43:26.015999Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x8E8b858b32FaC0C29080547B49031EcF493e74F8',
#     'implementation_address': None,
#     'implementation_name': None,
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'IdentityRegistryProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': '0.8.17+commit.8df45f5f',
#    'has_constructor_args': False,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': True,
#    'tx_count': None,
#    'verified_at': '2024-07-15T12:05:45.707598Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0xcC4801256Ec2361a36B89C79098D2c48A947dae6',
#     'implementation_address': None,
#     'implementation_name': None,
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'AutomanRelayerProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': '0.8.26+commit.8a97fa7a',
#    'has_constructor_args': False,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': True,
#    'tx_count': None,
#    'verified_at': '2024-07-15T08:16:21.440676Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x20D4029c783D5c9f47569940c656Af4189e53799',
#     'implementation_address': '0xefE147fFC12b847C0f2B6f19c11fa8266A8e3DDf',
#     'implementation_name': 'PPAgentV2VRF',
#     'implementations': [{'address': '0xefE147fFC12b847C0f2B6f19c11fa8266A8e3DDf',
#       'name': 'PPAgentV2VRF'}],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'TransparentUpgradeableProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '8782647493938241313',
#    'compiler_version': '0.8.19+commit.7dd6d404',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': True,
#    'tx_count': None,
#    'verified_at': '2024-07-14T02:37:57.162519Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x7D45c55408b413936AE00EFB32dFcd01c25B32E4',
#     'implementation_address': None,
#     'implementation_name': None,
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'ProxyAdmin',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.8.22+commit.4fc1097e',
#    'has_constructor_args': False,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': True,
#    'tx_count': None,
#    'verified_at': '2024-07-12T05:03:01.322136Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x2163ec83988C2c20A5530679904D9C23f713F2e4',
#     'implementation_address': None,
#     'implementation_name': None,
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'ProxyAdmin',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.8.19+commit.7dd6d404',
#    'has_constructor_args': False,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': True,
#    'tx_count': None,
#    'verified_at': '2024-07-12T01:16:51.922633Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x92a4e8Bc6B92a2e1ced411f41013B5FE6BE07613',
#     'implementation_address': '0xECde8Dc47702c536707D49e5535Dbd9cc47317b0',
#     'implementation_name': 'BetExpress',
#     'implementations': [{'address': '0xECde8Dc47702c536707D49e5535Dbd9cc47317b0',
#       'name': 'BetExpress'}],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'BeaconProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.8.16+commit.07a7930e',
#    'has_constructor_args': False,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': True,
#    'tx_count': None,
#    'verified_at': '2024-07-11T23:35:52.852366Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x95A62521c655e7A24A3919AA1f99764C05B7ec4E',
#     'implementation_address': '0xc2e5116731FBE76dD7FCb380F31911298808301a',
#     'implementation_name': 'UChildERC20',
#     'implementations': [{'address': '0xc2e5116731FBE76dD7FCb380F31911298808301a',
#       'name': 'UChildERC20'}],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'UChildERC20Proxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': '0.6.6+commit.6c089d02',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': '291200233.0260283',
#    'optimization_enabled': False,
#    'tx_count': 2429,
#    'verified_at': '2024-07-11T15:11:27.380780Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x3C69d114664d48357d820Dbdd121a8071eAc99bf',
#     'implementation_address': '0x7d8663F5841d8B9F676040f5B31B97214EC0DF59',
#     'implementation_name': 'UChildERC20',
#     'implementations': [{'address': '0x7d8663F5841d8B9F676040f5B31B97214EC0DF59',
#       'name': 'UChildERC20'}],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'UChildERC20Proxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': '0.6.6+commit.6c089d02',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': '0.0',
#    'optimization_enabled': False,
#    'tx_count': None,
#    'verified_at': '2024-07-11T15:08:32.581967Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x6ab707Aca953eDAeFBc4fD23bA73294241490620',
#     'implementation_address': '0xCf85FF1c37c594a10195F7A9Ab85CBb0a03f69dE',
#     'implementation_name': None,
#     'implementations': [{'address': '0xCf85FF1c37c594a10195F7A9Ab85CBb0a03f69dE',
#       'name': None}],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'InitializableImmutableAdminUpgradeabilityProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': '0.8.10+commit.fc410830',
#    'has_constructor_args': False,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': '0.0',
#    'optimization_enabled': True,
#    'tx_count': None,
#    'verified_at': '2024-07-11T15:08:07.917420Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x2756662cd72F047E0C3316E75b0192eD9DC74193',
#     'implementation_address': None,
#     'implementation_name': None,
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'ChainspotProxyV1',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': '0.8.23+commit.f704f362',
#    'has_constructor_args': False,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': True,
#    'tx_count': None,
#    'verified_at': '2024-07-11T02:10:39.976413Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0xb44e490Ee9E39F373Af8D5FCCFF819DE39dc96e3',
#     'implementation_address': '0x5219A014aDaE22e2195F549F9Df38cd3164A8eF0',
#     'implementation_name': 'MetaTraceNFTPart',
#     'implementations': [{'address': '0x5219A014aDaE22e2195F549F9Df38cd3164A8eF0',
#       'name': 'MetaTraceNFTPart'}],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'ERC1967Proxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.8.7+commit.e28d00a7',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': False,
#    'tx_count': 7598,
#    'verified_at': '2024-07-10T09:18:45.650353Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x078f358208685046a11C85e8ad32895DED33A249',
#     'implementation_address': '0xCf85FF1c37c594a10195F7A9Ab85CBb0a03f69dE',
#     'implementation_name': None,
#     'implementations': [{'address': '0xCf85FF1c37c594a10195F7A9Ab85CBb0a03f69dE',
#       'name': None}],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'InitializableImmutableAdminUpgradeabilityProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': '0.8.10+commit.fc410830',
#    'has_constructor_args': False,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': '0.0',
#    'optimization_enabled': True,
#    'tx_count': 4123,
#    'verified_at': '2024-07-09T13:24:50.533462Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x96F5b0DAd534f9A21b9c62D3675e9cd430c15d7b',
#     'implementation_address': '0xe8b71989dda272A85ea63861dD1c45ac59e83D91',
#     'implementation_name': 'TREXImplementationAuthority',
#     'implementations': [{'address': '0xe8b71989dda272A85ea63861dD1c45ac59e83D91',
#       'name': 'TREXImplementationAuthority'}],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'TokenProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.8.17+commit.8df45f5f',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': True,
#    'tx_count': None,
#    'verified_at': '2024-07-08T22:19:14.611649Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x298CE61FADa4a9e3A0FC8AcF4C373A3c14b15125',
#     'implementation_address': None,
#     'implementation_name': None,
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'ProxyWalletFactory',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.5.10+commit.5a6ea5b1',
#    'has_constructor_args': False,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': True,
#    'tx_count': None,
#    'verified_at': '2024-07-08T12:11:12.724232Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x4dD835afC9E02382e98700eC2fa5317aeE1f321d',
#     'implementation_address': '0xEa8249345c0FD4051c432e1dcE0Fad6d163c4648',
#     'implementation_name': None,
#     'implementations': [{'address': '0xEa8249345c0FD4051c432e1dcE0Fad6d163c4648',
#       'name': None}],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'ERC1967Proxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': '0.8.9+commit.e5eed63a',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': True,
#    'tx_count': 12,
#    'verified_at': '2024-07-08T10:03:30.049187Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0xf30aC7054B3Da7A155cFB530E353a1b3554399EF',
#     'implementation_address': None,
#     'implementation_name': None,
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'TokenProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': '0.8.17+commit.8df45f5f',
#    'has_constructor_args': False,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': True,
#    'tx_count': None,
#    'verified_at': '2024-07-08T09:54:32.659249Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x07F0BaEB0897075F607A62a0F510913C0BF1E4C9',
#     'implementation_address': None,
#     'implementation_name': None,
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'PortfolioProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': '0.8.20+commit.a1b79de6',
#    'has_constructor_args': False,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': True,
#    'tx_count': None,
#    'verified_at': '2024-07-08T06:54:44.087707Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x9d77b341873fD7ba90545D793215F5A83c6A7860',
#     'implementation_address': '0xA13d6a2E0DCE28F05513164328269E51Cb55062D',
#     'implementation_name': 'TREXImplementationAuthority',
#     'implementations': [{'address': '0xA13d6a2E0DCE28F05513164328269E51Cb55062D',
#       'name': 'TREXImplementationAuthority'}],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'IdentityRegistryProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.8.17+commit.8df45f5f',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': True,
#    'tx_count': None,
#    'verified_at': '2024-07-08T05:48:31.795854Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x6Fb2835018015F1712B0aA74E2Add56899AFc7F3',
#     'implementation_address': '0xA13d6a2E0DCE28F05513164328269E51Cb55062D',
#     'implementation_name': 'TREXImplementationAuthority',
#     'implementations': [{'address': '0xA13d6a2E0DCE28F05513164328269E51Cb55062D',
#       'name': 'TREXImplementationAuthority'}],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'IdentityRegistryStorageProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.8.17+commit.8df45f5f',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': True,
#    'tx_count': None,
#    'verified_at': '2024-07-08T05:48:31.789077Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0xe15F371f8932fD157B60daa3F438Df6E074659AB',
#     'implementation_address': None,
#     'implementation_name': None,
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'IdentityRegistryProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': '0.8.17+commit.8df45f5f',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': True,
#    'tx_count': None,
#    'verified_at': '2024-07-08T01:49:59.731115Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x79E75F470E60075b3F6dF5740Fe7e86F7F6e3642',
#     'implementation_address': None,
#     'implementation_name': None,
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'ProxyAdmin',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': '0.8.18+commit.87f61d96',
#    'has_constructor_args': False,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': True,
#    'tx_count': None,
#    'verified_at': '2024-07-06T03:55:23.324506Z'}],
#  'next_page_params': {'coin_balance': '0',
#   'items_count': 50,
#   'smart_contract_id': 7674,
#   'tx_count': None}}
