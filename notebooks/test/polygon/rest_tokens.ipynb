# %%
from blockscout import Blockscout
from blockscout import TokenTransfers
from blockscout import Net
from blockscout import API

vitalik_addr = '0xd8da6bf26964af9d7eed9e03e53415d37aa96045'
usdc_addr = '0x3c499c542cEF5E3811e1192ce70d8cC03d5c3359'

eth_rest = Blockscout(Net.MATIC, API.REST)

# %%
eth_rest.get_token_counters(address=usdc_addr)
# Out:
# url: https://polygon.blockscout.com/api/v2/tokens/0x3c499c542cEF5E3811e1192ce70d8cC03d5c3359/counters
# {'token_holders_count': '564856', 'transfers_count': '0'}

# %%
#eth_rest.get_token_holders(address=usdc_addr)

# %%
#eth_rest.get_token_transfers(address=usdc_addr)

# %%
eth_rest.get_token_info(address=usdc_addr)
# Out:
# url: https://polygon.blockscout.com/api/v2/tokens/0x3c499c542cEF5E3811e1192ce70d8cC03d5c3359
# {'address': '0x3c499c542cEF5E3811e1192ce70d8cC03d5c3359',
#  'circulating_market_cap': '33806257445.160835',
#  'decimals': '6',
#  'exchange_rate': '0.999755',
#  'holders': '564857',
#  'icon_url': 'https://assets.coingecko.com/coins/images/6319/small/usdc.png?1696506694',
#  'name': 'USD Coin',
#  'symbol': 'USDC',
#  'total_supply': '390807198623334',
#  'type': 'ERC-20',
#  'volume_24h': '9318673255.556795'}

# %%
eth_rest.get_tokens_list(token_name="USDC")
# Out:
# url: https://polygon.blockscout.com/api/v2/tokens?q=USDC&type=ERC-20%2CERC-721%2CERC-1155
# {'items': [{'address': '0x3c499c542cEF5E3811e1192ce70d8cC03d5c3359',
#    'circulating_market_cap': '33806257445.160835',
#    'decimals': '6',
#    'exchange_rate': '0.999755',
#    'holders': '564857',
#    'icon_url': 'https://assets.coingecko.com/coins/images/6319/small/usdc.png?1696506694',
#    'name': 'USD Coin',
#    'symbol': 'USDC',
#    'total_supply': '390807198623334',
#    'type': 'ERC-20',
#    'volume_24h': '9318673255.556795'},
#   {'address': '0x9719d867A500Ef117cC201206B8ab51e794d3F82',
#    'circulating_market_cap': '0.0',
#    'decimals': '6',
#    'exchange_rate': '1.13',
#    'holders': '114',
#    'icon_url': 'https://assets.coingecko.com/coins/images/14074/small/maUSDC.png?1696513798',
#    'name': 'Matic Aave interest bearing USDC',
#    'symbol': 'maUSDC',
#    'total_supply': '167155978909',
#    'type': 'ERC-20',
#    'volume_24h': '84.94226067773789'},
# ...
