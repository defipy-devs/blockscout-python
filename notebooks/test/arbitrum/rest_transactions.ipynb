# %%
from blockscout import Blockscout
from blockscout import Net
from blockscout import API

vitalik_addr = '0xd8da6bf26964af9d7eed9e03e53415d37aa96045'
usdc_addr = '0xaf88d065e77c8cC2239327C5EDb3A432268e5831'

eth_rest = Blockscout(Net.ARB, API.REST)

# %%
eth_rest.get_main_page_transactions()
# Out:
# url: https://arbitrum.blockscout.com/api/v2/transactions
# {'items': [{'timestamp': '2024-07-25T21:16:45.000000Z',
#    'fee': {'type': 'actual', 'value': '2237120000000'},
#    'gas_limit': '624382',
#    'block': 236027346,
#    'status': 'ok',
#    'method': None,
#    'confirmations': 5,
#    'type': 0,
#    'exchange_rate': '3154.65',
#    'to': {'ens_domain_name': None,
#     'hash': '0xcf17b68a40f10d3DcEedd9a092F1Df331cE3D9da',
#     'implementations': [],
#     'is_contract': False,
#     'is_verified': False,
#     'metadata': None,
#     'name': None,
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'tx_burnt_fee': None,
#    'max_fee_per_gas': None,
#    'result': 'success',
#    'hash': '0x614c48fdfc3b27744cf86fc0eaf2b4b3e0f5a33440459a0a9b1abecaf2d44438',
#    'gas_price': '10000000',
#    'priority_fee': None,
#    'base_fee_per_gas': '10000000',
#    'from': {'ens_domain_name': None,
# ...

# %%
eth_rest.get_transaction_info(tx_hash = "0x5509f7f1ed812528777fbfcf638b0ee4a5d194b21d47e5ebeaf7b220d7fbd84f")
# Out:
# url: https://arbitrum.blockscout.com/api/v2/transactions/0x5509f7f1ed812528777fbfcf638b0ee4a5d194b21d47e5ebeaf7b220d7fbd84f
# {'timestamp': '2024-07-25T21:08:17.000000Z',
#  'fee': {'type': 'actual', 'value': '675110000000'},
#  'gas_limit': '252259',
#  'block': 236025318,
#  'status': 'ok',
#  'method': '0x095ea7b3',
#  'confirmations': 2168,
#  'type': 2,
#  'exchange_rate': '3154.65',
#  'to': {'ens_domain_name': None,
#   'hash': '0xFd086bC7CD5C481DCC9C85ebE478A1C0b69FCbb9',
#   'implementations': [{'address': '0xf31e1AE27e7cd057C1D6795a5a083E0453D39B50',
#     'name': None}],
#   'is_contract': True,
#   'is_verified': True,
#   'metadata': None,
#   'name': 'TransparentUpgradeableProxy',
#   'private_tags': [],
#   'public_tags': [],
#   'watchlist_names': []},
#  'tx_burnt_fee': '675110000000',
#  'max_fee_per_gas': '15000000',
#  'result': 'success',
#  'hash': '0x5509f7f1ed812528777fbfcf638b0ee4a5d194b21d47e5ebeaf7b220d7fbd84f',
#  'gas_price': '10000000',
# ...

# %%
eth_rest.get_token_hash_transfers(tx_hash = "0x5509f7f1ed812528777fbfcf638b0ee4a5d194b21d47e5ebeaf7b220d7fbd84f")
# Out:
# url: https://arbitrum.blockscout.com/api/v2/transactions/0x5509f7f1ed812528777fbfcf638b0ee4a5d194b21d47e5ebeaf7b220d7fbd84f/token-transfers?type=ERC-20%2CERC-721%2CERC-1155
# {'items': [], 'next_page_params': None}

# %%
eth_rest.get_internal_transactions(tx_hash = "0x5509f7f1ed812528777fbfcf638b0ee4a5d194b21d47e5ebeaf7b220d7fbd84f")
# Out:
# url: https://arbitrum.blockscout.com/api/v2/transactions/0x5509f7f1ed812528777fbfcf638b0ee4a5d194b21d47e5ebeaf7b220d7fbd84f/internal-transactions
# {'items': [{'block': 236025318,
#    'block_index': 2,
#    'created_contract': None,
#    'error': None,
#    'from': {'ens_domain_name': None,
#     'hash': '0xFd086bC7CD5C481DCC9C85ebE478A1C0b69FCbb9',
#     'implementations': [{'address': '0xf31e1AE27e7cd057C1D6795a5a083E0453D39B50',
#       'name': None}],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'TransparentUpgradeableProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'gas_limit': '206136',
#    'index': 1,
#    'success': True,
#    'timestamp': '2024-07-25T21:08:17.000000Z',
#    'to': {'ens_domain_name': None,
#     'hash': '0xf31e1AE27e7cd057C1D6795a5a083E0453D39B50',
#     'implementations': [],
#     'is_contract': False,
#     'is_verified': False,
#     'metadata': None,
# ...

# %%
eth_rest.get_transaction_logs(tx_hash = "0x5509f7f1ed812528777fbfcf638b0ee4a5d194b21d47e5ebeaf7b220d7fbd84f")
# Out:
# url: https://arbitrum.blockscout.com/api/v2/transactions/0x5509f7f1ed812528777fbfcf638b0ee4a5d194b21d47e5ebeaf7b220d7fbd84f/logs
# {'items': [{'address': {'ens_domain_name': None,
#     'hash': '0xFd086bC7CD5C481DCC9C85ebE478A1C0b69FCbb9',
#     'implementations': [{'address': '0xf31e1AE27e7cd057C1D6795a5a083E0453D39B50',
#       'name': None}],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'TransparentUpgradeableProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'block_hash': '0xee29d2796ab09a59115b2ee34ec6d8f2984242f7cf960c446d67892b02cef9f9',
#    'block_number': 236025318,
#    'data': '0x00000000000000000000000000000000000000000000000000000000060cb13c',
#    'decoded': {'method_call': 'Approval(address indexed o, address indexed s, uint256 a)',
#     'method_id': '8c5be1e5',
#     'parameters': [{'indexed': True,
#       'name': 'o',
#       'type': 'address',
# ...

# %%
eth_rest.get_state_changes(tx_hash = "0x5509f7f1ed812528777fbfcf638b0ee4a5d194b21d47e5ebeaf7b220d7fbd84f")
# Out:
# url: https://arbitrum.blockscout.com/api/v2/transactions/0x5509f7f1ed812528777fbfcf638b0ee4a5d194b21d47e5ebeaf7b220d7fbd84f/state-changes
# {'items': [{'address': {'ens_domain_name': None,
#     'hash': '0xBA239cb58d1dbe32da1d08bA182A488E79149982',
#     'implementations': [],
#     'is_contract': False,
#     'is_verified': False,
#     'metadata': None,
#     'name': None,
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'balance_after': '735010182107000',
#    'balance_before': '735685292107000',
#    'change': '-675110000000',
#    'is_miner': False,
#    'token': None,
#    'token_id': None,
#    'type': 'coin'}],
#  'next_page_params': None}
