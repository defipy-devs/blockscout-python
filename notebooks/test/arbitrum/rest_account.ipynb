# %% [markdown]
# * https://arbitrum.blockscout.com

# %%
from blockscout import Blockscout
from blockscout import TokenTransfers
from blockscout import Net
from blockscout import API

vitalik_addr = '0xd8da6bf26964af9d7eed9e03e53415d37aa96045'
usdc_addr = '0xaf88d065e77c8cC2239327C5EDb3A432268e5831'

eth_rest = Blockscout(Net.ARB, API.REST)

# %%
#eth_rest.get_addresses()

# %%
eth_rest.get_coin_balance_history_by_day(address = vitalik_addr)
# Out:
# url: https://arbitrum.blockscout.com/api/v2/addresses/0xd8da6bf26964af9d7eed9e03e53415d37aa96045/coin-balance-history-by-day
# {'items': [{'date': '2024-07-15', 'value': '831233364322485060'},
#   {'date': '2024-07-25', 'value': '831233364322485060'}],
#  'days': 10}

# %%
eth_rest.get_coin_balance_history(address = vitalik_addr)
# Out:
# url: https://arbitrum.blockscout.com/api/v2/addresses/0xd8da6bf26964af9d7eed9e03e53415d37aa96045/coin-balance-history
# {'items': [{'block_number': 232579120,
#    'block_timestamp': '2024-07-15T20:41:39Z',
#    'delta': '30000000000000',
#    'transaction_hash': '0x7524b343b5c9693d678c56d5b62edbe18d449133b15c6f18b115c49bb667eb70',
#    'value': '831233364322485060'},
#   {'block_number': 231305662,
#    'block_timestamp': '2024-07-12T00:13:58Z',
#    'delta': '30000000000000',
#    'transaction_hash': '0x53f2f6bb79828a181a346d36ace017fd62feaf5c0f45f535f5e7ff8550fc03e2',
#    'value': '831203364322485060'},
#   {'block_number': 229984045,
#    'block_timestamp': '2024-07-08T00:16:29Z',
#    'delta': '342403604825151',
#    'transaction_hash': '0x285615e5751a2bcfe1e007e300b7014fb84a8f0f4551d029199db045b5514a85',
#    'value': '831173364322485060'},
#   {'block_number': 225285963,
#    'block_timestamp': '2024-06-23T19:09:48Z',
#    'delta': '130000000000000',
#    'transaction_hash': '0x8f731bf22c06745061f8ea25bcb2183fb130f4571dd57278e5d67abaf0a8ba2d',
#    'value': '830830960717659909'},
#   {'block_number': 224683071,
#    'block_timestamp': '2024-06-21T23:23:22Z',
#    'delta': '30000000007245',
#    'transaction_hash': '0x1ae46199cf0d55eb37ab8269844cc85cc021683d44c425ab6a5bc301d93df40e',
#    'value': '830700960717659909'},
#   {'block_number': 223816975,
#    'block_timestamp': '2024-06-19T08:30:19Z',
#    'delta': '69',
#    'transaction_hash': '0xedd48601726dd68a8d93bf1c25a4f448c9f59c9aebba461745670434c2731db2',
#    'value': '830670960717652664'},
#   {'block_number': 223816974,
#    'block_timestamp': '2024-06-19T08:30:19Z',
#    'delta': '69',
#    'transaction_hash': '0x040305e8afba3add06f6c22eea5e5d1c854ea79b5424af30e244dc99ad5e0351',
#    'value': '830670960717652595'},
#   {'block_number': 223816972,
#    'block_timestamp': '2024-06-19T08:30:18Z',
#    'delta': '69',
#    'transaction_hash': '0xe44099a6d742e71f3c34b7ecce7524781adf81e2841c947a2bb92b76ca42a1f4',
#    'value': '830670960717652526'},
#   {'block_number': 223816489,
#    'block_timestamp': '2024-06-19T08:28:12Z',
#    'delta': '69',
#    'transaction_hash': '0xf285760e352a990f0da197f9fc593f5dafca3c67bed0d51828e4d1f4388d353e',
#    'value': '830670960717652457'},
#   {'block_number': 223816488,
#    'block_timestamp': '2024-06-19T08:28:12Z',
#    'delta': '69',
#    'transaction_hash': '0xd3dbc79fa6df0ff7f80ec39b9b8461523b4cce7c591e2c7e3b7d7aa14cc68c4e',
#    'value': '830670960717652388'},
#   {'block_number': 223816487,
#    'block_timestamp': '2024-06-19T08:28:11Z',
#    'delta': '69',
#    'transaction_hash': '0xc7b107708aa20e19ddecffc1c70cd936c2cb53aad7ce5fcf7ef503a163e6f25c',
#    'value': '830670960717652319'},
#   {'block_number': 223815532,
#    'block_timestamp': '2024-06-19T08:24:02Z',
#    'delta': '138',
#    'transaction_hash': '0x3ad36018dabc031ba236980d3bfd3ba437a394b2e0cd81b4aca153491a59c7da',
#    'value': '830670960717652250'},
#   {'block_number': 223815525,
#    'block_timestamp': '2024-06-19T08:24:00Z',
#    'delta': '69',
#    'transaction_hash': '0x743b6656adbcc81ce372c632d2e3244146df5cfe5649b8d41e619e2a48454ed9',
#    'value': '830670960717652112'},
#   {'block_number': 223814948,
#    'block_timestamp': '2024-06-19T08:21:29Z',
#    'delta': '207',
#    'transaction_hash': '0x56cd807827a0ef1a71dceed067bfb0859c003551b486a324ea472b4aaf7dc211',
#    'value': '830670960717652043'},
#   {'block_number': 223814947,
#    'block_timestamp': '2024-06-19T08:21:29Z',
#    'delta': '276',
#    'transaction_hash': '0xdd0e1fdc9b47313950973fd4c72b89160338bc1dbcf823a52a4dee8c32e688cc',
#    'value': '830670960717651836'},
#   {'block_number': 223814946,
#    'block_timestamp': '2024-06-19T08:21:29Z',
#    'delta': '414',
#    'transaction_hash': '0xfedadf36369f2fdcc49264acc95c62475286defdd0a052d57b5e61548ba28c1f',
#    'value': '830670960717651560'},
#   {'block_number': 223814945,
#    'block_timestamp': '2024-06-19T08:21:28Z',
#    'delta': '552',
#    'transaction_hash': '0x5f7b0962cd4d9c10d9c5edaf924fd87f67ae62330660ce892194b778ae6ed369',
#    'value': '830670960717651146'},
#   {'block_number': 223814944,
#    'block_timestamp': '2024-06-19T08:21:28Z',
#    'delta': '759',
#    'transaction_hash': '0xa92414c171aa76ad60cbbb0664244fc9db7871d402a5208248ae3508d7571cd4',
#    'value': '830670960717650594'},
#   {'block_number': 223814943,
#    'block_timestamp': '2024-06-19T08:21:28Z',
#    'delta': '414',
#    'transaction_hash': '0x9ca00d5f4c991e64e85d52619651b6c5ee0b7b9cefe94482b91d90568a624cad',
#    'value': '830670960717649835'},
#   {'block_number': 223814942,
#    'block_timestamp': '2024-06-19T08:21:28Z',
#    'delta': '69',
#    'transaction_hash': '0xa8721e37d9f9e79abcc1d36538285c80f559fc99e1aef7c9fbc950c182ae086c',
#    'value': '830670960717649421'},
#   {'block_number': 223814938,
#    'block_timestamp': '2024-06-19T08:21:27Z',
#    'delta': '207',
#    'transaction_hash': '0xfb0ff6a2d7630bcab9395ce862b4856aec9026b63ac90876546c5ddb17b52821',
#    'value': '830670960717649352'},
#   {'block_number': 223814937,
#    'block_timestamp': '2024-06-19T08:21:26Z',
#    'delta': '345',
#    'transaction_hash': '0xe09679a559902682905025aa4034a0ba9f49d2b26869ec590e9818df239ab1fc',
#    'value': '830670960717649145'},
#   {'block_number': 223814669,
#    'block_timestamp': '2024-06-19T08:20:16Z',
#    'delta': '414',
#    'transaction_hash': '0x306ffbc451780ebe207219743a1e61f1939415cf12b17768fb812946a308bef5',
#    'value': '830670960717648800'},
#   {'block_number': 223814668,
#    'block_timestamp': '2024-06-19T08:20:16Z',
#    'delta': '483',
#    'transaction_hash': '0x724b3d72077bb32e37d5ab5e1232a586ce0ec15d9321a94edefe043abc563b65',
#    'value': '830670960717648386'},
#   {'block_number': 223814667,
#    'block_timestamp': '2024-06-19T08:20:16Z',
#    'delta': '1035',
#    'transaction_hash': '0xfcb60c28023c95761c5b7ca43c29f80138e52989879ae4edabd628ccc701a007',
#    'value': '830670960717647903'},
#   {'block_number': 223814666,
#    'block_timestamp': '2024-06-19T08:20:15Z',
#    'delta': '1587',
#    'transaction_hash': '0xec7fb4962bd4bed8667d5435527ada1383575b1c546bd76be54bebdd58084129',
#    'value': '830670960717646868'},
#   {'block_number': 223814665,
#    'block_timestamp': '2024-06-19T08:20:15Z',
#    'delta': '207',
#    'transaction_hash': '0x7ebf3e636ec376be26d146e8f5b8e214f43c1bc1925ac9dbc0698dfffbaa62ba',
#    'value': '830670960717645281'},
#   {'block_number': 223814664,
#    'block_timestamp': '2024-06-19T08:20:15Z',
#    'delta': '1173',
#    'transaction_hash': '0xe3ebd16e9ca20e1f76d333c7cb8df8469680b64072de1444f45d8e553b924170',
#    'value': '830670960717645074'},
#   {'block_number': 223814660,
#    'block_timestamp': '2024-06-19T08:20:14Z',
#    'delta': '966',
#    'transaction_hash': '0x4339cf13a63fe564d8d8f29644cd83edffa9ae3a01566d9e8c65ebdb3bd2c198',
#    'value': '830670960717643901'},
#   {'block_number': 220936195,
#    'block_timestamp': '2024-06-10T15:20:31Z',
#    'delta': '10000000000000',
#    'transaction_hash': '0xa1e3611abed940163c3fabf616bfed4b18635766a109e6c6adabd92f04c6acb7',
#    'value': '830670960717642935'},
#   {'block_number': 217865999,
#    'block_timestamp': '2024-06-01T08:25:33Z',
#    'delta': '52871908685739068',
#    'transaction_hash': '0x187610339787eaabefb319dfa793c0bc815e2869fd30fbf34c8f48e5d0d0beb9',
#    'value': '830660960717642935'},
#   {'block_number': 212061280,
#    'block_timestamp': '2024-05-14T18:57:55Z',
#    'delta': '1000000420690420',
#    'transaction_hash': '0x5dba418daa797fb132cda89645f550e3d62bf603d0f9dcfcf7d8e9d53cf351b5',
#    'value': '777789052031903867'},
#   {'block_number': 210592507,
#    'block_timestamp': '2024-05-10T08:19:22Z',
#    'delta': '10000000000000',
#    'transaction_hash': '0x0c1865bfed333a28824ebb63429f518f611a239a625fcbf339571e8d4d156722',
#    'value': '776789051611213447'},
#   {'block_number': 208866416,
#    'block_timestamp': '2024-05-05T02:59:51Z',
#    'delta': '-420008177050000000',
#    'transaction_hash': '0xeed0249907b0799b95c3f3d061e46ca75c42a0a2b0d888cfdc53eb87dcb0ebd6',
#    'value': '776779051611213447'},
#   {'block_number': 208431864,
#    'block_timestamp': '2024-05-03T19:26:46Z',
#    'delta': '350000000000000',
#    'transaction_hash': '0x2096fe84bfb7106a995f56af9129fcfec605f24d0d23fa022d68fec90ec5ed09',
#    'value': '1196787228661213447'},
#   {'block_number': 194868116,
#    'block_timestamp': '2024-03-23T18:37:47Z',
#    'delta': '4560000000000',
#    'transaction_hash': '0xc666af769279a79dc06c890bc2e3758abb575bba4c7c15048d24c69d8c0b3302',
#    'value': '1196437228661213447'},
#   {'block_number': 193821614,
#    'block_timestamp': '2024-03-20T14:38:49Z',
#    'delta': '63818111426893',
#    'transaction_hash': '0x3f657b93b7b97c2b674bb706d2e3406ea903225263aa039f64239a3a6977f7c1',
#    'value': '1196432668661213447'},
#   {'block_number': 189745623,
#    'block_timestamp': '2024-03-08T06:42:12Z',
#    'delta': '1541190900000000',
#    'transaction_hash': '0xadd540d3a0826724e62674c030a6ebf5650cbc21641598fd41fad1ed1ab6951a',
#    'value': '1196368850549786554'},
#   {'block_number': 189353968,
#    'block_timestamp': '2024-03-07T02:16:00Z',
#    'delta': '72279691490000000',
#    'transaction_hash': '0x4eda3e26357fb92c3dcaa303335be958ac24d299c26f7dfd4b9a70c51869bd9b',
#    'value': '1194827659649786554'},
#   {'block_number': 115307821,
#    'block_timestamp': '2023-07-27T02:02:05Z',
#    'delta': '1122547968159786554',
#    'transaction_hash': '0x42e8aa2da0c65142103a42e9be43f30575b054a660db7afeb82a7303f1d04aeb',
#    'value': '1122547968159786554'}],
#  'next_page_params': None}

# %%
eth_rest.get_token_balances_with_filtering(address = vitalik_addr)
# Out:
# url: https://arbitrum.blockscout.com/api/v2/addresses/0xd8da6bf26964af9d7eed9e03e53415d37aa96045/tokens/?/type=ERC-20%2CERC-721%2CERC-1155
# {'items': [{'token': {'address': '0xd2199c6594a48EbebE53637097356a757d19A948',
#     'circulating_market_cap': None,
#     'decimals': '18',
#     'exchange_rate': None,
#     'holders': '243',
#     'icon_url': None,
#     'name': 'AISHIB',
#     'symbol': 'AISHIB',
#     'total_supply': '7777777777777777000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': None},
#    'token_id': None,
#    'token_instance': None,
#    'value': '3333333333333333000000000000000000'},
#   {'token': {'address': '0x69fC12D1DEDC8AC2eC256586581b66ADB75A091F',
#     'circulating_market_cap': None,
#     'decimals': '18',
#     'exchange_rate': None,
#     'holders': '1',
#     'icon_url': None,
#     'name': 'Eugene',
#     'symbol': 'GENE',
#     'total_supply': '1000000000000000000000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': None},
#    'token_id': None,
#    'token_instance': None,
#    'value': '1000000000000000000000000000000000'},
#   {'token': {'address': '0xF7e5a6507f9CCe578797BF110cD0ca1D41Ca7dcE',
#     'circulating_market_cap': None,
#     'decimals': '18',
#     'exchange_rate': None,
#     'holders': '3',
#     'icon_url': None,
#     'name': 'AIPepe Token',
#     'symbol': 'APP',
#     'total_supply': '100000000000000000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': None},
#    'token_id': None,
#    'token_instance': None,
#    'value': '89100000000000000000000000000000'},
#   {'token': {'address': '0x7c78FEF81b99116827BC31695E9E83Ab70868CBD',
#     'circulating_market_cap': None,
#     'decimals': '18',
#     'exchange_rate': None,
#     'holders': '1',
#     'icon_url': None,
#     'name': 'FOMO',
#     'symbol': 'FOMO',
#     'total_supply': '2000000000000000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': None},
#    'token_id': None,
#    'token_instance': None,
#    'value': '156816055362591644495745783635'},
#   {'token': {'address': '0xB0B069003E6766621bF3dcB3ccc6F12eF935B222',
#     'circulating_market_cap': None,
#     'decimals': '18',
#     'exchange_rate': None,
#     'holders': '15',
#     'icon_url': None,
#     'name': 'BOBO',
#     'symbol': 'BOBO',
#     'total_supply': '6900000000000000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': None},
#    'token_id': None,
#    'token_instance': None,
#    'value': '82300699091590908151581022236'},
#   {'token': {'address': '0xA11A00cCFD8282b635B26c53462B380fE0944B84',
#     'circulating_market_cap': None,
#     'decimals': '18',
#     'exchange_rate': None,
#     'holders': '4',
#     'icon_url': None,
#     'name': 'Anaconda',
#     'symbol': 'ANACONDA',
#     'total_supply': '1000000000000000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': None},
#    'token_id': None,
#    'token_instance': None,
#    'value': '61824854558783104287414724320'},
#   {'token': {'address': '0xbBC3b20B083E1434A1e96D82a21385b2b36b408A',
#     'circulating_market_cap': None,
#     'decimals': '18',
#     'exchange_rate': None,
#     'holders': '481',
#     'icon_url': None,
#     'name': 'MoyeMoye',
#     'symbol': 'MoyeMoye',
#     'total_supply': '999990000000000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': None},
#    'token_id': None,
#    'token_instance': None,
#    'value': '60000000000000000000000000000'},
#   {'token': {'address': '0x45e6f50977b176462cF126113Bd1E9Ac0a10a390',
#     'circulating_market_cap': None,
#     'decimals': '18',
#     'exchange_rate': None,
#     'holders': '1',
#     'icon_url': None,
#     'name': 'Joker Pepe',
#     'symbol': 'PEPER',
#     'total_supply': '8888888888888888888000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': None},
#    'token_id': None,
#    'token_instance': None,
#    'value': '44444444444000000000000000000'},
#   {'token': {'address': '0xAB0BAa84790708E36D37e20efd659C186ff16a46',
#     'circulating_market_cap': None,
#     'decimals': '18',
#     'exchange_rate': None,
#     'holders': '4',
#     'icon_url': None,
#     'name': 'AB0BA',
#     'symbol': 'AB0BA',
#     'total_supply': '1111111111000000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': None},
#    'token_id': None,
#    'token_instance': None,
#    'value': '39766983965192662681951651057'},
#   {'token': {'address': '0xD76D501196240611208aD0663bf1B960BcB58E68',
#     'circulating_market_cap': None,
#     'decimals': '18',
#     'exchange_rate': None,
#     'holders': '16',
#     'icon_url': None,
#     'name': 'PIG',
#     'symbol': 'PIG',
#     'total_supply': '1000000000000000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': None},
#    'token_id': None,
#    'token_instance': None,
#    'value': '28264016210911155467139945005'},
#   {'token': {'address': '0x8b1261b1400F42beB37Bce5C86B5a51613E345eD',
#     'circulating_market_cap': None,
#     'decimals': '18',
#     'exchange_rate': None,
#     'holders': '1',
#     'icon_url': None,
#     'name': 'CRUSH',
#     'symbol': 'CRUSH',
#     'total_supply': '1000000000000000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': None},
#    'token_id': None,
#    'token_instance': None,
#    'value': '17931341202060647458641593112'},
#   {'token': {'address': '0x3D939263814e2E53F7A7893087AAe5cf5B3078B1',
#     'circulating_market_cap': None,
#     'decimals': '18',
#     'exchange_rate': None,
#     'holders': '3',
#     'icon_url': None,
#     'name': 'SOK',
#     'symbol': 'SOK',
#     'total_supply': '1000000000000000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': None},
#    'token_id': None,
#    'token_instance': None,
#    'value': '14673209819699590650728267048'},
#   {'token': {'address': '0x28a6D983C011a8f147592F596c40ebf6FEADa845',
#     'circulating_market_cap': None,
#     'decimals': '18',
#     'exchange_rate': None,
#     'holders': '7',
#     'icon_url': None,
#     'name': 'PEPEK',
#     'symbol': 'PEPEK',
#     'total_supply': '1000000000000000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': None},
#    'token_id': None,
#    'token_instance': None,
#    'value': '10134176412304354828720509499'},
#   {'token': {'address': '0xb6bc09a70E522291c146f734bF3336b07deD653D',
#     'circulating_market_cap': None,
#     'decimals': '18',
#     'exchange_rate': None,
#     'holders': '7',
#     'icon_url': None,
#     'name': 'Wuff Inu',
#     'symbol': 'WUFF',
#     'total_supply': '99974604856597059999995323842',
#     'type': 'ERC-20',
#     'volume_24h': None},
#    'token_id': None,
#    'token_instance': None,
#    'value': '10000000000000000000000000000'},
#   {'token': {'address': '0x2bcC8C2b0b04189ba19e536f0fBb6cc44b0FEe70',
#     'circulating_market_cap': None,
#     'decimals': '18',
#     'exchange_rate': None,
#     'holders': '3',
#     'icon_url': None,
#     'name': 'KaboChan',
#     'symbol': 'KABO',
#     'total_supply': '1000000000000000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': None},
#    'token_id': None,
#    'token_instance': None,
#    'value': '10000000000000000000000000000'},
#   {'token': {'address': '0xCAD2f49234F2Bb45472602bBB622A8C754ddb40A',
#     'circulating_market_cap': None,
#     'decimals': '18',
#     'exchange_rate': None,
#     'holders': '34',
#     'icon_url': None,
#     'name': 'Nyan Cat',
#     'symbol': 'Nyan Cat',
#     'total_supply': '1000000000000000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': None},
#    'token_id': None,
#    'token_instance': None,
#    'value': '5464369091808805555636235696'},
#   {'token': {'address': '0xce12bB556677709Afb58347A9Ad38C8503c8288A',
#     'circulating_market_cap': None,
#     'decimals': '18',
#     'exchange_rate': None,
#     'holders': '201594',
#     'icon_url': None,
#     'name': 'MirthMoney',
#     'symbol': 'MIRTH',
#     'total_supply': '1000000000000000000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': None},
#    'token_id': None,
#    'token_instance': None,
#    'value': '2098470739000000000000000000'},
#   {'token': {'address': '0x2CBaA177641E4B90CFc35ea9adf5bF1DCF2883f4',
#     'circulating_market_cap': None,
#     'decimals': '18',
#     'exchange_rate': None,
#     'holders': '38',
#     'icon_url': None,
#     'name': 'LADYPEPE',
#     'symbol': 'LADYPEPE',
#     'total_supply': '100000000000000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': None},
#    'token_id': None,
#    'token_instance': None,
#    'value': '1738307577881203005014502366'},
#   {'token': {'address': '0x5dF59c7A276d5deDc4AeBbe349E5339123896D63',
#     'circulating_market_cap': None,
#     'decimals': '18',
#     'exchange_rate': None,
#     'holders': '9',
#     'icon_url': None,
#     'name': 'Pepe Labs Token',
#     'symbol': 'PEPEL',
#     'total_supply': '100000000000000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': None},
#    'token_id': None,
#    'token_instance': None,
#    'value': '1695773281545502324611910963'},
#   {'token': {'address': '0xd709dB3292021c93B13E401e75c0A0CF0cdeF650',
#     'circulating_market_cap': None,
#     'decimals': '18',
#     'exchange_rate': None,
#     'holders': '166',
#     'icon_url': None,
#     'name': 'OVER',
#     'symbol': 'OVER',
#     'total_supply': '1991000000000000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': None},
#    'token_id': None,
#    'token_instance': None,
#    'value': '1308579581032156000000000000'},
#   {'token': {'address': '0x5b1e6438FF767E5870ff5A159D79bc3F02070c5D',
#     'circulating_market_cap': None,
#     'decimals': '18',
#     'exchange_rate': None,
#     'holders': '63',
#     'icon_url': None,
#     'name': 'MRPEPE',
#     'symbol': 'MRPEPE',
#     'total_supply': '100000000000000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': None},
#    'token_id': None,
#    'token_instance': None,
#    'value': '1210208843194225323885432166'},
#   {'token': {'address': '0x3d036B0022f953FE7649Ca59607DeB8084a2aE90',
#     'circulating_market_cap': None,
#     'decimals': '18',
#     'exchange_rate': None,
#     'holders': '8',
#     'icon_url': None,
#     'name': 'Squid Pepe Token',
#     'symbol': 'SPEPE',
#     'total_supply': '100000000000000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': None},
#    'token_id': None,
#    'token_instance': None,
#    'value': '969338398889519885119171731'},
#   {'token': {'address': '0x5ea2aF7ca05d0Dc5AC0d908F75dFcde9Bb9E572c',
#     'circulating_market_cap': None,
#     'decimals': '18',
#     'exchange_rate': None,
#     'holders': '4',
#     'icon_url': None,
#     'name': 'MemeLand',
#     'symbol': 'MemeLand',
#     'total_supply': '100000000000000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': None},
#    'token_id': None,
#    'token_instance': None,
#    'value': '660857985564195674400294311'},
#   {'token': {'address': '0x6aDf04b7B6E131CF26459dfe72321Ba15baC8Ad5',
#     'circulating_market_cap': None,
#     'decimals': '18',
#     'exchange_rate': None,
#     'holders': '23',
#     'icon_url': None,
#     'name': 'FUN',
#     'symbol': 'FUN',
#     'total_supply': '100000000000000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': None},
#    'token_id': None,
#    'token_instance': None,
#    'value': '452198317564053735441462623'},
#   {'token': {'address': '0xa9A9677C930Fb2Fb7370f0Ea45418E9d61Cf70B6',
#     'circulating_market_cap': None,
#     'decimals': '18',
#     'exchange_rate': None,
#     'holders': '5',
#     'icon_url': None,
#     'name': 'Milady',
#     'symbol': 'LADYS',
#     'total_supply': '100000000000000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': None},
#    'token_id': None,
#    'token_instance': None,
#    'value': '357136488011781301234793175'},
#   {'token': {'address': '0xEf811Ec6B9FD225d5f11c2c7b118008Fde8582bc',
#     'circulating_market_cap': None,
#     'decimals': '18',
#     'exchange_rate': None,
#     'holders': '5',
#     'icon_url': None,
#     'name': 'McPEPE',
#     'symbol': 'MCPEPE',
#     'total_supply': '69420000000000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': None},
#    'token_id': None,
#    'token_instance': None,
#    'value': '208280000000000000000000000'},
#   {'token': {'address': '0x18408939f3940d7F1c3449021d47D3F3dd29cfC1',
#     'circulating_market_cap': None,
#     'decimals': '18',
#     'exchange_rate': None,
#     'holders': '56',
#     'icon_url': None,
#     'name': 'Dogshit',
#     'symbol': 'Dogshit',
#     'total_supply': '150000000000000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': None},
#    'token_id': None,
#    'token_instance': None,
#    'value': '200000000000000000000000000'},
#   {'token': {'address': '0xE64368CdaD8BC3195088c6f706a272b772da52E1',
#     'circulating_market_cap': None,
#     'decimals': '18',
#     'exchange_rate': None,
#     'holders': '7',
#     'icon_url': None,
#     'name': 'LK-99',
#     'symbol': 'LK99',
#     'total_supply': '1000000000000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': None},
#    'token_id': None,
#    'token_instance': None,
#    'value': '60000000000000000000000000'},
#   {'token': {'address': '0xA0A0A08a7c150e80d103778e70eF9E905e306990',
#     'circulating_market_cap': None,
#     'decimals': '18',
#     'exchange_rate': None,
#     'holders': '3',
#     'icon_url': None,
#     'name': 'KINGPEPE',
#     'symbol': 'KINGPEPE',
#     'total_supply': '1000000000000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': None},
#    'token_id': None,
#    'token_instance': None,
#    'value': '54856290528729362174010128'},
#   {'token': {'address': '0x59352E26Dc90568D85DA39a449717C6EE9d8fd81',
#     'circulating_market_cap': None,
#     'decimals': '18',
#     'exchange_rate': None,
#     'holders': '15',
#     'icon_url': None,
#     'name': 'Diamond',
#     'symbol': 'DD',
#     'total_supply': '100000000000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': None},
#    'token_id': None,
#    'token_instance': None,
#    'value': '50000000000000000000000000'},
#   {'token': {'address': '0x985bb1ba1004845e2D4dbA045914054b9E9F7AAA',
#     'circulating_market_cap': None,
#     'decimals': '18',
#     'exchange_rate': None,
#     'holders': '3',
#     'icon_url': None,
#     'name': 'PepeKing',
#     'symbol': 'PepeKing',
#     'total_supply': '100000000000000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': None},
#    'token_id': None,
#    'token_instance': None,
#    'value': '37627856382908712161429002'},
#   {'token': {'address': '0x0C3455feCdf7B73D75EFE832beaAA32cE55Dd5db',
#     'circulating_market_cap': None,
#     'decimals': '18',
#     'exchange_rate': None,
#     'holders': '24',
#     'icon_url': None,
#     'name': 'ArbNothing',
#     'symbol': 'Nothing',
#     'total_supply': '100000000000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': None},
#    'token_id': None,
#    'token_instance': None,
#    'value': '10000000000000000000000000'},
#   {'token': {'address': '0x676F7ED2D4829460f73468b36Be49e0D6505107F',
#     'circulating_market_cap': None,
#     'decimals': '18',
#     'exchange_rate': None,
#     'holders': '284',
#     'icon_url': None,
#     'name': 'Toob',
#     'symbol': 'TOOB',
#     'total_supply': '10000000000000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': None},
#    'token_id': None,
#    'token_instance': None,
#    'value': '10000000000000000000000000'},
#   {'token': {'address': '0xECb074A3d46013e89036f7D68816EE2c4390CB1d',
#     'circulating_market_cap': None,
#     'decimals': '18',
#     'exchange_rate': None,
#     'holders': '1',
#     'icon_url': None,
#     'name': 'CyberTruckToken',
#     'symbol': 'CYBTRX',
#     'total_supply': '900000000000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': None},
#    'token_id': None,
#    'token_instance': None,
#    'value': '5000000000000000000000000'},
#   {'token': {'address': '0xD2F8B81CFFf297c70E5d58aC58762Dd5D213EA20',
#     'circulating_market_cap': None,
#     'decimals': '18',
#     'exchange_rate': None,
#     'holders': '124',
#     'icon_url': 'https://assets.coingecko.com/coins/images/29111/small/IMG_20230217_063445_776.png?1696528073',
#     'name': 'artGPT',
#     'symbol': 'AGPT',
#     'total_supply': '1000000000000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': None},
#    'token_id': None,
#    'token_instance': None,
#    'value': '2990529000000000000000000'},
#   {'token': {'address': '0xD437951E3BD95A43dcB7F86228c3B08aC8531d38',
#     'circulating_market_cap': None,
#     'decimals': '18',
#     'exchange_rate': None,
#     'holders': '7',
#     'icon_url': None,
#     'name': 'BOLDBOTs Token',
#     'symbol': 'BOT',
#     'total_supply': '30415227000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': None},
#    'token_id': None,
#    'token_instance': None,
#    'value': '1500001000000000000000000'},
#   {'token': {'address': '0x7aba4CaA6632d3E64aDbaE0249717663c980A24C',
#     'circulating_market_cap': None,
#     'decimals': '18',
#     'exchange_rate': None,
#     'holders': '8',
#     'icon_url': None,
#     'name': 'ERC404',
#     'symbol': 'ERC404',
#     'total_supply': '10000000000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': None},
#    'token_id': None,
#    'token_instance': None,
#    'value': '999000000000000000000000'},
#   {'token': {'address': '0xeE0b14e8fC86691Cf6eE42B9954985B4cF968534',
#     'circulating_market_cap': None,
#     'decimals': '18',
#     'exchange_rate': None,
#     'holders': '1216',
#     'icon_url': 'https://assets.coingecko.com/coins/images/30269/small/panda.png?1696529176',
#     'name': 'ZenPandaCoin',
#     'symbol': 'ZPC',
#     'total_supply': '888888888888888000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': None},
#    'token_id': None,
#    'token_instance': None,
#    'value': '645616000000000000000000'},
#   {'token': {'address': '0x25d887Ce7a35172C62FeBFD67a1856F20FaEbB00',
#     'circulating_market_cap': None,
#     'decimals': '18',
#     'exchange_rate': None,
#     'holders': '7401',
#     'icon_url': 'https://assets.coingecko.com/coins/images/29850/small/pepe-token.jpeg?1696528776',
#     'name': 'Pepe',
#     'symbol': 'PEPE',
#     'total_supply': '303007543934856700000000000000',
#     'type': 'ERC-20',
#     'volume_24h': None},
#    'token_id': None,
#    'token_instance': None,
#    'value': '568013300780979859512338'},
#   {'token': {'address': '0x329c332888007550deC321308249d85E9c5707d3',
#     'circulating_market_cap': None,
#     'decimals': '18',
#     'exchange_rate': None,
#     'holders': '3',
#     'icon_url': None,
#     'name': 'Manta Pacific: DAO Token',
#     'symbol': 'MPDao',
#     'total_supply': '36500000000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': None},
#    'token_id': None,
#    'token_instance': None,
#    'value': '500000000000000000000000'},
#   {'token': {'address': '0x2d1Cd95648D95619B826317876b74244eAeBbaa2',
#     'circulating_market_cap': None,
#     'decimals': '18',
#     'exchange_rate': None,
#     'holders': '24',
#     'icon_url': None,
#     'name': 'BabyCatCoin',
#     'symbol': 'BCAT',
#     'total_supply': '1000000000000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': None},
#    'token_id': None,
#    'token_instance': None,
#    'value': '475000000000000000000000'},
#   {'token': {'address': '0x7023B00c52B346d4a565e35a6A66487E839A64b9',
#     'circulating_market_cap': None,
#     'decimals': '18',
#     'exchange_rate': None,
#     'holders': '1',
#     'icon_url': None,
#     'name': 'LADYS',
#     'symbol': 'Milady Meme Coin',
#     'total_supply': '1000000000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': None},
#    'token_id': None,
#    'token_instance': None,
#    'value': '300000000000000000000000'},
#   {'token': {'address': '0x963836176Acbe0C41b7974F9d04BDEB7155C73c3',
#     'circulating_market_cap': None,
#     'decimals': '18',
#     'exchange_rate': None,
#     'holders': '1',
#     'icon_url': None,
#     'name': 'HotFart',
#     'symbol': 'HFRT',
#     'total_supply': '5600000000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': None},
#    'token_id': None,
#    'token_instance': None,
#    'value': '200000000000000000000000'},
#   {'token': {'address': '0xDc8A726Fe81d6561661a85BF4C8Aa39cF2026a76',
#     'circulating_market_cap': None,
#     'decimals': '18',
#     'exchange_rate': None,
#     'holders': '9',
#     'icon_url': None,
#     'name': 'Baby Crab',
#     'symbol': 'BBC',
#     'total_supply': '10000000000000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': None},
#    'token_id': None,
#    'token_instance': None,
#    'value': '130609102995897600451444'},
#   {'token': {'address': '0x8f41A4F73f9212138Add303B7feF8d0Bf5151988',
#     'circulating_market_cap': None,
#     'decimals': '18',
#     'exchange_rate': None,
#     'holders': '2',
#     'icon_url': None,
#     'name': 'AERC',
#     'symbol': 'AERC',
#     'total_supply': '21000000000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': None},
#    'token_id': None,
#    'token_instance': None,
#    'value': '105000000000000000000000'},
#   {'token': {'address': '0x9634b3B92adcc18a1A926Bc7AD6CBBd486528719',
#     'circulating_market_cap': None,
#     'decimals': '18',
#     'exchange_rate': None,
#     'holders': '1',
#     'icon_url': None,
#     'name': 'AERC',
#     'symbol': 'AERC',
#     'total_supply': '21000000000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': None},
#    'token_id': None,
#    'token_instance': None,
#    'value': '105000000000000000000000'},
#   {'token': {'address': '0xfC15a6B79B58b727fCfdaf41E1c6CF04A5419e7e',
#     'circulating_market_cap': None,
#     'decimals': '18',
#     'exchange_rate': None,
#     'holders': '2',
#     'icon_url': None,
#     'name': 'Reliable ERC20',
#     'symbol': 'rerc',
#     'total_supply': '21000000000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': None},
#    'token_id': None,
#    'token_instance': None,
#    'value': '105000000000000000000000'},
#   {'token': {'address': '0x9E419A3543B5FEF68Eb5611E864fA89f9DcCB335',
#     'circulating_market_cap': None,
#     'decimals': '18',
#     'exchange_rate': None,
#     'holders': '2',
#     'icon_url': None,
#     'name': 'Reliable ERC20',
#     'symbol': 'rerc',
#     'total_supply': '21000000000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': None},
#    'token_id': None,
#    'token_instance': None,
#    'value': '105000000000000000000000'},
#   {'token': {'address': '0x9AD7dF31A95F4BCd360841AbFf6B9445fD0C10e6',
#     'circulating_market_cap': None,
#     'decimals': '18',
#     'exchange_rate': None,
#     'holders': '6',
#     'icon_url': None,
#     'name': 'Come On ERC20',
#     'symbol': 'cerc',
#     'total_supply': '21000000000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': None},
#    'token_id': None,
#    'token_instance': None,
#    'value': '105000000000000000000000'},
#   {'token': {'address': '0x71522F28FFE0D845A2b09F1b978B48fF3c51032c',
#     'circulating_market_cap': None,
#     'decimals': '18',
#     'exchange_rate': None,
#     'holders': '3',
#     'icon_url': None,
#     'name': 'RadiantButthole',
#     'symbol': 'RDNTBUTTHOLE',
#     'total_supply': '69420000000000000000000000',
#     'type': 'ERC-20',
#     'volume_24h': None},
#    'token_id': None,
#    'token_instance': None,
#    'value': '100000000000000000000000'}],
#  'next_page_params': {'/type': 'ERC-20,ERC-721,ERC-1155',
#   'fiat_value': None,
#   'id': 137464585,
#   'items_count': 50,
#   'value': '100000000000000000000000'}}

# %%
#eth_rest.get_token_balances(address = vitalik_addr)

# %%
eth_rest.get_blocks_validated(address = usdc_addr)
# Out:
# url: https://arbitrum.blockscout.com/api/v2/addresses/0xaf88d065e77c8cC2239327C5EDb3A432268e5831/blocks-validated
# {'items': [], 'next_page_params': None}

# %%
eth_rest.get_address_logs(address = vitalik_addr)
# Out:
# url: https://arbitrum.blockscout.com/api/v2/addresses/0xd8da6bf26964af9d7eed9e03e53415d37aa96045/logs
# {'items': [], 'next_page_params': None}

# %%
#eth_rest.get_address_transactions(address = vitalik_addr)

# %%
eth_rest.get_address_counters(address = vitalik_addr)
# Out:
# url: https://arbitrum.blockscout.com/api/v2/addresses/0xd8da6bf26964af9d7eed9e03e53415d37aa96045/counters
# {'transactions_count': '322',
#  'token_transfers_count': '2493',
#  'gas_usage_count': '1670767',
#  'validations_count': '0'}

# %%
eth_rest.get_address_info(address = vitalik_addr)
# Out:
# url: https://arbitrum.blockscout.com/api/v2/addresses/0xd8da6bf26964af9d7eed9e03e53415d37aa96045
# {'block_number_balance_updated_at': 236024418,
#  'coin_balance': '831233364322485060',
#  'creation_tx_hash': None,
#  'creator_address_hash': None,
#  'ens_domain_name': None,
#  'exchange_rate': '3154.65',
#  'has_beacon_chain_withdrawals': False,
#  'has_decompiled_code': False,
#  'has_logs': False,
#  'has_token_transfers': True,
#  'has_tokens': True,
#  'has_validated_blocks': False,
#  'hash': '0xd8dA6BF26964aF9D7eEd9e03E53415D37aA96045',
#  'implementations': [],
#  'is_contract': False,
#  'is_verified': False,
#  'metadata': None,
#  'name': None,
#  'private_tags': [],
#  'public_tags': [],
#  'token': None,
#  'watchlist_address_id': None,
#  'watchlist_names': []}
