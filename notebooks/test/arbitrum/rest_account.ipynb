# %%
from blockscout import Blockscout
from blockscout import TokenTransfers
from blockscout import Net
from blockscout import API

eth_rest = Blockscout(Net.ARB, API.REST)

# %%
eth_rest.get_addresses()
# Out:
# url: https://arbitrum.blockscout.com/api/v2/addresses
# {'items': [{'coin_balance': '886318064107903714203406',
#    'tx_count': '368',
#    'ens_domain_name': None,
#    'hash': '0xF977814e90dA44bFA03b6295A0616a897441aceC',
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': {'tags': [{'meta': {},
#       'name': 'Binance 8',
#       'ordinal': 10,
#       'slug': 'binance-8',
#       'tagType': 'name'}]},
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '254600409650941365463706',
#    'tx_count': '3867935',
#    'ens_domain_name': None,
#    'hash': '0x82aF49447D8a07e3bd95BD0d56f35241523fBab1',
#    'implementations': [{'address': '0x8b194bEae1d3e0788A1a35173978001ACDFba668',
#      'name': None}],
#    'is_contract': True,
#    'is_verified': True,
#    'metadata': None,
#    'name': 'TransparentUpgradeableProxy',
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '215982998306834304645880',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x5a52E96BAcdaBb82fd05763E25335261B270Efcb',
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': {'tags': [{'meta': {},
#       'name': 'Binance 28',
#       'ordinal': 10,
#       'slug': 'binance-28',
#       'tagType': 'name'}]},
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '55076385182290408019984',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x490b1E689Ca23be864e55B46bf038e007b528208',
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '50148229298820373693053',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0xf89d7b9c864f589bbF53a82105107622B35EaA40',
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '29364799338525073972026',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0xB38e8c17e38363aF6EbdCb3dAE12e0243582891D',
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '28000104142699344179760',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x131F001aF400D5f212e1894846469FBa70f8bCc9',
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '26000107143713090679760',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x05fb32C26103f6b58343a58009f2424c388c17E0',
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '14160325781426320889760',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0xbFc1FECa8B09A5c5D3EFfE7429eBE24b9c09EF58',
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '9181195244860659142893',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0xD20E007881ea62B5922B06D025c9dc1D41962953',
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '8233904043353622879546',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x3701F04E25b57e549A2a348C18e2d925C2805602',
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '6164005830254477301396',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0xf92402bB795Fd7CD08fb83839689DB79099C8c9C',
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '5615730493653311441000',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x3931dAb967C3E2dbb492FE12460a66d0fe4cC857',
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '5208513982138403920778',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x205bA210b80dE3b3cedf1243D4718F92CB674d01',
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '4138071298453579032694',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x1B5B4e441F5A22bfd91B7772C780463F66A74b35',
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '3982245863322071701527',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0xA45B5130f36CDcA45667738e2a258AB09f4A5f7F',
#    'implementations': [],
#    'is_contract': True,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '3925929863297553897000',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x25681Ab599B4E2CEea31F8B498052c53FC2D74db',
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '3736104820145943087304',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x3727cfCBD85390Bb11B3fF421878123AdB866be8',
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '2834619000000000000000',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x3EA78Ac9769B199B3e961E41B35E495B04036B5a',
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '2833270000000000000000',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x3014Ab992464E3323D4b53570baDF782aC897a67',
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '2726019091130909658308',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x82CbeCF39bEe528B5476FE6d1550af59a9dB6Fc0',
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': 'Stargate Ether Vault',
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '2520020609577504216041',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x5bdf85216ec1e38D6458C870992A69e38e03F7Ef',
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': {'tags': [{'meta': {},
#       'name': 'Bitget 5',
#       'ordinal': 10,
#       'slug': 'bitget-5',
#       'tagType': 'name'}]},
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '2218017659710475097892',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x9223C017a39d4806d1D92c15046Ae28c32c6D8E7',
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '2039403778016753501440',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x03248f4759Ef5c4FdDd959aa07a5294e00B03e44',
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '1776110346257917525299',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x24f2bA8dbA81265ECF053cBAC410184ab38B2a92',
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '1631954784489235474892',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0xfD089cd44862Bb398CF50dEB577FeD9AeCcf016E',
#    'implementations': [],
#    'is_contract': True,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '1584029920725636980012',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0xEc9fC235A8064698A2533c2D489DEFF4fBA8226B',
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '1394899446932796828452',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0xa4b1E63Cb4901E327597bc35d36FE8a23e4C253f',
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '1317081447354218296003',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x1714400FF23dB4aF24F9fd64e7039e6597f18C2b',
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '1213996294821566812981',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x20fA1822A87D4e7A3CcF20f86e716Ef3772eCff1',
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '1187854854950891338136',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x02944e3Fb72AA13095d7cebd8389FC74Bec8e48e',
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '1067000665786220000000',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x835678a611B28684005a5e2233695fB6cbbB0007',
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '1002455954019867360389',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0xd3D3a295bE556Cf8cef2a7FF4cda23D22c4627E8',
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '979587657196780000000',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x86a05B13C6b231cdf25DBD961423572881D9A6f0',
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '977414391098016516301',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x524fF34BCD36f84FEc741dE25240914B9D71D143',
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '924755022725127614094',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x36A5732960513AD26a99E2Bd6159dfF2AB94A678',
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '909516692318122453543',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x2a45907f94df93388801AE72fE810eac75926a1d',
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '896073504006324399186',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x92a4e0C461378C626B6AA1B31cB1322aD2b503a2',
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '895073836689432715881',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0xA60113f7d43130919802b0863abdCdb956664fD5',
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '879028938485547480277',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0xe88AB6Fa7F02C3ED96985dE5e50Cca7CEeA54D4e',
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '873780863433100000000',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x1620B350EfE80369EEF719bD6F3082381E5dBcf2',
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '861060025822874616085',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x7a560269480Ef38B885526C8bBecdc4686d8bF7A',
#    'implementations': [],
#    'is_contract': True,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '833902330000000000000',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x4fA267532A1eAEf8C6Bad9Ec43faab7D52c7DcF0',
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '823913021543504758725',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x4207837D4Cd914467EB76bf88c4d6e7Ba11ccDf9',
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '803046963999999999999',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0x42139DCb61bE30220A134c84F78272F9AeF4C7dB',
#    'implementations': [],
#    'is_contract': True,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '798582217216532500000',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0xFCF7248C495d6fd3641eE43F861c48Ebe402c878',
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '796983584180380051592',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0xb86f1061E0D79E8319339d5FDbb187D4E7Ad3300',
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '782940149786555635198',
#    'tx_count': '5671',
#    'ens_domain_name': None,
#    'hash': '0x77134cbC06cB00b66F4c7e623D5fdBF6777635EC',
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': {'tags': [{'meta': {},
#       'name': 'Bitfinex: Hot Wallet',
#       'ordinal': 10,
#       'slug': 'bitfinex-hot-wallet',
#       'tagType': 'name'}]},
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '768039186682160000000',
#    'tx_count': '',
#    'ens_domain_name': None,
#    'hash': '0xAbCED91E3A95CdCbb54679102BD8b116098c2E09',
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   {'coin_balance': '753190034243064022061',
#    'tx_count': '0',
#    'ens_domain_name': None,
#    'hash': '0x52Aa899454998Be5b000Ad077a46Bbe360F4e497',
#    'implementations': [{'address': '0x102a42aa1F6BEA5c9eC200B95AFbf928ae4b855b',
#      'name': None}],
#    'is_contract': True,
#    'is_verified': True,
#    'metadata': None,
#    'name': 'FluidLiquidityProxy',
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []}],
#  'total_supply': '0.0',
#  'exchange_rate': '3143.25',
#  'next_page_params': {'fetched_coin_balance': '753190034243064022061',
#   'hash': '0x52aa899454998be5b000ad077a46bbe360f4e497',
#   'items_count': 50}}

# %%
eth_rest.get_coin_balance_history_by_day(address = '0x8A4AA176007196D48d39C89402d3753c39AE64c1')

# %%
#eth_rest.get_coin_balance_history(address = '0x8A4AA176007196D48d39C89402d3753c39AE64c1')

# %%
eth_rest.get_token_balances_with_filtering(address = '0x48023b16c3e81AA7F6eFFbdEB35Bb83f4f31a8fd')

# %%
eth_rest.get_token_balances(address = '0x8A4AA176007196D48d39C89402d3753c39AE64c1')

# %%
#eth_rest.get_blocks_validated(address = '0x4200000000000000000000000000000000000011')

# %%
#eth_rest.get_address_logs(address = '0x48023b16c3e81AA7F6eFFbdEB35Bb83f4f31a8fd')

# %%
#eth_rest.get_address_transactions(address = '0x8A4AA176007196D48d39C89402d3753c39AE64c1')

# %%
eth_rest.get_address_counters(address = '0x8A4AA176007196D48d39C89402d3753c39AE64c1')

# %%
eth_rest.get_address_info(address = '0x8A4AA176007196D48d39C89402d3753c39AE64c1')
