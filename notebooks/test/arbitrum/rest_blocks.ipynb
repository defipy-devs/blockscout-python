# %%
from blockscout import Blockscout
from blockscout import Net
from blockscout import API

vitalik_addr = '0xd8da6bf26964af9d7eed9e03e53415d37aa96045'
usdc_addr = '0xaf88d065e77c8cC2239327C5EDb3A432268e5831'

eth_rest = Blockscout(Net.ARB, API.REST)

# %%
eth_rest.get_main_page_blocks()
# Out:
# url: https://arbitrum.blockscout.com/api/v2/main-page/blocks
# [{'base_fee_per_gas': '10000000',
#   'burnt_fees': '321050000000',
#   'burnt_fees_percentage': 100.0,
#   'difficulty': '1',
#   'gas_limit': '1125899906842624',
#   'gas_target_percentage': -99.999999994297,
#   'gas_used': '32105',
#   'gas_used_percentage': 2.851496816447252e-09,
#   'hash': '0x67b56879da6a1b5545609d1ecd951ecf021866c60a9a18c1168d6ac982572158',
#   'height': 236026105,
#   'miner': {'ens_domain_name': None,
#    'hash': '0xA4b000000000000000000073657175656e636572',
#    'implementations': [],
#    'is_contract': False,
#    'is_verified': False,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   'nonce': '0x000000000018cf68',
#   'parent_hash': '0x086a17ea8ebe92370586f310dd885cc54858ac855480f31288322944fcf9bc1c',
#   'priority_fee': '0',
#   'rewards': [],
#   'size': 807,
#   'timestamp': '2024-07-25T21:11:34.000000Z',
# ...

# %%
eth_rest.get_block_withdrawals(block_number = "236025318")
# Out:
# url: https://arbitrum.blockscout.com/api/v2/blocks/236025318/withdrawals
# {'items': [], 'next_page_params': None}

# %%
eth_rest.get_block_transactions(block_number = "236025318")
# Out:
# url: https://arbitrum.blockscout.com/api/v2/blocks/236025318/transactions
# {'items': [{'timestamp': '2024-07-25T21:08:17.000000Z',
#    'fee': {'type': 'actual', 'value': '0'},
#    'gas_limit': '0',
#    'block': 236025318,
#    'status': 'ok',
#    'method': 'startBlock',
#    'confirmations': 886,
#    'type': 106,
#    'exchange_rate': '3154.65',
#    'to': {'ens_domain_name': None,
#     'hash': '0x00000000000000000000000000000000000A4B05',
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'ArbOS',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'tx_burnt_fee': None,
#    'max_fee_per_gas': None,
#    'result': 'success',
#    'hash': '0x155d1cdee9808b154c7b1d830143266499b2b38b00c18dec5360344dca4e0fd2',
#    'gas_price': '10000000',
#    'priority_fee': None,
#    'base_fee_per_gas': '10000000',
#    'from': {'ens_domain_name': None,
# ...

# %%
eth_rest.get_block_info(block_number = "236025318")
# Out:
# url: https://arbitrum.blockscout.com/api/v2/blocks/236025318
# {'arbitrum': {'batch_data_container': 'in_blob4844',
#   'batch_number': 655901,
#   'commitment_transaction': {'hash': '0xaa345ab80151eb6e1560c7d42ed79e20de9ea52bea4d608af83526fdb2590d5b',
#    'status': 'unfinalized',
#    'timestamp': '2024-07-25T21:08:47.000000Z'},
#   'confirmation_transaction': {'hash': None,
#    'status': None,
#    'timestamp': None},
#   'delayed_messages': 1625953,
#   'l1_block_height': 20386148,
#   'send_count': 124945,
#   'send_root': '0x8292f00aced28bd88a3116392f8a21fe0591cf335aaab0e5156fb3e1faf37045',
#   'status': 'Sent to base'},
#  'base_fee_per_gas': '10000000',
#  'burnt_fees': '982770000000',
#  'burnt_fees_percentage': 100.0,
#  'difficulty': '1',
#  'gas_limit': '1125899906842624',
#  'gas_target_percentage': -99.9999999825425,
#  'gas_used': '98277',
#  'gas_used_percentage': 8.72875105528692e-09,
#  'hash': '0xee29d2796ab09a59115b2ee34ec6d8f2984242f7cf960c446d67892b02cef9f9',
# ...
