# %%
from blockscout import Blockscout
from blockscout import Net
from blockscout import API

vitalik_addr = '0xd8da6bf26964af9d7eed9e03e53415d37aa96045'
usdc_addr = '0x0b2C639c533813f4Aa9D7837CAf62653d097Ff85'

eth_rest = Blockscout(Net.OP, API.REST)

# %%
eth_rest.get_token_counters(address=usdc_addr)
# Out:
# url: https://optimism.blockscout.com/api/v2/tokens/0x0b2C639c533813f4Aa9D7837CAf62653d097Ff85/counters
# {'token_holders_count': '210756', 'transfers_count': '0'}

# %%
#eth_rest.get_token_holders(address=usdc_addr)

# %%
#eth_rest.get_token_transfers(address=usdc_addr)

# %%
eth_rest.get_token_info(address=usdc_addr)
# Out:
# url: https://optimism.blockscout.com/api/v2/tokens/0x0b2C639c533813f4Aa9D7837CAf62653d097Ff85
# {'address': '0x0b2C639c533813f4Aa9D7837CAf62653d097Ff85',
#  'circulating_market_cap': '33806257445.160835',
#  'decimals': '6',
#  'exchange_rate': '0.999486',
#  'holders': '210759',
#  'icon_url': 'https://assets.coingecko.com/coins/images/6319/small/usdc.png?1696506694',
#  'name': 'USD Coin',
#  'symbol': 'USDC',
#  'total_supply': '178308604247507',
#  'type': 'ERC-20',
#  'volume_24h': '8809553742.823599'}

# %%
eth_rest.get_tokens_list(token_name="USDC")
# Out:
# url: https://optimism.blockscout.com/api/v2/tokens?q=USDC&type=ERC-20%2CERC-721%2CERC-1155
# {'items': [{'address': '0x0b2C639c533813f4Aa9D7837CAf62653d097Ff85',
#    'circulating_market_cap': '33806257445.160835',
#    'decimals': '6',
#    'exchange_rate': '0.999486',
#    'holders': '210759',
#    'icon_url': 'https://assets.coingecko.com/coins/images/6319/small/usdc.png?1696506694',
#    'name': 'USD Coin',
#    'symbol': 'USDC',
#    'total_supply': '178308604247507',
#    'type': 'ERC-20',
#    'volume_24h': '8809553742.823599'},
#   {'address': '0x7F5c764cBc14f9669B88837ca1490cCa17c31607',
#    'circulating_market_cap': '0.0',
#    'decimals': '6',
#    'exchange_rate': '1.005',
#    'holders': '2293721',
#    'icon_url': 'https://assets.coingecko.com/coins/images/31580/small/USDC-icon.png?1696530397',
#    'name': 'USD Coin',
#    'symbol': 'USDC',
#    'total_supply': '132951291813715',
#    'type': 'ERC-20',
#    'volume_24h': '16924450.31028476'},
#   {'address': '0xEB466342C4d449BC9f53A865D5Cb90586f405215',
#    'circulating_market_cap': '0.0',
#    'decimals': '6',
#    'exchange_rate': '1.003',
#    'holders': '890',
#    'icon_url': 'https://assets.coingecko.com/coins/images/26476/small/uausdc_D_3x.png?1696525548',
#    'name': 'Axelar Wrapped USDC',
#    'symbol': 'axlUSDC',
#    'total_supply': '264366160320',
#    'type': 'ERC-20',
#    'volume_24h': '5544455.017113789'},
#   {'address': '0x81C9A7B55A4df39A9B7B5F781ec0e53539694873',
#    'circulating_market_cap': '0.0',
#    'decimals': '6',
#    'exchange_rate': '0.99998',
#    'holders': '1499',
#    'icon_url': 'https://assets.coingecko.com/coins/images/31175/small/ExaUSDC_1.png?1696530003',
#    'name': 'exactly USDC',
#    'symbol': 'exaUSDC',
#    'total_supply': '798157145186',
#    'type': 'ERC-20',
#    'volume_24h': '0.0'},
#   {'address': '0x625E7708f30cA75bfd92586e17077590C60eb4cD',
#    'circulating_market_cap': '0.0',
#    'decimals': '6',
#    'exchange_rate': '0.999888',
#    'holders': '37836',
#    'icon_url': 'https://assets.coingecko.com/coins/images/32847/small/usdc_%281%29.png?1699619355',
#    'name': 'Aave Optimism USDC',
#    'symbol': 'aOptUSDC',
#    'total_supply': '9109724995172',
#    'type': 'ERC-20',
#    'volume_24h': '1.5276264465413751'},
#   {'address': '0xDecC0c09c3B5f6e92EF4184125D5648a66E35298',
#    'circulating_market_cap': None,
#    'decimals': '6',
#    'exchange_rate': None,
#    'holders': '58328',
#    'icon_url': None,
#    'name': 'USD Coin-LP',
#    'symbol': 'S*USDC',
#    'total_supply': '4963921423370',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0x7A0FDDBA78FF45D353B1630B77f4D175A00df0c0',
#    'circulating_market_cap': None,
#    'decimals': '6',
#    'exchange_rate': None,
#    'holders': '38240',
#    'icon_url': None,
#    'name': 'Granary USDC',
#    'symbol': 'grainUSDC',
#    'total_supply': '283562267890',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0x8BCdeD0f36161aC1c58035a1fd03b632a50E8944',
#    'circulating_market_cap': None,
#    'decimals': '1',
#    'exchange_rate': None,
#    'holders': '33139',
#    'icon_url': None,
#    'name': '# usdc-airdrop.com',
#    'symbol': 'Visit usdc-airdrop.com to claim $USDC',
#    'total_supply': None,
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0xFCCf3cAbbe80101232d343252614b6A3eE81C989',
#    'circulating_market_cap': None,
#    'decimals': '6',
#    'exchange_rate': None,
#    'holders': '21286',
#    'icon_url': None,
#    'name': 'Aave Optimism Variable Debt USDC',
#    'symbol': 'variableDebtOptUSDC',
#    'total_supply': '6437762138348',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0x8430F084B939208E2eDEd1584889C9A66B90562f',
#    'circulating_market_cap': None,
#    'decimals': '18',
#    'exchange_rate': None,
#    'holders': '11302',
#    'icon_url': None,
#    'name': 'Super USD Coin',
#    'symbol': 'USDCx',
#    'total_supply': '51696685805000000000000',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0x38d693cE1dF5AaDF7bC62595A37D667aD57922e5',
#    'circulating_market_cap': None,
#    'decimals': '6',
#    'exchange_rate': None,
#    'holders': '6123',
#    'icon_url': None,
#    'name': 'Aave Optimism USDCn',
#    'symbol': 'aOptUSDCn',
#    'total_supply': '37623885636742',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0xbC26519f936A90E78fe2C9aA2A03CC208f041234',
#    'circulating_market_cap': None,
#    'decimals': '18',
#    'exchange_rate': None,
#    'holders': '5063',
#    'icon_url': None,
#    'name': 'StableV2 AMM - USDC/sUSD',
#    'symbol': 'sAMMV2-USDC/sUSD',
#    'total_supply': '828389844457',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0xb271973b367E50fcDE5Ee5e426944C37045Dd0bf',
#    'circulating_market_cap': None,
#    'decimals': '6',
#    'exchange_rate': None,
#    'holders': '4462',
#    'icon_url': None,
#    'name': 'Granary variable debt bearing USDC',
#    'symbol': 'variableDebtUSDC',
#    'total_supply': '183307917683',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0x72683E768d3dedbBb8B08e5526aA1ee56B21041C',
#    'circulating_market_cap': None,
#    'decimals': '18',
#    'exchange_rate': None,
#    'holders': '3405',
#    'icon_url': None,
#    'name': 'Moo Aave USDC',
#    'symbol': 'mooAaveUSDC',
#    'total_supply': '137441912162',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0x5D557B07776D12967914379C71a1310e917C7555',
#    'circulating_market_cap': None,
#    'decimals': '6',
#    'exchange_rate': None,
#    'holders': '3344',
#    'icon_url': None,
#    'name': 'Aave Optimism Variable Debt USDCn',
#    'symbol': 'variableDebtOptUSDCn',
#    'total_supply': '33204641694784',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0xB12A1Be740B99D845Af98098965af761be6BD7fE',
#    'circulating_market_cap': None,
#    'decimals': '18',
#    'exchange_rate': None,
#    'holders': '3118',
#    'icon_url': None,
#    'name': 'Connext USDC StableSwap LP',
#    'symbol': 'CUSDCLP',
#    'total_supply': '155045447529425894207359',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0x2e44e174f7D53F0212823acC11C01A11d58c5bCB',
#    'circulating_market_cap': None,
#    'decimals': '6',
#    'exchange_rate': None,
#    'holders': '2776',
#    'icon_url': None,
#    'name': 'Compound USDC',
#    'symbol': 'cUSDCv3',
#    'total_supply': '7318872496475',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0x2e17b8193566345a2Dd467183526dEdc42d2d5A8',
#    'circulating_market_cap': None,
#    'decimals': '18',
#    'exchange_rate': None,
#    'holders': '2323',
#    'icon_url': None,
#    'name': 'Hop USDC LP Token',
#    'symbol': 'HOP-LP-USDC',
#    'total_supply': '341436866501207939526628',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0x83b8391B9efBc5B5A38777fB22A4968c622a405a',
#    'circulating_market_cap': None,
#    'decimals': '18',
#    'exchange_rate': None,
#    'holders': '2214',
#    'icon_url': None,
#    'name': 'Velodrome v2 BLU-USDC.e Factory yVault',
#    'symbol': 'yvVelo-BLU-USDC.e-f',
#    'total_supply': '64772634863186802',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0xEC8FEa79026FfEd168cCf5C627c7f486D77b765F',
#    'circulating_market_cap': None,
#    'decimals': '8',
#    'exchange_rate': None,
#    'holders': '1702',
#    'icon_url': None,
#    'name': 'Sonne USDC',
#    'symbol': 'soUSDC',
#    'total_supply': '16456217334882899',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0x7F384ca61a0F3cEf9678ED93943A48A785921A63',
#    'circulating_market_cap': None,
#    'decimals': '18',
#    'exchange_rate': None,
#    'holders': '1483',
#    'icon_url': None,
#    'name': 'Moo VeloV2 USDC-wstETH',
#    'symbol': 'mooVeloV2USDC-wstETH',
#    'total_supply': '859649112716177',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0x8f9Ab50FC5C0d2EAD5953A2836D22E48e5788151',
#    'circulating_market_cap': None,
#    'decimals': '18',
#    'exchange_rate': None,
#    'holders': '1403',
#    'icon_url': None,
#    'name': 'Gelato Uniswap USDC/DAI LP',
#    'symbol': 'G-UNI',
#    'total_supply': '704627070892059717',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0xd2e32323686de92411639d446396AFA5E6149C28',
#    'circulating_market_cap': None,
#    'decimals': '6',
#    'exchange_rate': None,
#    'holders': '1370',
#    'icon_url': None,
#    'name': 'Metronome Synth USDC-Deposit',
#    'symbol': 'msdUSDC-1',
#    'total_supply': '173389372782',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0xaD17A225074191d5c8a37B50FdA1AE278a2EE6A2',
#    'circulating_market_cap': None,
#    'decimals': '6',
#    'exchange_rate': None,
#    'holders': '1187',
#    'icon_url': None,
#    'name': 'USDC.e yVault',
#    'symbol': 'yvUSDC.e',
#    'total_supply': '489966481726',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0xdAc8Ccf5E7Bf060eEad47Cdf5f64E200eE1a11e7',
#    'circulating_market_cap': None,
#    'decimals': '18',
#    'exchange_rate': None,
#    'holders': '1110',
#    'icon_url': None,
#    'name': 'Reward Cow Velo Op OP-USDC',
#    'symbol': 'rcowVeloOpOP-USDC',
#    'total_supply': '44124888546149726850793',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0xFfccf8C057A6f213b149A61FF91eec77EC56946E',
#    'circulating_market_cap': None,
#    'decimals': '6',
#    'exchange_rate': None,
#    'holders': '1106',
#    'icon_url': None,
#    'name': 'USD Coin',
#    'symbol': 'USDC',
#    'total_supply': '132951291813715',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0x078f65c0E854AB7Fa3BAa2cFf62A4F9cB4031382',
#    'circulating_market_cap': None,
#    'decimals': '18',
#    'exchange_rate': None,
#    'holders': '1020',
#    'icon_url': None,
#    'name': 'VolatileV1 AMM - USDC/DAI',
#    'symbol': 'vAMM-USDC/DAI',
#    'total_supply': '7840850585440615',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0x0495a700407975b2641Fa61Aef5Ccd0106F525Cc',
#    'circulating_market_cap': None,
#    'decimals': '18',
#    'exchange_rate': None,
#    'holders': '1018',
#    'icon_url': None,
#    'name': 'Moo Velo USDC-USDT',
#    'symbol': 'mooVeloUSDC-USDT',
#    'total_supply': '530061521',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0xA2A8B06aa9d211e02E1F8CEb7706aE8bF3362Dfb',
#    'circulating_market_cap': None,
#    'decimals': '18',
#    'exchange_rate': None,
#    'holders': '775',
#    'icon_url': None,
#    'name': 'Cow Uniswap Op USDC-OP',
#    'symbol': 'cowUniswapOpUSDC-OP',
#    'total_supply': '85099062234903047040877',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0x65eCE72Cc6Aad88432366DdD96b83AE62f8B1a71',
#    'circulating_market_cap': None,
#    'decimals': '18',
#    'exchange_rate': None,
#    'holders': '701',
#    'icon_url': None,
#    'name': 'Moo VeloV2 USDC-VELO',
#    'symbol': 'mooVeloV2USDC-VELO',
#    'total_supply': '216970038550837674',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0x615B9dd61f1F9a80f5bcD33A53Eb79c37b20adDC',
#    'circulating_market_cap': None,
#    'decimals': '18',
#    'exchange_rate': None,
#    'holders': '699',
#    'icon_url': None,
#    'name': 'VolatileV2 AMM - USDC/BLU',
#    'symbol': 'vAMMV2-USDC/BLU',
#    'total_supply': '540692192927688034',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0x03D3CE84279cB6F54f5e6074ff0F8319d830dafe',
#    'circulating_market_cap': None,
#    'decimals': '6',
#    'exchange_rate': None,
#    'holders': '647',
#    'icon_url': None,
#    'name': 'Prize USDC',
#    'symbol': 'przUSDC',
#    'total_supply': '2596013988535',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0x16cd38b1B54E7abf307Cb2697E2D9321e843d5AA',
#    'circulating_market_cap': None,
#    'decimals': None,
#    'exchange_rate': None,
#    'holders': '639',
#    'icon_url': None,
#    'name': 'Angle Protocol USDC-EUR Vault',
#    'symbol': 'USDC-EUR-vault',
#    'total_supply': None,
#    'type': 'ERC-721',
#    'volume_24h': None},
#   {'address': '0x7Be8a466dA0eAef2101fDEa6DFc8d0E935A6eaE2',
#    'circulating_market_cap': None,
#    'decimals': '18',
#    'exchange_rate': None,
#    'holders': '622',
#    'icon_url': None,
#    'name': 'Moo StargateV2 USDC',
#    'symbol': 'mooStargateV2USDC',
#    'total_supply': '705754827363',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0xcAAeaa835332B5bdB54c1753f4334f53021df7ea',
#    'circulating_market_cap': None,
#    'decimals': '18',
#    'exchange_rate': None,
#    'holders': '599',
#    'icon_url': None,
#    'name': 'Moo Sonne USDC',
#    'symbol': 'mooSonneUSDC',
#    'total_supply': '28206562228',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0x6F974A6dfD5B166731704Be226795901c45Bb815',
#    'circulating_market_cap': None,
#    'decimals': '6',
#    'exchange_rate': None,
#    'holders': '455',
#    'icon_url': None,
#    'name': 'USD Coin',
#    'symbol': 'USDC',
#    'total_supply': '11961141899',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0x811Cd5CB4cC43F44600Cfa5eE3F37a402C82aec2',
#    'circulating_market_cap': None,
#    'decimals': '8',
#    'exchange_rate': None,
#    'holders': '449',
#    'icon_url': None,
#    'name': 'WePiggy USDC',
#    'symbol': 'pUSDC',
#    'total_supply': '252767281373577',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0x603B5383d1F701C120D4A8E24F2DAccEF30b80b4',
#    'circulating_market_cap': None,
#    'decimals': '6',
#    'exchange_rate': None,
#    'holders': '432',
#    'icon_url': None,
#    'name': 'Avault Aave USDC',
#    'symbol': 'aaUSDC',
#    'total_supply': '2189414474',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0x906122aC1b55B71248ABFA552fDc6ABd3356884A',
#    'circulating_market_cap': None,
#    'decimals': '18',
#    'exchange_rate': None,
#    'holders': '399',
#    'icon_url': None,
#    'name': 'Velodrome v2 MTA-USDC.e Factory yVault',
#    'symbol': 'yvVelo-MTA-USDC.e-f',
#    'total_supply': '12337418455051391',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0xbA440808004AEBdFB10E4d2518323b8CC9aFAcFB',
#    'circulating_market_cap': None,
#    'decimals': '6',
#    'exchange_rate': None,
#    'holders': '382',
#    'icon_url': None,
#    'name': 'USD Coin',
#    'symbol': 'USDC',
#    'total_supply': '178263712937108',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0xEE2e18164609499cd623E493307B1e5a68fccC5B',
#    'circulating_market_cap': None,
#    'decimals': '18',
#    'exchange_rate': None,
#    'holders': '377',
#    'icon_url': None,
#    'name': 'Moo Silo Op USDC (OP)',
#    'symbol': 'mooSiloOpUSDC(OP)',
#    'total_supply': '220805741001',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0xa55DaE836094a13Cbf56ABAF650B141729a5245A',
#    'circulating_market_cap': None,
#    'decimals': None,
#    'exchange_rate': None,
#    'holders': '355',
#    'icon_url': None,
#    'name': 'Announcing USDC on Noble',
#    'symbol': 'ANNOUNCINGUSDCONNOBLE',
#    'total_supply': '424',
#    'type': 'ERC-721',
#    'volume_24h': None},
#   {'address': '0xc0Fdb17dd0811e9a6855b9bb0C6c0bbC2194C98F',
#    'circulating_market_cap': None,
#    'decimals': '18',
#    'exchange_rate': None,
#    'holders': '330',
#    'icon_url': None,
#    'name': 'Cow Uniswap Op USDC-WETH',
#    'symbol': 'cowUniswapOpUSDC-WETH',
#    'total_supply': '10548121094411759580',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0xD21C55092E7D9599302Cb735117136C3dB1855b9',
#    'circulating_market_cap': None,
#    'decimals': '6',
#    'exchange_rate': None,
#    'holders': '306',
#    'icon_url': None,
#    'name': 'Fuji-V2 USDC YieldVault-1',
#    'symbol': 'fyvUSDC-1',
#    'total_supply': '262707534',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0x4f365Dfb701cb653F057C1d57cBf08fF860e8fdc',
#    'circulating_market_cap': None,
#    'decimals': '18',
#    'exchange_rate': None,
#    'holders': '293',
#    'icon_url': None,
#    'name': 'Moo Velo v2 NEXT-USDC',
#    'symbol': 'mooVeloV2NEXT-USDC',
#    'total_supply': '4331198100981999',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0x2Cf5B6371734447A8A74fae1ce1653973fe0c0b5',
#    'circulating_market_cap': None,
#    'decimals': '18',
#    'exchange_rate': None,
#    'holders': '280',
#    'icon_url': None,
#    'name': 'Moo VeloV2 USDC-NEXT',
#    'symbol': 'mooVeloV2USDC-NEXT',
#    'total_supply': '237307482548082',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0x75087E15115C016Fb0696e1A3f75EA869e88c609',
#    'circulating_market_cap': None,
#    'decimals': '18',
#    'exchange_rate': None,
#    'holders': '280',
#    'icon_url': None,
#    'name': 'Reward Cow Velo Op USDC-USDT',
#    'symbol': 'rcowVeloOpUSDC-USDT',
#    'total_supply': '124413454879',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0xe148D6Ae042De77c1f9fe0d6c495EbfD7b705B4c',
#    'circulating_market_cap': None,
#    'decimals': '18',
#    'exchange_rate': None,
#    'holders': '279',
#    'icon_url': None,
#    'name': 'StableV2 AMM - USDC/msUSD',
#    'symbol': 'sAMMV2-USDC/msUSD',
#    'total_supply': '956579668176531959',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0xaba2b5E628641c717727128f9b9194597B310139',
#    'circulating_market_cap': None,
#    'decimals': '18',
#    'exchange_rate': None,
#    'holders': '262',
#    'icon_url': None,
#    'name': 'Moo VeloV2 USDC-STG',
#    'symbol': 'mooVeloV2USDC-STG',
#    'total_supply': '94677842585097',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0xC1CE18ee03bED17676021ca0B84F550339c66a24',
#    'circulating_market_cap': None,
#    'decimals': '18',
#    'exchange_rate': None,
#    'holders': '258',
#    'icon_url': None,
#    'name': 'Moo VeloV2 USDC-OP',
#    'symbol': 'mooVeloV2USDC-OP',
#    'total_supply': '226854759222192',
#    'type': 'ERC-20',
#    'volume_24h': None}],
#  'next_page_params': {'contract_address_hash': '0xc1ce18ee03bed17676021ca0b84f550339c66a24',
#   'fiat_value': None,
#   'holder_count': 258,
#   'is_name_null': False,
#   'items_count': 50,
#   'market_cap': None,
#   'name': 'Moo VeloV2 USDC-OP'}}
