# %%
from blockscout import Blockscout
from blockscout import Net
from blockscout import API

vitalik_addr = '0xd8da6bf26964af9d7eed9e03e53415d37aa96045'
usdc_addr = '0x0b2C639c533813f4Aa9D7837CAf62653d097Ff85'

eth_rest = Blockscout(Net.OP, API.REST)

# %%
#eth_rest.get_smart_contract(address=usdc_addr)

# %%
eth_rest.get_smart_contract_counters()
# Out:
# url: https://optimism.blockscout.com/api/v2/smart-contracts/counters
# {'new_smart_contracts_24h': '899',
#  'new_verified_smart_contracts_24h': '10243',
#  'smart_contracts': '140597087',
#  'verified_smart_contracts': '2276551'}

# %%
eth_rest.get_smart_contracts(contract_type="proxy")
# Out:
# url: https://optimism.blockscout.com/api/v2/smart-contracts?q=proxy&filter=vyper%20%7C%20solidity%20%7C%20yul
# {'items': [{'address': {'ens_domain_name': None,
#     'hash': '0xF36f56d8aabF63aDE5E0C48eff2232D6004Fc080',
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'GnosisSafeProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.7.6+commit.7338295f',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': False,
#    'tx_count': None,
#    'verified_at': '2024-07-25T18:32:42.056352Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x2113833c4F631e46a577c7980ACbBdA0ed0f31f3',
#     'implementations': [{'address': '0xd9Db270c1B5E3Bd161E8c8503c55cEABeE709552',
#       'name': 'GnosisSafe'}],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'GnosisSafeProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.7.6+commit.7338295f',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': False,
#    'tx_count': None,
#    'verified_at': '2024-07-25T18:32:29.003399Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x51cFB2F3Da1f55da7BAD9c5677D3e5BD29803235',
#     'implementations': [{'address': '0xd9Db270c1B5E3Bd161E8c8503c55cEABeE709552',
#       'name': 'GnosisSafe'}],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'GnosisSafeProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.7.6+commit.7338295f',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': False,
#    'tx_count': None,
#    'verified_at': '2024-07-25T18:32:28.284876Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x3c7494f152758F690a5122C854d0a26c6e905411',
#     'implementations': [{'address': '0xd9Db270c1B5E3Bd161E8c8503c55cEABeE709552',
#       'name': 'GnosisSafe'}],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'GnosisSafeProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.7.6+commit.7338295f',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': False,
#    'tx_count': None,
#    'verified_at': '2024-07-25T18:32:28.122873Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x79959BAb3933eb8E5ba3Ce085018DA2790c068e7',
#     'implementations': [{'address': '0xd9Db270c1B5E3Bd161E8c8503c55cEABeE709552',
#       'name': 'GnosisSafe'}],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'GnosisSafeProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.7.6+commit.7338295f',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': False,
#    'tx_count': None,
#    'verified_at': '2024-07-25T18:32:27.970280Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x65c98cBa99b3b8c17791e15B44b4BD88e184159F',
#     'implementations': [{'address': '0x505C873EE726F5008882c2B28C9a23dF133A30C8',
#       'name': 'BLendingToken'}],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'TransparentUpgradeableProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': '0.8.19+commit.7dd6d404',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': True,
#    'tx_count': None,
#    'verified_at': '2024-07-25T08:17:23.141295Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0xa9590Ff116147436Ff646270ad29A5E7c0855Ce4',
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'GnosisSafeProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.7.6+commit.7338295f',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': False,
#    'tx_count': None,
#    'verified_at': '2024-07-25T07:14:11.988362Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0xA5a990E24567809dB993cEbCccb94117f708d621',
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'GnosisSafeProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.7.6+commit.7338295f',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': False,
#    'tx_count': None,
#    'verified_at': '2024-07-25T07:14:02.007280Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0xB2D29b3B6e87647ad8aF7cAF497BfECfe17e0C89',
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'GnosisSafeProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.7.6+commit.7338295f',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': False,
#    'tx_count': None,
#    'verified_at': '2024-07-25T07:13:50.034643Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0xb738d1AF257Ea87Dc20a6455E100CA4D743E4821',
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'GnosisSafeProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.7.6+commit.7338295f',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': False,
#    'tx_count': None,
#    'verified_at': '2024-07-25T07:13:48.539726Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0xa7A84Dc970D6f5fD2dE06af02CD3931FFd745520',
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'GnosisSafeProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.7.6+commit.7338295f',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': False,
#    'tx_count': None,
#    'verified_at': '2024-07-25T07:13:47.913725Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x314983D1fe8453A619E0e3060664a93F6f9105DA',
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'GnosisSafeProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.7.6+commit.7338295f',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': False,
#    'tx_count': None,
#    'verified_at': '2024-07-25T07:13:32.417149Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x132B1DFf0A094ad8Ad9059DBfC3FD1b856D2De0d',
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'GnosisSafeProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.7.6+commit.7338295f',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': False,
#    'tx_count': None,
#    'verified_at': '2024-07-25T07:13:29.965602Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x11799f8bD2DC7903B67952605916e1656316D61B',
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'GnosisSafeProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.7.6+commit.7338295f',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': False,
#    'tx_count': None,
#    'verified_at': '2024-07-25T07:13:29.837257Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x0ca39e7F0746661e65bE94Ddd3AF14034Ca6aA1E',
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'GnosisSafeProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.7.6+commit.7338295f',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': False,
#    'tx_count': None,
#    'verified_at': '2024-07-25T07:13:26.393124Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0xcE7ba48c8fbc4B180F5af91e7b8f861D65aAD897',
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'GnosisSafeProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.7.6+commit.7338295f',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': False,
#    'tx_count': None,
#    'verified_at': '2024-07-25T07:13:18.305585Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0