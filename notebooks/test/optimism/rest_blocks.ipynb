# %%
from blockscout import Blockscout
from blockscout import TokenTransfers
from blockscout import Net
from blockscout import API

vitalik_addr = '0xd8da6bf26964af9d7eed9e03e53415d37aa96045'
usdc_addr = '0x0b2C639c533813f4Aa9D7837CAf62653d097Ff85'

eth_rest = Blockscout(Net.OP, API.REST)

# %%
#eth_rest.get_main_page_blocks()

# %%
eth_rest.get_block_withdrawals(block_number = "123172305")
# Out:
# url: https://optimism.blockscout.com/api/v2/blocks/123172305/withdrawals
# {'items': [], 'next_page_params': None}

# %%
eth_rest.get_block_transactions(block_number = "123172305")
# Out:
# url: https://optimism.blockscout.com/api/v2/blocks/123172305/transactions
# {'items': [{'timestamp': '2024-07-25T21:36:27.000000Z',
#    'fee': {'type': 'actual', 'value': '0'},
#    'gas_limit': '1000000',
#    'block': 123172305,
#    'status': 'ok',
#    'method': 'setL1BlockValuesEcotone',
#    'confirmations': 16,
#    'type': 126,
#    'exchange_rate': '3178.21',
#    'to': {'ens_domain_name': None,
#     'hash': '0x4200000000000000000000000000000000000015',
#     'implementations': [{'address': '0x07dbe8500fc591d1852B76feE44d5a05e13097Ff',
#       'name': 'L1Block'}],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'Proxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'tx_burnt_fee': None,
#    'max_fee_per_gas': None,
#    'result': 'success',
#    'hash': '0x36c63036f0a53dbc2e6884d0677ca658f80aced62d7102104c848bd58ed67e40',
#    'gas_price': '0',
#    'priority_fee': None,
#    'base_fee_per_gas': '720562',
#    'from': {'ens_domain_name': None,
#     'hash': '0xDeaDDEaDDeAdDeAdDEAdDEaddeAddEAdDEAd0001',
#     'implementations': [],
#     'is_contract': False,
#     'is_verified': False,
#     'metadata': None,
#     'name': None,
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'token_transfers': None,
#    'tx_types': ['contract_call'],
#    'gas_used': '43851',
#    'created_contract': None,
#    'position': 0,
#    'nonce': 17937243,
#    'has_error_in_internal_txs': False,
#    'actions': [],
#    'decoded_input': {'method_call': 'setL1BlockValuesEcotone()',
#     'method_id': '440a5e20',
#     'parameters': []},
#    'token_transfers_overflow': None,
#    'raw_input': '',
#    'value': '0',
#    'max_priority_fee_per_gas': None,
#    'revert_reason': None,
#    'confirmation_duration': [0, 2000.0],
#    'tx_tag': None},
#   {'timestamp': '2024-07-25T21:36:27.000000Z',
#    'fee': {'type': 'actual', 'value': '29617898341375'},
#    'gas_limit': '600000',
#    'block': 123172305,
#    'status': 'ok',
#    'method': '0xa00597a0',
#    'confirmations': 16,
#    'type': 2,
#    'exchange_rate': '3178.21',
#    'to': {'ens_domain_name': None,
#     'hash': '0x802b65b5d9016621E66003aeD0b16615093f328b',
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': False,
#     'metadata': None,
#     'name': None,
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'tx_burnt_fee': '124761707490',
#    'max_fee_per_gas': '170936730',
#    'result': 'success',
#    'hash': '0xd86b3113148a498c78177077b50e6be4d2da9ceddfb4c182328177b7faa421cd',
#    'gas_price': '170720562',
#    'priority_fee': '29434650000000',
#    'base_fee_per_gas': '720562',
#    'from': {'ens_domain_name': None,
#     'hash': '0x989ebD9437371FaCd601281b8a56d87962131567',
#     'implementations': [],
#     'is_contract': False,
#     'is_verified': False,
#     'metadata': None,
#     'name': None,
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'token_transfers': None,
#    'tx_types': ['contract_call', 'token_transfer'],
#    'gas_used': '173145',
#    'created_contract': None,
#    'position': 1,
#    'nonce': 68948,
#    'has_error_in_internal_txs': False,
#    'actions': [],
#    'decoded_input': None,
#    'token_transfers_overflow': None,
#    'raw_input': '',
#    'value': '0',
#    'max_priority_fee_per_gas': '170000000',
#    'revert_reason': None,
#    'confirmation_duration': [0, 2000.0],
#    'tx_tag': None},
#   {'timestamp': '2024-07-25T21:36:27.000000Z',
#    'fee': {'type': 'actual', 'value': '18633652422002'},
#    'gas_limit': '250000',
#    'block': 123172305,
#    'status': 'ok',
#    'method': 'execTransaction',
#    'confirmations': 16,
#    'type': 2,
#    'exchange_rate': '3178.21',
#    'to': {'ens_domain_name': None,
#     'hash': '0x65ad84A548dEEA54D07C697d3106396FE13415C0',
#     'implementations': [{'address': '0xd9Db270c1B5E3Bd161E8c8503c55cEABeE709552',
#       'name': 'GnosisSafe'}],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'GnosisSafeProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'tx_burnt_fee': '133292441008',
#    'max_fee_per_gas': '100000000',
#    'result': 'success',
#    'hash': '0xe88f33e60482525d1bbc51dcd9b690ce74323b6b96cb115f918d2fb9135c6cdc',
#    'gas_price': '100000000',
#    'priority_fee': '18365107558992',
#    'base_fee_per_gas': '720562',
#    'from': {'ens_domain_name': None,
#     'hash': '0x8e310B9D3361C93A2A64e5dB4123345FC375894d',
#     'implementations': [],
#     'is_contract': False,
#     'is_verified': False,
#     'metadata': None,
#     'name': None,
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'token_transfers': None,
#    'tx_types': ['contract_call', 'token_transfer'],
#    'gas_used': '184984',
#    'created_contract': None,
#    'position': 2,
#    'nonce': 16231,
#    'has_error_in_internal_txs': False,
#    'actions': [],
#    'decoded_input': {'method_call': 'execTransaction(address to, uint256 value, bytes data, uint8 operation, uint256 safeTxGas, uint256 baseGas, uint256 gasPrice, address gasToken, address refundReceiver, bytes signatures)',
#     'method_id': '6a761202',
#     'parameters': [{'name': 'to',
#       'type': 'address',
#       'value': '0x087000a300de7200382b55d40045000000e5d60e'},
#      {'name': 'value', 'type': 'uint256', 'value': '0'},
#      {'name': 'data',
#       'type': 'bytes',
#       'value': '...'},
#      {'name': 'operation', 'type': 'uint8', 'value': '1'},
#      {'name': 'safeTxGas', 'type': 'uint256', 'value': '0'},
#      {'name': 'baseGas', 'type': 'uint256', 'value': '0'},
#      {'name': 'gasPrice', 'type': 'uint256', 'value': '0'},
#      {'name': 'gasToken',
#       'type': 'address',
#       'value': '0x0000000000000000000000000000000000000000'},
#      {'name': 'refundReceiver',
#       'type': 'address',
#       'value': '0x0000000000000000000000000000000000000000'},
#      {'name': 'signatures',
#       'type': 'bytes',
#       'value': '0x508f1cc3ee02978e3cccd8d624534aa23a9510b09b2794e3ff5c809ce30ce0613354d4331f6db38c0447afea1a8fba7b08a4f9a4170b1560982c411c4595abe41c'}]},
#    'token_transfers_overflow': None,
#    'raw_input': '...',
#    'value': '0',
#    'max_priority_fee_per_gas': '100000000',
#    'revert_reason': None,
#    'confirmation_duration': [0, 2000.0],
#    'tx_tag': None},
#   {'timestamp': '2024-07-25T21:36:27.000000Z',
#    'fee': {'type': 'actual', 'value': '2531583025032'},
#    'gas_limit': '400000',
#    'block': 123172305,
#    'status': 'error',
#    'method': '0xdbd2893a',
#    'confirmations': 16,
#    'type': 0,
#    'exchange_rate': '3178.21',
#    'to': {'ens_domain_name': None,
#     'hash': '0xacf1A11D720Ff5Cfff5de88eD325725bB357Cc11',
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': False,
#     'metadata': None,
#     'name': None,
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'tx_burnt_fee': None,
#    'max_fee_per_gas': None,
#    'result': 'execution reverted',
#    'hash': '0xd478018d86ec5bab82b5e5eb1980ed8b751ad9832698932a840dcaf19fc80610',
#    'gas_price': '65165439',
#    'priority_fee': None,
#    'base_fee_per_gas': '720562',
#    'from': {'ens_domain_name': None,
#     'hash': '0x8D5579542a924C621AE9106D77eC4D9B42894602',
#     'implementations': [],
#     'is_contract': False,
#     'is_verified': False,
#     'metadata': None,
#     'name': None,
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'token_transfers': None,
#    'tx_types': ['contract_call'],
#    'gas_used': '38178',
#    'created_contract': None,
#    'position': 3,
#    'nonce': 146038,
#    'has_error_in_internal_txs': True,
#    'actions': [],
#    'decoded_input': None,
#    'token_transfers_overflow': None,
#    'raw_input': '',
#    'value': '0',
#    'max_priority_fee_per_gas': None,
#    'revert_reason': {'method_call': 'Error(string reason)',
#     'method_id': '08c379a0',
#     'parameters': [{'name': 'reason', 'type': 'string', 'value': 'err32'}]},
#    'confirmation_duration': [0, 2000.0],
#    'tx_tag': None},
#   {'timestamp': '2024-07-25T21:36:27.000000Z',
#    'fee': {'type': 'actual', 'value': '435305203728'},
#    'gas_limit': '49857',
#    'block': 123172305,
#    'status': 'ok',
#    'method': 'transfer',
#    'confirmations': 16,
#    'type': 2,
#    'exchange_rate': '3178.21',
#    'to': {'ens_domain_name': None,
#     'hash': '0x7F5c764cBc14f9669B88837ca1490cCa17c31607',
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'OVMFiatToken',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'tx_burnt_fee': '26428773036',
#    'max_fee_per_gas': '10897232',
#    'result': 'success',
#    'hash': '0x87a64d2d8eb16a3764aba8d7ac4e1d09cc8b616282d1d11767b3d9194be05f34',
#    'gas_price': '10720562',
#    'priority_fee': '366780000000',
#    'base_fee_per_gas': '720562',
#    'from': {'ens_domain_name': None,
#     'hash': '0xD6000B8a96D8Cce46BdC79FeEF1F036bc5eb56a5',
#     'implementations': [],
#     'is_contract': False,
#     'is_verified': False,
#     'metadata': None,
#     'name': None,
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'token_transfers': None,
#    'tx_types': ['contract_call', 'token_transfer'],
#    'gas_used': '36678',
#    'created_contract': None,
#    'position': 4,
#    'nonce': 11,
#    'has_error_in_internal_txs': False,
#    'actions': [],
#    'decoded_input': {'method_call': 'transfer(address recipient, uint256 amount)',
#     'method_id': 'a9059cbb',
#     'parameters': [{'name': 'recipient',
#       'type': 'address',
#       'value': '0x253dd57300904225762960755b7662e6ae06492d'},
#      {'name': 'amount', 'type': 'uint256', 'value': '20000000'}]},
#    'token_transfers_overflow': None,
#    'raw_input': '0xa9059cbb000000000000000000000000253dd57300904225762960755b7662e6ae06492d0000000000000000000000000000000000000000000000000000000001312d00',
#    'value': '0',
#    'max_priority_fee_per_gas': '10000000',
#    'revert_reason': None,
#    'confirmation_duration': [0, 2000.0],
#    'tx_tag': None},
#   {'timestamp': '2024-07-25T21:36:27.000000Z',
#    'fee': {'type': 'actual', 'value': '267228232692'},
#    'gas_limit': '21000',
#    'block': 123172305,
#    'status': 'ok',
#    'method': None,
#    'confirmations': 16,
#    'type': 2,
#    'exchange_rate': '3178.21',
#    'to': {'ens_domain_name': None,
#     'hash': '0xce04D922B19b17265b8B54Dbc7ecd21e17441822',
#     'implementations': [],
#     'is_contract': False,
#     'is_verified': False,
#     'metadata': None,
#     'name': None,
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'tx_burnt_fee': '15131802000',
#    'max_fee_per_gas': '10897232',
#    'result': 'success',
#    'hash': '0x135b168219302031c98569c2e7351d58f0ffa90f5ae50cb0c4bbdb84c1d95ebb',
#    'gas_price': '10720562',
#    'priority_fee': '210000000000',
#    'base_fee_per_gas': '720562',
#    'from': {'ens_domain_name': None,
#     'hash': '0xD47ee3Fffd67312959d4Ce51C1d265ae49Ec76D8',
#     'implementations': [],
#     'is_contract': False,
#     'is_verified': False,
#     'metadata': None,
#     'name': None,
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'token_transfers': None,
#    'tx_types': ['coin_transfer'],
#    'gas_used': '21000',
#    'created_contract': None,
#    'position': 5,
#    'nonce': 38292,
#    'has_error_in_internal_txs': False,
#    'actions': [],
#    'decoded_input': None,
#    'token_transfers_overflow': None,
#    'raw_input': '0x',
#    'value': '20000000000000',
#    'max_priority_fee_per_gas': '10000000',
#    'revert_reason': None,
#    'confirmation_duration': [0, 2000.0],
#    'tx_tag': None},
#   {'timestamp': '2024-07-25T21:36:27.000000Z',
#    'fee': {'type': 'actual', 'value': '4399185329623'},
#    'gas_limit': '2000000',
#    'block': 123172305,
#    'status': 'ok',
#    'method': '0x3baf7491',
#    'confirmations': 16,
#    'type': 2,
#    'exchange_rate': '3178.21',
#    'to': {'ens_domain_name': None,
#     'hash': '0xeF4E57501e1bc4e72523DCa9f64B83b651c51079',
#     'implementations': [{'address': '0x279518b39760DDB1073671842Fd4448cCDEf660a',
#       'name': None}],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'TransparentUpgradeableProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'tx_burnt_fee': '1135095554104',
#    'max_fee_per_gas': '9378357',
#    'result': 'success',
#    'hash': '0x370e29ede0aaf44656b54f6ee976761efce8a8729c2003f3744ad10143befff9',
#    'gas_price': '2756606',
#    'priority_fee': '3207363824848',
#    'base_fee_per_gas': '720562',
#    'from': {'ens_domain_name': None,
#     'hash': '0x3FE8Df3c590204c5aFEfAE853e293BF1c33Be769',
#     'implementations': [],
#     'is_contract': False,
#     'is_verified': False,
#     'metadata': None,
#     'name': None,
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'token_transfers': None,
#    'tx_types': ['contract_call', 'token_transfer'],
#    'gas_used': '1575292',
#    'created_contract': None,
#    'position': 6,
#    'nonce': 139241,
#    'has_error_in_internal_txs': False,
#    'actions': [],
#    'decoded_input': None,
#    'token_transfers_overflow': None,
#    'raw_input': '',
#    'value': '0',
#    'max_priority_fee_per_gas': '2036044',
#    'revert_reason': None,
#    'confirmation_duration': [0, 2000.0],
#    'tx_tag': None},
#   {'timestamp': '2024-07-25T21:36:27.000000Z',
#    'fee': {'type': 'actual', 'value': '303466495767'},
#    'gas_limit': '250530',
#    'block': 123172305,
#    'status': 'ok',
#    'method': '0x0508941e',
#    'confirmations': 16,
#    'type': 0,
#    'exchange_rate': '3178.21',
#    'to': {'ens_domain_name': None,
#     'hash': '0x81E792e5a9003CC1C8BF5569A00f34b65d75b017',
#     'implementations': [{'address': '0x9A4DF6D81309c8a583C28eD8e449E320043e7A97',
#       'name': None}],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'OptimizedTransparentUpgradeableProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'tx_burnt_fee': None,
#    'max_fee_per_gas': None,
#    'result': 'success',
#    'hash': '0xdfc0985b3330ba77b2585033a7d41f54622200855332344573f1666b370e8ebe',
#    'gas_price': '2065644',
#    'priority_fee': None,
#    'base_fee_per_gas': '720562',
#    'from': {'ens_domain_name': None,
#     'hash': '0xe93685f3bBA03016F02bD1828BaDD6195988D950',
#     'implementations': [],
#     'is_contract': False,
#     'is_verified': False,
#     'metadata': {'tags': [{'meta': {},
#        'name': 'Layer Zero: Executor',
#        'ordinal': 10,
#        'slug': 'layer-zero-executor',
#        'tagType': 'name'}]},
#     'name': None,
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'token_transfers': None,
#    'tx_types': ['coin_transfer', 'contract_call'],
#    'gas_used': '108028',
#    'created_contract': None,
#    'position': 7,
#    'nonce': 9315941,
#    'has_error_in_internal_txs': False,
#    'actions': [],
#    'decoded_input': None,
#    'token_transfers_overflow': None,
#    'raw_input': '...',
#    'value': '5840000000000',
#    'max_priority_fee_per_gas': None,
#    'revert_reason': None,
#    'confirmation_duration': [0, 2000.0],
#    'tx_tag': None},
#   {'timestamp': '2024-07-25T21:36:27.000000Z',
#    'fee': {'type': 'actual', 'value': '381350690322'},
#    'gas_limit': '1000000',
#    'block': 123172305,
#    'status': 'ok',
#    'method': '0x9c96eec5',
#    'confirmations': 16,
#    'type': 0,
#    'exchange_rate': '3178.21',
#    'to': {'ens_domain_name': None,
#     'hash': '0xA355c1991B69d5A8E1ce24A5EB90557c913Ce789',
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': False,
#     'metadata': None,
#     'name': '! VELODROME',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'tx_burnt_fee': None,
#    'max_fee_per_gas': None,
#    'result': 'success',
#    'hash': '0x5c2e86d470ab65b2d6d4d9d57a74dbe8b1a18769700fc07745a10d42680f2842',
#    'gas_price': '1721370',
#    'priority_fee': None,
#    'base_fee_per_gas': '720562',
#    'from': {'ens_domain_name': None,
#     'hash': '0x3C9D461bCcaDE0f05fcfBa90744277757d45A62a',
#     'implementations': [],
#     'is_contract': False,
#     'is_verified': False,
#     'metadata': None,
#     'name': None,
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'token_transfers': None,
#    'tx_types': ['contract_call', 'token_transfer'],
#    'gas_used': '85483',
#    'created_contract': None,
#    'position': 8,
#    'nonce': 1447,
#    'has_error_in_internal_txs': False,
#    'actions': [],
#    'decoded_input': None,
#    'token_transfers_overflow': None,
#    'raw_input': '...',
#    'value': '0',
#    'max_priority_fee_per_gas': None,
#    'revert_reason': None,
#    'confirmation_duration': [0, 2000.0],
#    'tx_tag': None},
#   {'timestamp': '2024-07-25T21:36:27.000000Z',
#    'fee': {'type': 'actual', 'value': '78228232692'},
#    'gas_limit': '21000',
#    'block': 123172305,
#    'status': 'ok',
#    'method': None,
#    'confirmations': 16,
#    'type': 2,
#    'exchange_rate': '3178.21',
#    'to': {'ens_domain_name': None,
#     'hash': '0xE4eDb277e41dc89aB076a1F049f4a3EfA700bCE8',
#     'implementations': [],
#     'is_contract': False,
#     'is_verified': False,
#     'metadata': {'tags': [{'meta': {},
#        'name': 'Bridge',
#        'ordinal': 0,
#        'slug': 'bridge',
#        'tagType': 'note'},
#       {'meta': {},
#        'name': 'Orbiter Finance: Bridge 2',
#        'ordinal': 10,
#        'slug': 'orbiter-finance-bridge-2',
#        'tagType': 'name'}]},
#     'name': None,
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'tx_burnt_fee': '15131802000',
#    'max_fee_per_gas': '3582055',
#    'result': 'success',
#    'hash': '0xc70bc6a7cc1bb9351085cdb133a8092d0e94ed9d078dce8c077957736bbb6746',
#    'gas_price': '1720562',
#    'priority_fee': '21000000000',
#    'base_fee_per_gas': '720562',
#    'from': {'ens_domain_name': None,
#     'hash': '0x9642C38a314CA7f6ee8579d0b1919DcB809d17c9',
#     'implementations': [],
#     'is_contract': False,
#     'is_verified': False,
#     'metadata': None,
#     'name': None,
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'token_transfers': None,
#    'tx_types': ['coin_transfer'],
#    'gas_used': '21000',
#    'created_contract': None,
#    'position': 9,
#    'nonce': 1501,
#    'has_error_in_internal_txs': False,
#    'actions': [],
#    'decoded_input': None,
#    'token_transfers_overflow': None,
#    'raw_input': '0x',
#    'value': '1020000000009020',
#    'max_priority_fee_per_gas': '1000000',
#    'revert_reason': None,
#    'confirmation_duration': [0, 2000.0],
#    'tx_tag': None},
#   {'timestamp': '2024-07-25T21:36:27.000000Z',
#    'fee': {'type': 'actual', 'value': '136205477962'},
#    'gas_limit': '442713',
#    'block': 123172305,
#    'status': 'error',
#    'method': '0x00004200',
#    'confirmations': 16,
#    'type': 0,
#    'exchange_rate': '3178.21',
#    'to': {'ens_domain_name': None,
#     'hash': '0x99009E1c35c70c6C40731df12Dab928852999F3C',
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': False,
#     'metadata': None,
#     'name': None,
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'tx_burnt_fee': None,
#    'max_fee_per_gas': None,
#    'result': 'execution reverted',
#    'hash': '0x2246198819aa9f6604ff5218b506db0313525851b90945c11fffc4be5231cbe4',
#    'gas_price': '809354',
#    'priority_fee': None,
#    'base_fee_per_gas': '720562',
#    'from': {'ens_domain_name': None,
#     'hash': '0xEE09884572187F86076c5c8Dc7ebd6b6e7Cc301e',
#     'implementations': [],
#     'is_contract': False,
#     'is_verified': False,
#     'metadata': None,
#     'name': None,
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'token_transfers': None,
#    'tx_types': ['contract_call'],
#    'gas_used': '55563',
#    'created_contract': None,
#    'position': 10,
#    'nonce': 49394,
#    'has_error_in_internal_txs': True,
#    'actions': [],
#    'decoded_input': None,
#    'token_transfers_overflow': None,
#    'raw_input': '...',
#    'value': '0',
#    'max_priority_fee_per_gas': None,
#    'revert_reason': {'method_call': 's()',
#     'method_id': '86b714e2',
#     'parameters': []},
#    'confirmation_duration': [0, 2000.0],
#    'tx_tag': None}],
#  'next_page_params': None}

# %%
eth_rest.get_block_info(block_number = "123172305")
# Out:
# url: https://optimism.blockscout.com/api/v2/blocks/123172305
# {'base_fee_per_gas': '720562',
#  'burnt_fees': '1688422319524',
#  'burnt_fees_percentage': 3.0173084955671094,
#  'difficulty': '0',
#  'gas_limit': '30000000',
#  'gas_target_percentage': -53.13596,
#  'gas_used': '2343202',
#  'gas_used_percentage': 7.810673333333333,
#  'hash': '0xe3165c7100e8174eba0f649a1b18e023c05f5516c8d38d0b844119b7d156bb5e',
#  'height': 123172305,
#  'miner': {'ens_domain_name': None,
#   'hash': '0x4200000000000000000000000000000000000011',
#   'implementations': [{'address': '0xC0D3C0d3c0d3c0d3C0D3c0d3C0D3c0d3c0D30011',
#     'name': 'SequencerFeeVault'}],
#   'is_contract': True,
#   'is_verified': True,
#   'metadata': None,
#   'name': 'Proxy',
#   'private_tags': [],
#   'public_tags': [],
#   'watchlist_names': []},
#  'nonce': '0x0000000000000000',
#  'parent_hash': '0x124c8eab00ea6d2bebc0742d056e827e620fb4ba00eeb90aa0ad3f02cfb6fd98',
#  'priority_fee': '54301070036402',
#  'rewards': [],
#  'size': 5273,
#  'timestamp': '2024-07-25T21:36:27.000000Z',
#  'total_difficulty': '0',
#  'tx_count': 11,
#  'tx_fees': '55957894991664',
#  'type': 'block',
#  'uncles_hashes': [],
#  'withdrawals_count': 0}
