# %%
from blockscout import Blockscout
from blockscout import Net
from blockscout import API

eth = Blockscout(Net.ROLLUX, API.REST)

# %%
eth.get_main_page_blocks()
# Out:
# url: https://explorer.rollux.com/api/v2/main-page/blocks
# [{'base_fee_per_gas': '50',
#   'burnt_fees': '78655550',
#   'burnt_fees_percentage': 5.1534466819268325e-05,
#   'difficulty': '0',
#   'gas_limit': '30000000',
#   'gas_target_percentage': -89.51259333333333,
#   'gas_used': '1573111',
#   'gas_used_percentage': 5.243703333333333,
#   'hash': '0x541aaa3919ccc1b3a428a1493e6179a618e791e6c5ae18f21415e566c65267b8',
#   'height': 16726586,
#   'miner': {'ens_domain_name': None,
#    'hash': '0x4200000000000000000000000000000000000011',
#    'implementation_name': None,
#    'is_contract': True,
#    'is_verified': None,
#    'metadata': None,
#    'name': None,
#    'private_tags': [],
#    'public_tags': [],
#    'watchlist_names': []},
#   'nonce': '0x0000000000000000',
#   'parent_hash': '0x3490395d0c521c921c9bf8852c82500fabaaa928054ee1829e96fe110c4fe446',
#   'priority_fee': '152627000000000',
#   'rewards': [],
#   'size': 18680,
# ...

# %%
eth.get_block_withdrawals(block_number = "16668506")
# Out:
# url: https://explorer.rollux.com/api/v2/blocks/16668506/withdrawals
# {'items': [], 'next_page_params': None}

# %%
eth.get_block_transactions(block_number = "16668506")
# Out:
# url: https://explorer.rollux.com/api/v2/blocks/16668506/transactions
# {'items': [{'timestamp': '2024-07-11T12:50:53.000000Z',
#    'fee': {'type': 'actual', 'value': '0'},
#    'gas_limit': '1000000',
#    'block': 16668506,
#    'status': 'ok',
#    'method': 'setL1BlockValues',
#    'confirmations': 58082,
#    'type': 126,
#    'exchange_rate': None,
#    'to': {'ens_domain_name': None,
#     'hash': '0x4200000000000000000000000000000000000015',
#     'implementation_name': 'L1Block',
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'Proxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'tx_burnt_fee': None,
#    'max_fee_per_gas': None,
#    'result': 'success',
#    'hash': '0x972461471b09252d4fbdc8c91bd19d8f4a04c8addcbf9fb99d55a5baa76c1c3d',
#    'gas_price': '0',
#    'priority_fee': None,
#    'base_fee_per_gas': '50',
#    'from': {'ens_domain_name': None,
# ...

# %%
eth.get_block_info(block_number = "16668506")
# Out:
# url: https://explorer.rollux.com/api/v2/blocks/16668506
# {'base_fee_per_gas': '50',
#  'burnt_fees': '4656600',
#  'burnt_fees_percentage': 4.026894309257811e-06,
#  'difficulty': '0',
#  'gas_limit': '30000000',
#  'gas_target_percentage': -99.37912,
#  'gas_used': '93132',
#  'gas_used_percentage': 0.31044,
#  'hash': '0xcdae6c3acf4a35d0d0f42c70a9b04be779b8b10c38cdfea136e12d76b5fac2ec',
#  'height': 16668506,
#  'miner': {'ens_domain_name': None,
#   'hash': '0x4200000000000000000000000000000000000011',
#   'implementation_name': None,
#   'is_contract': True,
#   'is_verified': None,
#   'metadata': None,
#   'name': None,
#   'private_tags': [],
#   'public_tags': [],
#   'watchlist_names': []},
#  'nonce': '0x0000000000000000',
#  'parent_hash': '0x2414d0ada76616fb71a2870bab7164bcb0b9ba2591c17c7e9c71393b2312597c',
#  'priority_fee': '115637500000000',
#  'rewards': [],
#  'size': 1056,
#  'timestamp': '2024-07-11T12:50:53.000000Z',
#  'total_difficulty': '0',
#  'tx_count': 2,
# ...
