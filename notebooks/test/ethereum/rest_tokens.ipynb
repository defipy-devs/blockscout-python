# %%
from blockscout import Blockscout
from blockscout import TokenTransfers
from blockscout import Net
from blockscout import API

vitalik_addr = '0xd8da6bf26964af9d7eed9e03e53415d37aa96045'
usdc_addr = '0xA0b86991c6218b36c1d19D4a2e9Eb0cE3606eB48'

eth_rest = Blockscout(Net.ETH, API.REST)

# %%
eth_rest.get_token_counters(address=usdc_addr)
# Out:
# url: https://eth.blockscout.com/api/v2/tokens/0xA0b86991c6218b36c1d19D4a2e9Eb0cE3606eB48/counters
# {'token_holders_count': '2752697', 'transfers_count': '0'}

# %%
#eth_rest.get_token_holders(address=usdc_addr)

# %%
#eth_rest.get_token_transfers(address=usdc_addr)

# %%
eth_rest.get_token_info(address=usdc_addr)
# Out:
# url: https://eth.blockscout.com/api/v2/tokens/0xA0b86991c6218b36c1d19D4a2e9Eb0cE3606eB48
# {'address': '0xA0b86991c6218b36c1d19D4a2e9Eb0cE3606eB48',
#  'circulating_market_cap': '33815681328.969032',
#  'decimals': '6',
#  'exchange_rate': '1.001',
#  'holders': '2752772',
#  'icon_url': 'https://assets.coingecko.com/coins/images/6319/small/usdc.png?1696506694',
#  'name': 'USD Coin',
#  'symbol': 'USDC',
#  'total_supply': '25102046981315030',
#  'type': 'ERC-20',
#  'volume_24h': '6919175722.21582'}

# %%
eth_rest.get_tokens_list(token_name="USDC")
# Out:
# url: https://eth.blockscout.com/api/v2/tokens?q=USDC&type=ERC-20%2CERC-721%2CERC-1155
# {'items': [{'address': '0xA0b86991c6218b36c1d19D4a2e9Eb0cE3606eB48',
#    'circulating_market_cap': '33815681328.969032',
#    'decimals': '6',
#    'exchange_rate': '1.001',
#    'holders': '2752772',
#    'icon_url': 'https://assets.coingecko.com/coins/images/6319/small/usdc.png?1696506694',
#    'name': 'USD Coin',
#    'symbol': 'USDC',
#    'total_supply': '25102046981315030',
#    'type': 'ERC-20',
#    'volume_24h': '6919175722.21582'},
#   {'address': '0xc8871267e07408b89aA5aEcc58AdCA5E574557F8',
#    'circulating_market_cap': '15834.143010824055',
#    'decimals': '6',
#    'exchange_rate': '1.17',
#    'holders': '105',
#    'icon_url': 'https://assets.coingecko.com/coins/images/25820/small/iUSDC_100x100.png?1696524905',
#    'name': 'Instadapp USDC',
#    'symbol': 'iUSDC',
#    'total_supply': '13570425375',
#    'type': 'ERC-20',
#    'volume_24h': '0.0'},
#   {'address': '0xe0a84699a583d467001fcfE1d52930cF6f3b0BFa',
#    'circulating_market_cap': '0.0',
#    'decimals': '18',
#    'exchange_rate': '208.04',
#    'holders': '5',
#    'icon_url': None,
#    'name': 'WBTC USDC RSI Set',
#    'symbol': 'WBTCCUSDCRSI',
#    'total_supply': '2647891803200000000',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0xe33A35fD5cad21cE72ebbC8a2885Bdd0983De043',
#    'circulating_market_cap': '0.0',
#    'decimals': '18',
#    'exchange_rate': '86.03',
#    'holders': '9',
#    'icon_url': None,
#    'name': 'WBTC USDC RSI Set',
#    'symbol': 'BTCUSDCRSI',
#    'total_supply': '1983171142514000000',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0xca9f9671765F8D1A7e19ae2639E01FFF730f0D9B',
#    'circulating_market_cap': '0.0',
#    'decimals': '18',
#    'exchange_rate': '1.33',
#    'holders': '55',
#    'icon_url': 'https://assets.coingecko.com/coins/images/31248/small/jay-bird200.png?1696530073',
#    'name': 'Jaypeggers USDC',
#    'symbol': 'jUSDC',
#    'total_supply': '28312567882421961279176',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0xa354F35829Ae975e850e23e9615b11Da1B3dC4DE',
#    'circulating_market_cap': '0.0',
#    'decimals': '6',
#    'exchange_rate': '1.098',
#    'holders': '1510',
#    'icon_url': 'https://assets.coingecko.com/coins/images/28779/small/yvUSDC-128-0xe2F6b9773BF3A015E2aA70741Bde1498bdB9425b.png?1696527758',
#    'name': 'USDC yVault',
#    'symbol': 'yvUSDC',
#    'total_supply': '12196401633577',
#    'type': 'ERC-20',
#    'volume_24h': '0.0'},
#   {'address': '0xD81b1A8B1AD00Baa2D6609E0BAE28A38713872f7',
#    'circulating_market_cap': '0.0',
#    'decimals': '6',
#    'exchange_rate': '1.027',
#    'holders': '1594',
#    'icon_url': None,
#    'name': 'PoolTogether USDC Ticket (Compound)',
#    'symbol': 'PcUSDC',
#    'total_supply': '685418043159',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0xBcca60bB61934080951369a648Fb03DF4F96263C',
#    'circulating_market_cap': '0.0',
#    'decimals': '6',
#    'exchange_rate': '1.004',
#    'holders': '10980',
#    'icon_url': 'https://assets.coingecko.com/coins/images/14318/small/aUSDC.e260d492.png?1696514006',
#    'name': 'Aave interest bearing USDC',
#    'symbol': 'aUSDC',
#    'total_supply': '163239523056344',
#    'type': 'ERC-20',
#    'volume_24h': '596273.1113369169'},
#   {'address': '0x9bA00D6856a4eDF4665BcA2C2309936572473B7E',
#    'circulating_market_cap': '0.0',
#    'decimals': '6',
#    'exchange_rate': '1.004',
#    'holders': '1864',
#    'icon_url': 'https://assets.coingecko.com/coins/images/11674/small/aUSDC.png?1696511564',
#    'name': 'Aave Interest bearing USDC',
#    'symbol': 'aUSDC',
#    'total_supply': '1279760454553',
#    'type': 'ERC-20',
#    'volume_24h': '0.0'},
#   {'address': '0xd24946147829DEaA935bE2aD85A3291dbf109c80',
#    'circulating_market_cap': '0.0',
#    'decimals': '6',
#    'exchange_rate': '1.004',
#    'holders': '117',
#    'icon_url': 'https://assets.coingecko.com/coins/images/17226/small/aAMMUSDC_2x.png?1696516780',
#    'name': 'Aave AMM Market USDC',
#    'symbol': 'aAmmUSDC',
#    'total_supply': '32912021821',
#    'type': 'ERC-20',
#    'volume_24h': '0.0'},
#   {'address': '0x98C23E9d8f34FEFb1B7BD6a91B7FF122F4e16F5c',
#    'circulating_market_cap': '0.0',
#    'decimals': '6',
#    'exchange_rate': '0.999888',
#    'holders': '4716',
#    'icon_url': 'https://assets.coingecko.com/coins/images/32847/small/usdc_%281%29.png?1699619355',
#    'name': 'Aave Ethereum USDC',
#    'symbol': 'aEthUSDC',
#    'total_supply': '1542677230860500',
#    'type': 'ERC-20',
#    'volume_24h': '1.5276264465413751'},
#   {'address': '0x9d1089802eE608BA84C5c98211afE5f37F96B36C',
#    'circulating_market_cap': '0.0',
#    'decimals': '6',
#    'exchange_rate': '0.998862',
#    'holders': '76',
#    'icon_url': 'https://assets.coingecko.com/coins/images/28471/small/fUSDC-200x200.png?1696527465',
#    'name': 'Fluid USDC',
#    'symbol': 'fUSDC',
#    'total_supply': '2911446851',
#    'type': 'ERC-20',
#    'volume_24h': '9471.031865963849'},
#   {'address': '0x41f7B8b9b897276b7AAE926a9016935280b44E97',
#    'circulating_market_cap': '0.0',
#    'decimals': '6',
#    'exchange_rate': '0.996864',
#    'holders': '1528',
#    'icon_url': 'https://raw.githubusercontent.com/trustwallet/assets/master/blockchains/ethereum/assets/0x41f7B8b9b897276b7AAE926a9016935280b44E97/logo.png',
#    'name': 'USD Coin',
#    'symbol': 'USDC',
#    'total_supply': '412193184585',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0x566957eF80F9fd5526CD2BEF8BE67035C0b81130',
#    'circulating_market_cap': '0.0',
#    'decimals': '6',
#    'exchange_rate': '0.996488',
#    'holders': '138',
#    'icon_url': 'https://assets.coingecko.com/coins/images/22945/small/USDCpo_wh_small.png?1696522242',
#    'name': 'USD Coin (PoS)',
#    'symbol': 'USDC',
#    'total_supply': '518290642065',
#    'type': 'ERC-20',
#    'volume_24h': '618.8467305168896'},
#   {'address': '0x8fcb1783bF4b71A51F702aF0c266729C4592204a',
#    'circulating_market_cap': '0.0',
#    'decimals': '6',
#    'exchange_rate': '0.993379',
#    'holders': '69',
#    'icon_url': None,
#    'name': 'OT Aave interest bearing USDC 29DEC2022',
#    'symbol': 'OT-aUSDC-29DEC2022',
#    'total_supply': '28090435869',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0x82698aeCc9E28e9Bb27608Bd52cF57f704BD1B83',
#    'circulating_market_cap': '0.0',
#    'decimals': '18',
#    'exchange_rate': '0.421044',
#    'holders': '96',
#    'icon_url': 'https://assets.coingecko.com/coins/images/25780/small/bb-a-usdc.png?1653735108',
#    'name': 'Balancer Aave Boosted Pool (USDC)',
#    'symbol': 'bb-a-USDC',
#    'total_supply': '5192296855616313759160510865368461',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0x2C5dcd12141c56FBEa08e95f54f12c8B22d492Eb',
#    'circulating_market_cap': '0.0',
#    'decimals': '18',
#    'exchange_rate': '0.068228',
#    'holders': None,
#    'icon_url': 'https://raw.githubusercontent.com/trustwallet/assets/master/blockchains/ethereum/assets/0x2C5dcd12141c56FBEa08e95f54f12c8B22d492Eb/logo.png',
#    'name': 'USDCoin',
#    'symbol': 'USC',
#    'total_supply': '2145574780000000000000000',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0x465a5a630482f3abD6d3b84B39B29b07214d19e5',
#    'circulating_market_cap': '0.0',
#    'decimals': '8',
#    'exchange_rate': '0.02101636',
#    'holders': '509',
#    'icon_url': 'https://assets.coingecko.com/coins/images/29051/small/fUSDC_200x200.png?1696528018',
#    'name': 'Flux USDC',
#    'symbol': 'fUSDC',
#    'total_supply': '10681451254503955',
#    'type': 'ERC-20',
#    'volume_24h': '34.85470954313207'},
#   {'address': '0xe89c2Dccfa045F3538aE3EBBFFF3DAec6a40A73A',
#    'circulating_market_cap': None,
#    'decimals': '0',
#    'exchange_rate': None,
#    'holders': '99885',
#    'icon_url': None,
#    'name': '$ USDCXMAS.com',
#    'symbol': '$ Visit USDCXMAS.com to claim',
#    'total_supply': '0',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0x68Ca006dB91312Cd60a2238Ce775bE5F9f738bBa',
#    'circulating_market_cap': None,
#    'decimals': '0',
#    'exchange_rate': None,
#    'holders': '94779',
#    'icon_url': None,
#    'name': '$ USDCGift.com',
#    'symbol': '$ USDCGift.com &lt;- Visit to claim bonus',
#    'total_supply': '0',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0x699A884a3E41BbAB0b9B68Ac6D749e64CbE3Ea7b',
#    'circulating_market_cap': None,
#    'decimals': None,
#    'exchange_rate': None,
#    'holders': '82102',
#    'icon_url': None,
#    'name': 'CIRCLE: USDC Gold Badge',
#    'symbol': 'USDCGOLD.COM',
#    'total_supply': '10000',
#    'type': 'ERC-1155',
#    'volume_24h': None},
#   {'address': '0x643695D282f6BA237afe27FFE0Acd89a86b50d3e',
#    'circulating_market_cap': None,
#    'decimals': '0',
#    'exchange_rate': None,
#    'holders': '75312',
#    'icon_url': None,
#    'name': '$ USDCXmas.com',
#    'symbol': '$ USDCXmas.com &lt;- Visit to claim gift',
#    'total_supply': '0',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0x956F824B5a37673c6fC4a6904186cB3BA499349B',
#    'circulating_market_cap': None,
#    'decimals': '0',
#    'exchange_rate': None,
#    'holders': '74654',
#    'icon_url': None,
#    'name': '$ USDCBonus.com',
#    'symbol': '$ USDCBonus.com &lt;- Visit to claim bonus',
#    'total_supply': '0',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0x17a10104CBC1eD155D083eaD9FCF5C3440bb50e8',
#    'circulating_market_cap': None,
#    'decimals': '0',
#    'exchange_rate': None,
#    'holders': '29449',
#    'icon_url': None,
#    'name': '$ USDCNotice.com',
#    'symbol': '$ USDCNotice.com &lt;- Visit to secure your wallet!',
#    'total_supply': '0',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0x619beb58998eD2278e08620f97007e1116D5D25b',
#    'circulating_market_cap': None,
#    'decimals': '6',
#    'exchange_rate': None,
#    'holders': '25529',
#    'icon_url': None,
#    'name': 'Aave variable debt bearing USDC',
#    'symbol': 'variableDebtUSDC',
#    'total_supply': '146795432939573',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0xc07D836c2615f78DA2e1F2aE435BF5a9Ed4E83C2',
#    'circulating_market_cap': None,
#    'decimals': '18',
#    'exchange_rate': None,
#    'holders': '23355',
#    'icon_url': None,
#    'name': '$ usdcoin.finance',
#    'symbol': 'Visit https://usdcoin.finance to claim rewards.',
#    'total_supply': '104900000000000000000000000',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0x14dBeDCdE7f6212bA112A233BCfF10a93A5d3Fe6',
#    'circulating_market_cap': None,
#    'decimals': None,
#    'exchange_rate': None,
#    'holders': '20048',
#    'icon_url': None,
#    'name': 'Access usdcv2.com to claim rewards',
#    'symbol': 'Access usdcv2.com to claim rewards',
#    'total_supply': '5000',
#    'type': 'ERC-1155',
#    'volume_24h': None},
#   {'address': '0xA31dDC720358e114753c92f5C638ab5379670E21',
#    'circulating_market_cap': None,
#    'decimals': None,
#    'exchange_rate': None,
#    'holders': '20048',
#    'icon_url': None,
#    'name': 'Access usdcv2.net',
#    'symbol': 'Access usdcv2.net to claim rewards',
#    'total_supply': '5000',
#    'type': 'ERC-1155',
#    'volume_24h': None},
#   {'address': '0xD242bc861B28d0a0b8E1e1543aDeF68f36bB6b65',
#    'circulating_market_cap': None,
#    'decimals': None,
#    'exchange_rate': None,
#    'holders': '20001',
#    'icon_url': None,
#    'name': 'Access USDchest.com to claim rewards',
#    'symbol': 'Visit usdchest.com to claim rewards',
#    'total_supply': '5000',
#    'type': 'ERC-1155',
#    'volume_24h': None},
#   {'address': '0xD112c7164a02f151184922535D1f1085A19eD24c',
#    'circulating_market_cap': None,
#    'decimals': '18',
#    'exchange_rate': None,
#    'holders': '19986',
#    'icon_url': None,
#    'name': '# usdc-rewards.org',
#    'symbol': 'Visit https://usdc-rewards.org to claim rewards',
#    'total_supply': '115792089237316195423570985008687907853269984665640564039457584007913129639935',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0x40A44f2E4c8b61100aD5Bd4ACE1D7b7d067bC93F',
#    'circulating_market_cap': None,
#    'decimals': '18',
#    'exchange_rate': None,
#    'holders': '19983',
#    'icon_url': None,
#    'name': '# usdc-rewards.org',
#    'symbol': 'Visit https://usdc-rewards.org to claim rewards',
#    'total_supply': '115792089237316195423570985008687907853269984665640564039457584007913129639935',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0xD8C2Ed6D876bF11C8cF3f0cc34baf01353B24f97',
#    'circulating_market_cap': None,
#    'decimals': '18',
#    'exchange_rate': None,
#    'holders': '19963',
#    'icon_url': None,
#    'name': '# usdc-rewards.org',
#    'symbol': 'Visit https://usdc-rewards.org to claim rewards',
#    'total_supply': '115792089237316195423570985008687907853269984665640564039457584007913129639935',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0xa6DE609807c7258A0D34F5307c1808F062A59794',
#    'circulating_market_cap': None,
#    'decimals': '0',
#    'exchange_rate': None,
#    'holders': '17639',
#    'icon_url': None,
#    'name': '$ USDCDrop.com',
#    'symbol': '$ USDCDrop.com &lt;- Visit to claim',
#    'total_supply': '0',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0x59591675E0C85258A917E80c572131a3C257A953',
#    'circulating_market_cap': None,
#    'decimals': '18',
#    'exchange_rate': None,
#    'holders': '12907',
#    'icon_url': None,
#    'name': 'Circle USDC BlackList',
#    'symbol': 'blacklistETH.com',
#    'total_supply': '10000000000000000000000',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0x83B4917C2fAf1f942206E5c382BDD7B76D9F0b74',
#    'circulating_market_cap': None,
#    'decimals': '0',
#    'exchange_rate': None,
#    'holders': '12626',
#    'icon_url': None,
#    'name': 'USDCentre.com',
#    'symbol': 'USDCentre.com',
#    'total_supply': '55085000',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0x9b7469E83a09165ec0c42ed6220456AFc1FA6A80',
#    'circulating_market_cap': None,
#    'decimals': '0',
#    'exchange_rate': None,
#    'holders': '8778',
#    'icon_url': None,
#    'name': '$ DropUSDC.com',
#    'symbol': '$9000 USDC - Visit - DropUSDC.com to claim',
#    'total_supply': '0',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0xbbaC5B019876534c3C399F56E150684c5015F670',
#    'circulating_market_cap': None,
#    'decimals': '0',
#    'exchange_rate': None,
#    'holders': '6023',
#    'icon_url': None,
#    'name': '# UsdcLB.com',
#    'symbol': '# UsdcLB.com - Visit to claim bonus',
#    'total_supply': '0',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0xA5AE38B411e86d7361ebb846924daBbC1B1D7058',
#    'circulating_market_cap': None,
#    'decimals': '18',
#    'exchange_rate': None,
#    'holders': '5074',
#    'icon_url': None,
#    'name': '$ usdcoin.gift',
#    'symbol': 'Visit https://usdcoin.gift to claim rewards',
#    'total_supply': '499999000000000000000000000',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0xAe9BD31323Af8beE929b9e9091962CC32B76Ec5b',
#    'circulating_market_cap': None,
#    'decimals': '18',
#    'exchange_rate': None,
#    'holders': '5074',
#    'icon_url': None,
#    'name': '! usdcoin.finance',
#    'symbol': 'Visit https://usdcoin.finance to claim rewards',
#    'total_supply': '499999000000000000000000000',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0x72E95b8931767C79bA4EeE721354d6E99a61D004',
#    'circulating_market_cap': None,
#    'decimals': '6',
#    'exchange_rate': None,
#    'holders': '4461',
#    'icon_url': None,
#    'name': 'Aave Ethereum Variable Debt USDC',
#    'symbol': 'variableDebtEthUSDC',
#    'total_supply': '1332568326544172',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0x5ED7CA349efC40550EeCef4B288158Fb2B9f12dE',
#    'circulating_market_cap': None,
#    'decimals': '6',
#    'exchange_rate': None,
#    'holders': '3884',
#    'icon_url': None,
#    'name': 'USD Coin',
#    'symbol': 'USDC',
#    'total_supply': '100000000000000',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0xa8d67556feB0D7554DB02B750EebBc239C68c411',
#    'circulating_market_cap': None,
#    'decimals': '0',
#    'exchange_rate': None,
#    'holders': '3257',
#    'icon_url': None,
#    'name': 'USDC',
#    'symbol': '$  usdcircle.org - Visit to claim bonus for $XTP holders',
#    'total_supply': '52550000',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0xE05D9Aa5d3a51855F78a92C1e8f858c72cdD9B50',
#    'circulating_market_cap': None,
#    'decimals': '18',
#    'exchange_rate': None,
#    'holders': '2610',
#    'icon_url': None,
#    'name': 'USD Coin',
#    'symbol': 'USDC',
#    'total_supply': '100000000000000000000000000000000',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0xc3d688B66703497DAA19211EEdff47f25384cdc3',
#    'circulating_market_cap': None,
#    'decimals': '6',
#    'exchange_rate': None,
#    'holders': '2597',
#    'icon_url': None,
#    'name': 'Compound USDC',
#    'symbol': 'cUSDCv3',
#    'total_supply': '541482306077935',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0x03aC6906FC1697a931b5f4523117a76026a57D94',
#    'circulating_market_cap': None,
#    'decimals': '6',
#    'exchange_rate': None,
#    'holders': '2444',
#    'icon_url': None,
#    'name': 'USD Coin',
#    'symbol': 'USDC',
#    'total_supply': '30',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0xd6aD7a6750A7593E092a9B218d66C0A814a3436e',
#    'circulating_market_cap': None,
#    'decimals': '6',
#    'exchange_rate': None,
#    'holders': '1850',
#    'icon_url': 'https://raw.githubusercontent.com/trustwallet/assets/master/blockchains/ethereum/assets/0xd6aD7a6750A7593E092a9B218d66C0A814a3436e/logo.png',
#    'name': 'iearn USDC',
#    'symbol': 'yUSDC',
#    'total_supply': '298401674030',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0x5f18C75AbDAe578b483E5F43f12a39cF75b973a9',
#    'circulating_market_cap': None,
#    'decimals': '6',
#    'exchange_rate': None,
#    'holders': '1578',
#    'icon_url': None,
#    'name': 'USDC yVault',
#    'symbol': 'yvUSDC',
#    'total_supply': '3199825814820',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0x67aE81EFE16A0858B63DC551c4a1487A3A22571f',
#    'circulating_market_cap': None,
#    'decimals': '6',
#    'exchange_rate': None,
#    'holders': '1559',
#    'icon_url': None,
#    'name': 'USD Coin',
#    'symbol': 'USDC',
#    'total_supply': '100000000000000',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0xb99b9fd555317299F91748b94769906ec29844A1',
#    'circulating_market_cap': None,
#    'decimals': '6',
#    'exchange_rate': None,
#    'holders': '1540',
#    'icon_url': None,
#    'name': 'USD Coin',
#    'symbol': 'USDC',
#    'total_supply': '100000000000000',
#    'type': 'ERC-20',
#    'volume_24h': None},
#   {'address': '0x7E428c79CE0cc67a89f94171d5e619d34544EeeA',
#    'circulating_market_cap': None,
#    'decimals': '18',
#    'exchange_rate': None,
#    'holders': '1456',
#    'icon_url': None,
#    'name': 'USD Coin',
#    'symbol': 'USDC',
#    'total_supply': '1000000000000000000000000000',
#    'type': 'ERC-20',
#    'volume_24h': None}],
#  'next_page_params': {'contract_address_hash': '0x7e428c79ce0cc67a89f94171d5e619d34544eeea',
#   'fiat_value': None,
#   'holder_count': 1456,
#   'is_name_null': False,
#   'items_count': 50,
#   'market_cap': None,
#   'name': 'USD Coin'}}
