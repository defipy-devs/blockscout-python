# %%
from blockscout import Blockscout
from blockscout import TokenTransfers
from blockscout import Net
from blockscout import API

vitalik_addr = '0xd8da6bf26964af9d7eed9e03e53415d37aa96045'
usdc_addr = '0xA0b86991c6218b36c1d19D4a2e9Eb0cE3606eB48'

eth_rest = Blockscout(Net.ETH, API.REST)

# %%
#eth_rest.get_main_page_blocks()

# %%
eth_rest.get_block_withdrawals(block_number = "20386484")
# Out:
# url: https://eth.blockscout.com/api/v2/blocks/20386484/withdrawals
# {'items': [{'amount': '18882859000000000',
#    'index': 53624378,
#    'receiver': {'ens_domain_name': None,
#     'hash': '0xF255161AF38F9ff3596261D91716A55c5345c62b',
#     'implementation_address': None,
#     'implementation_name': None,
#     'implementations': [],
#     'is_contract': False,
#     'is_verified': False,
#     'metadata': None,
#     'name': None,
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'validator_index': 417348},
#   {'amount': '18859729000000000',
#    'index': 53624377,
#    'receiver': {'ens_domain_name': None,
#     'hash': '0xF255161AF38F9ff3596261D91716A55c5345c62b',
#     'implementation_address': None,
#     'implementation_name': None,
#     'implementations': [],
#     'is_contract': False,
#     'is_verified': False,
#     'metadata': None,
#     'name': None,
#     'private_tags': [],
#     'public_tags': [],
# ...

# %%
eth_rest.get_block_transactions(block_number = "20386484")
# Out:
# url: https://eth.blockscout.com/api/v2/blocks/20386484/transactions
# {'items': [{'timestamp': '2024-07-25T22:16:11.000000Z',
#    'fee': {'type': 'actual', 'value': '9115268806318320'},
#    'gas_limit': '262142',
#    'block': 20386484,
#    'status': 'ok',
#    'method': 'swapExactTokensForETHSupportingFeeOnTransferTokens',
#    'confirmations': 3,
#    'type': 2,
#    'exchange_rate': '3183.09',
#    'to': {'ens_domain_name': None,
#     'hash': '0x80a64c6D7f12C47B7c66c5B4E20E72bc1FCd5d9e',
#     'implementation_address': '0x46Affe1b4f3fc41581Fd20FbAF055daeAb80A8b5',
#     'implementation_name': None,
#     'implementations': [{'address': '0x46Affe1b4f3fc41581Fd20FbAF055daeAb80A8b5',
#       'name': None}],
#     'is_contract': True,
#     'is_verified': False,
#     'metadata': {'tags': [{'meta': {},
#        'name': 'Maestro: Router 2',
#        'ordinal': 10,
#        'slug': 'maestro-router-2',
#        'tagType': 'name'}]},
#     'name': None,
#     'private_tags': [],
# ...

# %%
eth_rest.get_block_info(block_number = "20386484")
# Out:
# url: https://eth.blockscout.com/api/v2/blocks/20386484
# {'base_fee_per_gas': '1891513710',
#  'blob_gas_price': '1',
#  'blob_gas_used': '131072',
#  'blob_tx_count': 1,
#  'burnt_blob_fees': '131072',
#  'burnt_fees': '23124655465275960',
#  'burnt_fees_percentage': 43.38207365470868,
#  'difficulty': '0',
#  'excess_blob_gas': '131072',
#  'gas_limit': '30000000',
#  'gas_target_percentage': -18.496826666666667,
#  'gas_used': '12225476',
#  'gas_used_percentage': 40.75158666666667,
#  'hash': '0x4ecb260c3d151a5ca40beaaeb0d989b7bcdd4295a6e8e71c9953b87c3892233d',
#  'height': 20386484,
#  'miner': {'ens_domain_name': None,
#   'hash': '0x95222290DD7278Aa3Ddd389Cc1E1d165CC4BAfe5',
#   'implementation_address': None,
#   'implementation_name': None,
#   'implementations': [],
#   'is_contract': False,
#   'is_verified': False,
#   'metadata': None,
#   'name': None,
#   'private_tags': [],
#   'public_tags': [],
#   'watchlist_names': []},
#  'nonce': '0x0000000000000000',
# ...
