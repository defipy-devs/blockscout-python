# %%
from blockscout import Blockscout
from blockscout import TokenTransfers
from blockscout import Net
from blockscout import API

vitalik_addr = '0xd8da6bf26964af9d7eed9e03e53415d37aa96045'
usdc_addr = '0xA0b86991c6218b36c1d19D4a2e9Eb0cE3606eB48'

eth_rest = Blockscout(Net.ETH, API.REST)

# %%
#eth_rest.get_smart_contract(address=usdc_addr)

# %%
eth_rest.get_smart_contract_counters()
# Out:
# url: https://eth.blockscout.com/api/v2/smart-contracts/counters
# {'new_smart_contracts_24h': '895',
#  'new_verified_smart_contracts_24h': '1403',
#  'smart_contracts': '66336941',
#  'verified_smart_contracts': '1316213'}

# %%
eth_rest.get_smart_contracts(contract_type="proxy")
# Out:
# url: https://eth.blockscout.com/api/v2/smart-contracts?q=proxy&filter=vyper%20%7C%20solidity%20%7C%20yul
# {'items': [{'address': {'ens_domain_name': None,
#     'hash': '0x9Dda98309562b02450e5F6Db5B87f8D1Bd090e91',
#     'implementation_address': None,
#     'implementation_name': None,
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'ProxyAdmin',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.8.12+commit.f00d7308',
#    'has_constructor_args': False,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': True,
#    'tx_count': None,
#    'verified_at': '2024-07-25T21:37:25.866569Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x978fc274a4845b959E6e26cD23e21dDbdb9469d4',
#     'implementation_address': '0x835c7f2a650e170e2F3B6C63C410f3A1571C904C',
#     'implementation_name': 'FixedPriceToken',
#     'implementations': [{'address': '0x835c7f2a650e170e2F3B6C63C410f3A1571C904C',
#       'name': 'FixedPriceToken'}],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'TokenProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': '0.8.16+commit.07a7930e',
#    'has_constructor_args': False,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': True,
#    'tx_count': None,
#    'verified_at': '2024-07-25T21:26:16.220486Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x9a4d39F46044400Aa48Ab528f8EC3DD3B793f885',
#     'implementation_address': '0x8d67Ef98c103bE264F2b6D78D02079a11F26DA29',
#     'implementation_name': 'OMD_LAUNCHPAD_V4',
#     'implementations': [{'address': '0x8d67Ef98c103bE264F2b6D78D02079a11F26DA29',
#       'name': 'OMD_LAUNCHPAD_V4'}],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'TransparentUpgradeableProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.8.9+commit.e5eed63a',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': True,
#    'tx_count': None,
#    'verified_at': '2024-07-25T20:16:26.457989Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x38B22E7C6F696533637203B763F9D6c63C48466E',
#     'implementation_address': '0x5EFb2F3A795a984EdCA5982D2231f2642cc3f6fE',
#     'implementation_name': 'L2OutputOracle',
#     'implementations': [{'address': '0x5EFb2F3A795a984EdCA5982D2231f2642cc3f6fE',
#       'name': 'L2OutputOracle'}],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'Proxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.8.15+commit.e14f2714',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': True,
#    'tx_count': None,
#    'verified_at': '2024-07-25T19:29:56.362510Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x4523D43C75c7252A26DC5540985D0bc9670147c9',
#     'implementation_address': None,
#     'implementation_name': None,
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'GnosisSafeProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.7.6+commit.7338295f',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': False,
#    'tx_count': None,
#    'verified_at': '2024-07-25T19:23:43.757250Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x72c3166c54E193C247e1c89f98081E57c2E477cf',
#     'implementation_address': None,
#     'implementation_name': None,
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'GnosisSafeProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '319094416100000',
#    'compiler_version': 'v0.7.6+commit.7338295f',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': False,
#    'tx_count': None,
#    'verified_at': '2024-07-25T18:16:40.286252Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x152e3Ac4fa8d4b25d31B02095235eAD483f5A83d',
#     'implementation_address': None,
#     'implementation_name': None,
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'ProxyAdmin',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.8.23+commit.f704f362',
#    'has_constructor_args': False,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': True,
#    'tx_count': None,
#    'verified_at': '2024-07-25T17:59:00.377154Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0xaC916c015B1B706b08AE28082FB1B868BCBBF632',
#     'implementation_address': '0xDc40ddc2EB6B818CcD8B16a4c347EFd06C5Ecb73',
#     'implementation_name': None,
#     'implementations': [{'address': '0xDc40ddc2EB6B818CcD8B16a4c347EFd06C5Ecb73',
#       'name': None}],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'TransparentUpgradeableProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.8.20+commit.a1b79de6',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': True,
#    'tx_count': None,
#    'verified_at': '2024-07-25T16:04:51.889265Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x7537AAe01f3B218DAE75e10d952473823F961B87',
#     'implementation_address': None,
#     'implementation_name': None,
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'ProxyERC20',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': '0.5.16+commit.9c3226ce',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': True,
#    'tx_count': None,
#    'verified_at': '2024-07-25T15:38:08.795258Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0xa3a45bE536a3Bb9ad101d489Ff2aA45b59270f09',
#     'implementation_address': None,
#     'implementation_name': None,
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'GnosisSafeProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.7.6+commit.7338295f',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': False,
#    'tx_count': None,
#    'verified_at': '2024-07-25T15:29:38.387070Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0xAF3B71Af1f8d7776D37b3CEe2cCc8E1d1D51d9cE',
#     'implementation_address': None,
#     'implementation_name': None,
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'GnosisSafeProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '6915583066668764347',
#    'compiler_version': 'v0.7.6+commit.7338295f',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': False,
#    'tx_count': None,
#    'verified_at': '2024-07-25T14:31:18.390762Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0xC50Cc7522Aac28fb9ee1F54a39Cd14783A0cAC14',
#     'implementation_address': None,
#     'implementation_name': None,
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'GnosisSafeProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.7.6+commit.7338295f',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': False,
#    'tx_count': None,
#    'verified_at': '2024-07-25T13:46:11.745428Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x4B6Fb1C8D16D3e409aCC9461118c036C1efDB173',
#     'implementation_address': '0x28144C53bA98B4e909Df5bC7cA33eAf0404cFfcc',
#     'implementation_name': 'EigenPod',
#     'implementations': [{'address': '0x28144C53bA98B4e909Df5bC7cA33eAf0404cFfcc',
#       'name': 'EigenPod'}],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'BeaconProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': '0.8.12+commit.f00d7308',
#    'has_constructor_args': False,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': True,
#    'tx_count': None,
#    'verified_at': '2024-07-25T13:25:34.952379Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x2C4B69C4c85C578cf91Bf660d9dEB80FECb3a6c9',
#     'implementation_address': None,
#     'implementation_name': None,
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'GnosisSafeProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.7.6+commit.7338295f',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': False,
#    'tx_count': None,
#    'verified_at': '2024-07-25T13:21:13.105354Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x877e58e74dD2bf4A12F25CeAA7Fa20A16D910631',
#     'implementation_address': '0xCd0AB837747095139577bDC6C0fadD34648DCC51',
#     'implementation_name': None,
#     'implementations': [{'address': '0xCd0AB837747095139577bDC6C0fadD34648DCC51',
#       'name': None}],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'TransparentUpgradeableProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.8.20+commit.a1b79de6',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': True,
#    'tx_count': None,
#    'verified_at': '2024-07-25T13:09:46.056098Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x584725bb23E76da3567c0C80EaDaE892cF910A1b',
#     'implementation_address': None,
#     'implementation_name': None,
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'Proxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': '0.8.20+commit.a1b79de6',
#    'has_constructor_args': False,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': True,
#    'tx_count': None,
#    'verified_at': '2024-07-25T13:01:23.487983Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x62D2a28d77c8312E798C214e2876B12a02B1e6fC',
#     'implementation_address': None,
#     'implementation_name': None,
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'GnosisSafeProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.7.6+commit.7338295f',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': False,
#    'tx_count': None,
#    'verified_at': '2024-07-25T13:00:48.652372Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x9c7f5D20ed8758aB2dA1AA567663cFAdffF6f146',
#     'implementation_address': '0x27f57e6E919EB8fa8EA8f64a45dD425C70d3Ad44',
#     'implementation_name': 'CollateralEscrowV1',
#     'implementations': [{'address': '0x27f57e6E919EB8fa8EA8f64a45dD425C70d3Ad44',
#       'name': 'CollateralEscrowV1'}],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'BeaconProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.8.9+commit.e5eed63a',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': True,
#    'tx_count': None,
#    'verified_at': '2024-07-25T12:56:20.521990Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0xabAB4fF503adc34c324bD7Ce29C41a66cD07Df0B',
#     'implementation_address': '0xabe3B0498108080922dE411bf3A853b2614f4f3C',
#     'implementation_name': 'DepositTokenV2',
#     'implementations': [{'address': '0xabe3B0498108080922dE411bf3A853b2614f4f3C',
#       'name': 'DepositTokenV2'}],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'BeaconProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': '0.8.17+commit.8df45f5f',
#    'has_constructor_args': False,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': True,
#    'tx_count': None,
#    'verified_at': '2024-07-25T12:41:16.919947Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x826C2E9bF1E53ff77F2a99452501ddA7F44D09D5',
#     'implementation_address': None,
#     'implementation_name': None,
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'GnosisSafeProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.7.6+commit.7338295f',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': False,
#    'tx_count': None,
#    'verified_at': '2024-07-25T12:40:44.502451Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0xF4f6FC195c387c02B8A3A9Fc89daB4079a84310f',
#     'implementation_address': '0xC016e6b04fE1CDFa642D20dBa4Ae4AC60D8442Cb',
#     'implementation_name': None,
#     'implementations': [{'address': '0xC016e6b04fE1CDFa642D20dBa4Ae4AC60D8442Cb',
#       'name': None}],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'FactorTransparentUpgradeableProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': '0.8.20+commit.a1b79de6',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': True,
#    'tx_count': None,
#    'verified_at': '2024-07-25T12:39:43.793958Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0xe5fE957F0E57Aa1E3CC8E10675b6A97A96D17Cb9',
#     'implementation_address': None,
#     'implementation_name': None,
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'GnosisSafeProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.7.6+commit.7338295f',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': False,
#    'tx_count': None,
#    'verified_at': '2024-07-25T12:23:56.347109Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x7Ba607ae1b88c813f072c397aF78437123E3a450',
#     'implementation_address': None,
#     'implementation_name': None,
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'GnosisSafeProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.7.6+commit.7338295f',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': False,
#    'tx_count': None,
#    'verified_at': '2024-07-25T12:21:05.641729Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x2ea72B70e07F0D1a50F840942F07F1F4599D7f8F',
#     'implementation_address': None,
#     'implementation_name': None,
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'GnosisSafeProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.7.6+commit.7338295f',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': False,
#    'tx_count': None,
#    'verified_at': '2024-07-25T12:18:10.161598Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x7530e19Da77f408f13c1B1e60D5854044A548B54',
#     'implementation_address': '0xA7D09255A068Bf433437d5Eb69D90f62DF0999C7',
#     'implementation_name': 'ERC20Vault',
#     'implementations': [{'address': '0xA7D09255A068Bf433437d5Eb69D90f62DF0999C7',
#       'name': 'ERC20Vault'}],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'TransparentUpgradeableProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': '0.8.10+commit.fc410830',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': True,
#    'tx_count': None,
#    'verified_at': '2024-07-25T12:14:08.100283Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x13E2bDcFb65ee00b77eA2e4D46dd8eC482667f71',
#     'implementation_address': None,
#     'implementation_name': None,
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'GnosisSafeProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.7.6+commit.7338295f',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': False,
#    'tx_count': None,
#    'verified_at': '2024-07-25T12:12:00.248325Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0xD32807777Aec929B0c11D2e96D67F4779bd7fFD1',
#     'implementation_address': None,
#     'implementation_name': None,
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'GnosisSafeProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.7.6+commit.7338295f',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': False,
#    'tx_count': None,
#    'verified_at': '2024-07-25T12:08:57.258258Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x43a127EcCEdf029C1ACb262557d10cd7AE69FA70',
#     'implementation_address': '0xfECEdf1593A3a18973adD5Fe6f2fc1CfBF14C928',
#     'implementation_name': None,
#     'implementations': [{'address': '0xfECEdf1593A3a18973adD5Fe6f2fc1CfBF14C928',
#       'name': None}],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'TransparentUpgradeableProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': '0.8.9+commit.e5eed63a',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': True,
#    'tx_count': None,
#    'verified_at': '2024-07-25T12:08:33.892916Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x7E7918Fd9C1b7943eE075F6099c4e7fFaC9815C2',
#     'implementation_address': None,
#     'implementation_name': None,
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'GnosisSafeProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.7.6+commit.7338295f',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': False,
#    'tx_count': None,
#    'verified_at': '2024-07-25T11:51:11.235116Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x1212Cf47DdE5b7B47472A1D1a3bF73Bc3bE5F005',
#     'implementation_address': None,
#     'implementation_name': None,
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'ProxyAdmin',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': '0.8.25+commit.b61c2a91',
#    'has_constructor_args': False,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': True,
#    'tx_count': None,
#    'verified_at': '2024-07-25T11:49:59.448405Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0xdf1dBA31476D49404B4dE9C2b7b4319f121b926f',
#     'implementation_address': '0x70bE90cD788bEf69d52b0D6E767EFE3b289bd0B4',
#     'implementation_name': None,
#     'implementations': [{'address': '0x70bE90cD788bEf69d52b0D6E767EFE3b289bd0B4',
#       'name': None}],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'AdminUpgradeabilityProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.5.2+commit.1df8f40c',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': False,
#    'tx_count': None,
#    'verified_at': '2024-07-25T11:46:13.703282Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0xE7C6A4525492395d65e736C3593aC933F33ee46e',
#     'implementation_address': '0xc9f019Fa138Ba4FAc3B4e400705FbDD75B20Af8c',
#     'implementation_name': 'IdleCDO',
#     'implementations': [{'address': '0xc9f019Fa138Ba4FAc3B4e400705FbDD75B20Af8c',
#       'name': 'IdleCDO'}],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'TransparentUpgradeableProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': '0.8.7+commit.e28d00a7',
#    'has_constructor_args': False,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': True,
#    'tx_count': None,
#    'verified_at': '2024-07-25T11:31:34.193675Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x997E6044D0e376b15BEF7847Fc45fa83D1D931eD',
#     'implementation_address': None,
#     'implementation_name': None,
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'GnosisSafeProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.7.6+commit.7338295f',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': False,
#    'tx_count': None,
#    'verified_at': '2024-07-25T11:30:08.257247Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x6E5D99B00BA4c7D5FA945f9C4C8ab455bEDe98F3',
#     'implementation_address': '0xd9Db270c1B5E3Bd161E8c8503c55cEABeE709552',
#     'implementation_name': 'GnosisSafe',
#     'implementations': [{'address': '0xd9Db270c1B5E3Bd161E8c8503c55cEABeE709552',
#       'name': 'GnosisSafe'}],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'GnosisSafeProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.7.6+commit.7338295f',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': False,
#    'tx_count': None,
#    'verified_at': '2024-07-25T11:17:55.462558Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x4Fd7c5Dd727ba7CA5021e33846D141bc5d1E0156',
#     'implementation_address': None,
#     'implementation_name': None,
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'GnosisSafeProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.7.6+commit.7338295f',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': False,
#    'tx_count': None,
#    'verified_at': '2024-07-25T11:17:16.656179Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0xC29DD480B8A9dB7732B2Cc55df1a545e4567079a',
#     'implementation_address': '0x27f57e6E919EB8fa8EA8f64a45dD425C70d3Ad44',
#     'implementation_name': 'CollateralEscrowV1',
#     'implementations': [{'address': '0x27f57e6E919EB8fa8EA8f64a45dD425C70d3Ad44',
#       'name': 'CollateralEscrowV1'}],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'BeaconProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.8.9+commit.e5eed63a',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': True,
#    'tx_count': None,
#    'verified_at': '2024-07-25T11:16:58.500976Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0xb938C128a41a313876f0E6C715402335eb71679d',
#     'implementation_address': None,
#     'implementation_name': None,
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'GnosisSafeProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '1994726945663454',
#    'compiler_version': 'v0.7.6+commit.7338295f',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': False,
#    'tx_count': None,
#    'verified_at': '2024-07-25T11:14:50.967652Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x76962391e8435f70E20753c09D0CeEF31e58229e',
#     'implementation_address': None,
#     'implementation_name': None,
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'ProxyAdmin',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': '0.8.10+commit.fc410830',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': True,
#    'tx_count': None,
#    'verified_at': '2024-07-25T11:09:10.536606Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x9cDbe24a9615D6046B00f98b7A0F28cE7E80297A',
#     'implementation_address': None,
#     'implementation_name': None,
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'GnosisSafeProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.7.6+commit.7338295f',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': False,
#    'tx_count': None,
#    'verified_at': '2024-07-25T10:51:03.350420Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x7826D9dD5bFC10D3F6c8B6911d9A21A09219b283',
#     'implementation_address': None,
#     'implementation_name': None,
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'GnosisSafeProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.7.6+commit.7338295f',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': False,
#    'tx_count': None,
#    'verified_at': '2024-07-25T10:46:27.007533Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x7c42E147B6d4F7c521E1aDB40D26d023C72Dcec9',
#     'implementation_address': None,
#     'implementation_name': None,
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'GnosisSafeProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.7.6+commit.7338295f',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': False,
#    'tx_count': None,
#    'verified_at': '2024-07-25T10:34:53.067294Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x33ceD3dEF368Ba2a168D4c1705067aCb25AF7aC8',
#     'implementation_address': None,
#     'implementation_name': None,
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'GnosisSafeProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '15800680169689715',
#    'compiler_version': 'v0.7.6+commit.7338295f',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': False,
#    'tx_count': None,
#    'verified_at': '2024-07-25T10:32:39.789332Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x6339D664278C4E0b2EfE560da422C2A118268cAa',
#     'implementation_address': '0xA1077a294dDE1B09bB078844df40758a5D0f9a27',
#     'implementation_name': 'PermittableToken',
#     'implementations': [{'address': '0xA1077a294dDE1B09bB078844df40758a5D0f9a27',
#       'name': 'PermittableToken'}],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'TokenProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.7.5+commit.eb77ed08',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': True,
#    'tx_count': None,
#    'verified_at': '2024-07-25T10:22:16.208094Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x706cC473DF9930EE1c1Dbd465e84cD4656A56462',
#     'implementation_address': '0xd9Db270c1B5E3Bd161E8c8503c55cEABeE709552',
#     'implementation_name': 'GnosisSafe',
#     'implementations': [{'address': '0xd9Db270c1B5E3Bd161E8c8503c55cEABeE709552',
#       'name': 'GnosisSafe'}],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'GnosisSafeProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.7.6+commit.7338295f',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': False,
#    'tx_count': None,
#    'verified_at': '2024-07-25T10:14:12.797461Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0xe8Cb591af0Fd5F3554D07e728f4AbB7cb49f3471',
#     'implementation_address': '0x8D7578c2188fb99b1Bd47889CE0B49c608705c89',
#     'implementation_name': None,
#     'implementations': [{'address': '0x8D7578c2188fb99b1Bd47889CE0B49c608705c89',
#       'name': None}],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'TransparentUpgradeableProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': '0.8.2+commit.661d1103',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': True,
#    'tx_count': None,
#    'verified_at': '2024-07-25T10:08:54.405345Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0xA854D35664c658280fFf27B6eDC6C4195c3229B3',
#     'implementation_address': None,
#     'implementation_name': None,
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'BeaconProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': '0.8.25+commit.b61c2a91',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': True,
#    'tx_count': None,
#    'verified_at': '2024-07-25T09:55:40.727272Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x9777E6359681dcEC7ffCa006C521a3D3fDc61365',
#     'implementation_address': None,
#     'implementation_name': None,
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'NonReceivableInitializedProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': '0.8.5+commit.a4f2e591',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': True,
#    'tx_count': 0,
#    'verified_at': '2024-07-25T09:51:06.794448Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x64000059F8580695A7a1d9d6b62edE503f903992',
#     'implementation_address': '0x5cA3eF0Af546296CB17d3A912C8b6bA5490db056',
#     'implementation_name': None,
#     'implementations': [{'address': '0x5cA3eF0Af546296CB17d3A912C8b6bA5490db056',
#       'name': None}],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'TransparentUpgradeableProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': '0.8.9+commit.e5eed63a',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': True,
#    'tx_count': None,
#    'verified_at': '2024-07-25T09:43:55.208107Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x11780211a1aaB0059BCa3E8E201CFe08287319eE',
#     'implementation_address': '0x6fe46C5CfcaD18b833c7933E40867d7571370A5E',
#     'implementation_name': 'AvailDepository',
#     'implementations': [{'address': '0x6fe46C5CfcaD18b833c7933E40867d7571370A5E',
#       'name': 'AvailDepository'}],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'TransparentUpgradeableProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': '0.8.25+commit.b61c2a91',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': True,
#    'tx_count': None,
#    'verified_at': '2024-07-25T09:42:03.126729Z'},
#   {'address': {'ens_domain_name': None,
#     'hash': '0x83104f807976851c945a2dF58de7F0906BE7Aec8',
#     'implementation_address': None,
#     'implementation_name': None,
#     'implementations': [],
#     'is_contract': True,
#     'is_verified': True,
#     'metadata': None,
#     'name': 'GnosisSafeProxy',
#     'private_tags': [],
#     'public_tags': [],
#     'watchlist_names': []},
#    'certified': False,
#    'coin_balance': '0',
#    'compiler_version': 'v0.7.6+commit.7338295f',
#    'has_constructor_args': True,
#    'language': 'solidity',
#    'license_type': 'none',
#    'market_cap': None,
#    'optimization_enabled': False,
#    'tx_count': None,
#    'verified_at': '2024-07-25T09:41:18.067433Z'}],
#  'next_page_params': {'coin_balance': '0',
#   'items_count': 50,
#   'smart_contract_id': 1336022,
#   'tx_count': None}}
